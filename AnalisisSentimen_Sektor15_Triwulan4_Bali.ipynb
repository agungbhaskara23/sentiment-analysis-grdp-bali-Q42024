# %% [markdown]
# # **IMPORT PACKAGE**

# %%
import pandas as pd
import datetime
import os

# %% [markdown]
# # **DATA DEFINITION**

# %% [markdown]
# Pada bagian ini, dipetakan keyword yang akan digunakan untuk proses scrapping (per lapangan usaha), berikut juga dengan batasan waktu dari artikel yang ingin diambil. Di Badan Pusat Statistik, terdapat 17 sektor lapangan usaha, meliputi:
# 1.	Pertanian, Kehutanan, dan Perikanan
# 2.	Pertambangan dan Penggalian
# 3.	Industri Pengolahan
# 4.	Pengadaan Listrik, Gas
# 5.	Pengadaan Air, Pengelolaan Sampah, Limbah dan Daur Ulang
# 6.	Konstruksi
# 7.	Perdagangan Besar dan Eceran, Reparasi Mobil dan Sepeda Motor
# 8.	Transportasi dan Pergudangan
# 9.	Penyediaan Akomodasi dan Makan Minum
# 10.	Informasi dan Komunikasi
# 11.	Jasa Keuangan dan Asuransi
# 12.	Real Estat
# 13.	Jasa Perusahaan
# 14.	Administrasi Pemerintahan, Pertahanan dan Jaminan Sosial Wajib
# 15.	Jasa Pendidikan
# 16.	Jasa Kesehatan dan Kegiatan Sosial
# 17.	Jasa lainnya

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Tentukan keywords dari masing-masing lapangan usaha
key_sektor = ['pendidikan','biaya pendidikan','spp']

keywords_scrap = key_sektor

# Tentukan rentang tanggal
start_date = datetime.date(2024, 10, 1)
end_date = datetime.date(2024, 11, 12)

# %% [markdown]
# # **SCRAPPING, PRE-CLEANING, & EXPORT (Scrapping BaliPost Lama)**

# %% [markdown]
# ## 1. BaliPost

# %% [markdown]
# Fungsi dan package untuk scrapping di balipost ada pada kode di chunk berikut \
# Aktifkan kalau pencarian di balipost sudah berjalan normal (saat kode ini dibuat sangat lambat)

# %%
# import requests
# from bs4 import BeautifulSoup
# import datetime
# import pandas as pd

# # Fungsi untuk melakukan scraping dari BaliPost
# def scrape_balipost(keyword, start_date, end_date, max_results, max_pages):
#     """
#     Fungsi untuk melakukan scraping artikel dari situs BaliPost berdasarkan keyword dan rentang tanggal.

#     Args:
#     - keyword (str): Keyword pencarian.
#     - start_date (datetime.date): Tanggal awal.
#     - end_date (datetime.date): Tanggal akhir.
#     - max_results (int): Maksimum jumlah artikel yang diambil.
#     - max_pages (int): Maksimum jumlah halaman yang diambil.

#     Returns:
#     - results (list): Daftar artikel yang berisi judul, link, tanggal, keyword, dan isi.
#     """
#     results = []

#     # Mengganti spasi dengan tanda "+" untuk keyword yang lebih dari satu kata
#     search_keyword = keyword.replace(" ", "+")
#     base_url = f"https://www.balipost.com/search/{search_keyword}"
#     current_page = 1

#     while len(results) < max_results and current_page <= max_pages:
#         url = f"{base_url}/page/{current_page}" if current_page > 1 else base_url
#         print(f"Scraping halaman {current_page} dari URL: {url}")
#         response = requests.get(url)

#         if response.status_code != 200:
#             print(f"Error saat mengakses halaman {current_page}. Status code: {response.status_code}")
#             break

#         soup = BeautifulSoup(response.content, "html.parser")
#         articles = soup.find_all("div", class_="td_module_10 td_module_wrap td-animation-stack")

#         if not articles:
#             print(f"Tidak ada artikel di halaman {current_page}, berhenti scraping.")
#             break

#         for article in articles:
#             title_element = article.find("h3", class_="entry-title td-module-title")
#             if title_element:
#                 title = title_element.text.strip()
#                 link = article.find("a")["href"]

#                 date_element = article.find("time", class_="entry-date updated td-module-date")
#                 if date_element:
#                     date_str = date_element["datetime"][:10]
#                     date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()

#                     # Cek apakah tanggal artikel dalam rentang yang diinginkan
#                     if not (start_date <= date <= end_date):
#                         continue

#                 content_element = article.find("div", class_="td-excerpt")
#                 content = content_element.text.strip() if content_element else ""

#                 results.append({"title": title, "keyword": keyword, "source": "BaliPost", "link": link, "date": date, "content": content})
#                 if len(results) >= max_results:
#                     break

#         pagination = soup.find("a", class_="page", title=str(current_page + 1))
#         if pagination:
#             current_page += 1
#         else:
#             break

#     return results

# %% [markdown]
# Memulai proses scrapping berita

# %%
# # Step 4: Scraping untuk setiap keyword
# # Takes a LOOOOOOOOOOOONG time

# all_news = []

# for keyword in keywords_scrap:
#     print(f"\nMemulai scraping untuk keyword: {keyword}")
#     news = scrape_balipost(keyword, start_date, end_date, max_results=25, max_pages=3)

#     # Tampilkan jumlah artikel yang berhasil diekstrak untuk keyword ini
#     num_articles = len(news)
#     print(f"Jumlah artikel yang diekstrak untuk keyword '{keyword}': {num_articles}")

#     all_news.extend(news)

# # Step 5: Simpan hasil ke dalam file Excel
# berita_balipost = pd.DataFrame(all_news)
# berita_balipost

# %%
# # Import melalui kode ini kalau sudah ada raw data scrapping BaliPost yang terpisah dari proses scrapping diatas (hanya untuk BaliPost)
# berita_balipost = pd.read_excel("C:/Users/asus/OneDrive/BPS/Neraca/berita_sektor15_triwulan4_bali.xlsx")
# berita_balipost

# %% [markdown]
# Pre-cleaning \
# Hasil Scrapping BaliPost harus difilter terlebih dahulu wilayah (dari isi konten) dan judulnya (kadang tidak sesuai dengan kata yang diinginkan) \
# Contoh: Kata kunci --> Ikan || Judul ditemukan --> DicarIKAN, DijanjIKAN

# %%
# # Keyword to filter out
# keywords_filter = ["TABANAN","SINGARAJA","DENPASAR","MANGUPURA","AMLAPURA","SEMARAPURA","NEGARA","GIANYAR","BANGLI"]

# # Build the condition for multiple keywords
# pattern = '|'.join(keywords_filter)  # Create a pattern that matches any of the keywords

# # Filter out rows where 'Description' contains the keyword
# berita_balipost_2 = pd.DataFrame(berita_balipost[berita_balipost['content'].str.contains(pattern, case=False, na=False)])

# # Show the filtered DataFrame
# print(berita_balipost_2.shape)
# berita_balipost_2

# %%
# # Build the regular expression pattern with word boundaries
# pattern_1 = r'\b(' + '|'.join(keywords_scrap) + r')\b'  # Ensures "Ikan" is a whole word

# # Filter rows where 'Title' contains the keyword as a whole word (case insensitive)
# berita_balipost_3 = berita_balipost_2[berita_balipost_2['title'].str.contains(pattern_1, case=False, na=False)]

# # Show the filtered DataFrame
# print(berita_balipost_3.shape)
# berita_balipost_3

# %%
# # Remove Duplication
# berita_balipost_3 = berita_balipost_3.drop_duplicates(subset='title', keep='first')
# print(berita_balipost_3.shape)
# berita_balipost_3

# %% [markdown]
# ## 2. DetikBali

# %%
import math
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# Define web scraping functions
# Fungsi untuk menuju ke portal berita
def search_url(query, date_start, date_end, pages_num=1):
    url = f"https://www.detik.com/search/searchnews?query={query}&siteid=123&sortby=time&fromdatex={date_start}&todatex={date_end}&page={pages_num}&result_type=relevansi"
    
    print(url)
    response = requests.get(url)
    page = bs(response.content, "html.parser")

    return page

# Fungsi untuk menghitung jumlah artikel di halaman terakhir
def last_page_article_count(query, date_start, date_end, page_num):
    last_page = search_url(query, date_start, date_end, page_num)
    article_list = last_page.find("div", {"class": "list-content"})

    if article_list:
        articles = article_list.find_all('article', class_='list-content__item')           
    article_count = len(articles)
    
    return article_count

def news_search_results(query, date_start, date_end):
    page = search_url(query, date_start, date_end)
    
    pagination = page.find("div", {"class": "pagination"})
    if pagination:
        page_numbers = pagination.find_all('a', class_='pagination__item')
        if page_numbers:
            last_page_number = int(page_numbers[-2].text)

        # Menghitung jumlah artikel di halaman terakhir
        last_page_articles = last_page_article_count(query, date_start, date_end, last_page_number)

        # Menghitung jumlah artikel yang diperoleh
        num = (last_page_number - 1) * 10 + last_page_articles
    else:
        num = 0
        last_page_number = 1
    
    return num, last_page_number

# Fungsi untuk mendapatkan isi konten
def news_get_content(article_url):
    response = requests.get(article_url)
    content_page = bs(response.content, "html.parser")

    content_list = []
    multiple_page = content_page.find("div", {"class": "detail__multiple"})
    if multiple_page:
        multiple_page = [x.get("href") for x in multiple_page.find_all("a")][:-1]
        for page in multiple_page:
            response = requests.get(page)
            content_page = bs(response.content, "html.parser")
            content_list.extend([p.get_text() for p in content_page.find_all("p") if not p.get_text().startswith('\n\n\n\nHalaman\n\n') and
                                p.get_text() not in ['',
                                                    '[Gambas:Instagram]',
                                                    '[Gambas:Video 20detik]',
                                                    '\r\nADVERTISEMENT\r\n',
                                                    '\r\n    ADVERTISEMENT\r\n',
                                                    '\r\n    ADVERTISEMENT\r\n  ',
                                                    '\r\n   ADVERTISEMENT\r\n  ',
                                                    '\r\n   ADVERTISEMENT\r\n',
                                                    '\r\n        SCROLL TO RESUME CONTENT\r\n  ',
                                                    'Selengkapnya di halaman selanjutnya.',
                                                    '\n\t\t\t\t\tAyo share cerita pengalaman dan upload photo album travelingmu di sini.\n\n\t\t\t\t\t\t\t\t\t\t\tSilakan Daftar atau Masuk\n']])
    else:
        content_list.extend([p.get_text() for p in content_page.find_all("p")
                            if p.get_text() not in ['',
                                                    '[Gambas:Instagram]',
                                                    '[Gambas:Video 20detik]',
                                                    '\r\nADVERTISEMENT\r\n',
                                                    '\r\n    ADVERTISEMENT\r\n',
                                                    '\r\n    ADVERTISEMENT\r\n  ',
                                                    '\r\n   ADVERTISEMENT\r\n  ',
                                                    '\r\n   ADVERTISEMENT\r\n',
                                                    '\r\n        SCROLL TO RESUME CONTENT\r\n  ',
                                                    '\n\t\t\t\t\tAyo share cerita pengalaman dan upload photo album travelingmu di sini.\n\n\t\t\t\t\t\t\t\t\t\t\tSilakan Daftar atau Masuk\n']])

    content_list = '\n\n'.join(content_list)

    return content_list

# Fungsi untuk mengecek berita yang merupakan advertorial
def news_advertorial_check(article_url):
    response = requests.get(article_url)
    content_page = bs(response.content, "html.parser")

    author = content_page.find("meta", {"content": "Advertorial"})

    return bool(author)

# Fungsi untuk mencari artikel dengan output adalah jumlah artikel dan halaman terakhir
def search_articles(query, from_date, to_date, ads_article, article_content):
    results_num, last_page = news_search_results(query, from_date, to_date)
        
    print(f"Result num: {results_num}")
    print(f"Last page: {last_page}")

    return results_num, last_page

# Fungsi untuk memperoleh list artikel
def articles_list(query, from_date, to_date, ads_article, article_content, num_articles, last_page):
    article_lists = []
    pages = math.ceil(num_articles / 10)
    
    print("\nMemulai Scrapping dari DetikBali untuk keyword:", query)
    for i in range(1, pages + 1):
        print("Scrapping halaman", i, "dari URL: ")
        page = search_url(query, from_date, to_date, i)
        articles = page.find_all("article", class_="list-content__item")

        for article in articles:
            title = article.find("a", {"class": "media__link"}).get('dtr-ttl')
            category = article.find('h2', class_='media__subtitle').text.strip()
            publish_date = article.find('span', title=True).get('title')
            article_url = article.find("a", {"class": "media__link"}).get('href')
                
            # print(f"Title: {title}")
            # print(f"Category: {category}")
            # print(f"Publish Date: {publish_date}")
            # print(f"Article URL: {article_url}")

            if ads_article and news_advertorial_check(article_url):
                continue
            else:
                if article_content:
                    content = news_get_content(article_url)
                    if (
                        any(title in existing_article["title"] for existing_article in article_lists) or 
                        any(content in existing_article["content"] for existing_article in article_lists)
                    ):
                        continue
                    else:
                        article_lists.append({
                            "title": title,
                            "keyword": query,
                            "source": category,
                            "link": article_url,
                            "date": publish_date,
                            "content": content
                        })
                else:
                    if any(title in existing_article["title"] for existing_article in article_lists):
                        continue
                    else:
                        article_lists.append({
                            "title": title,
                            "keyword": query,
                            "link": article_url,
                            "date": publish_date
                        })
            if len(article_lists) == num_articles:
                break
        if len(article_lists) == num_articles:
            break
            
    print(f"Jumlah artikel dengan kata kunci {keyword}: {len(article_lists)} artikel.")
    data = article_lists
    return data

# %%
# Scraping untuk setiap keyword
all_news_detik = []

for keyword in keywords_scrap:
    search_keyword = keyword.replace(" ", "+")
    news = articles_list(search_keyword, start_date.strftime('%d/%m/%Y'), end_date.strftime('%d/%m/%Y'), False, True, 25, 5)
    all_news_detik.extend(news)

# Simpan hasil ke dalam file Excel
berita_detik = pd.DataFrame(all_news_detik) 
berita_detik
# Out:
# Memulai Scrapping dari DetikBali untuk keyword: pendidikan
# Scrapping halaman 1 dari URL:
# https://www.detik.com/search/searchnews?query=pendidikan&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=1&result_type=relevansi
# Scrapping halaman 2 dari URL:
# https://www.detik.com/search/searchnews?query=pendidikan&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=2&result_type=relevansi
# Scrapping halaman 3 dari URL:
# https://www.detik.com/search/searchnews?query=pendidikan&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=3&result_type=relevansi
# Jumlah artikel dengan kata kunci pendidikan: 25 artikel.
#
# Memulai Scrapping dari DetikBali untuk keyword: biaya+pendidikan
# Scrapping halaman 1 dari URL:
# https://www.detik.com/search/searchnews?query=biaya+pendidikan&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=1&result_type=relevansi
# Scrapping halaman 2 dari URL:
# https://www.detik.com/search/searchnews?query=biaya+pendidikan&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=2&result_type=relevansi
# Scrapping halaman 3 dari URL:
# https://www.detik.com/search/searchnews?query=biaya+pendidikan&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=3&result_type=relevansi
# Jumlah artikel dengan kata kunci biaya pendidikan: 25 artikel.
#
# Memulai Scrapping dari DetikBali untuk keyword: spp
# Scrapping halaman 1 dari URL:
# https://www.detik.com/search/searchnews?query=spp&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=1&result_type=relevansi
# Scrapping halaman 2 dari URL:
# https://www.detik.com/search/searchnews?query=spp&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=2&result_type=relevansi
# Scrapping halaman 3 dari URL:
# https://www.detik.com/search/searchnews?query=spp&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=3&result_type=relevansi
# Jumlah artikel dengan kata kunci spp: 5 artikel.
#                                                 title           keyword  \
# 0   Diar Tawarkan Pasraman Singkat untuk Pendidika...        pendidikan
# 1   George-Walde Janjikan Digitalisasi Pendidikan ...        pendidikan
# 2   Winuntara: Sistem Pendidikan Bangli Era Sedana...        pendidikan
# 3   Seluruh Sekolah di Flores Timur Harus Terima S...        pendidikan
# 4   Telkomsel Perluas Jaringan Telekomunikasi di P...        pendidikan
# 5   Guru SMP Hamili Istri Orang Diperiksa Dinas Pe...        pendidikan
# 6   Kampanye di Klungkung, Koster-Giri Janjikan Ke...        pendidikan
# 7   Disdikpora Denpasar Siap Ajarkan Mata Pelajara...        pendidikan
# 8   Bangun Nasionalisme Anak Muda, Subrata Ingatka...        pendidikan
# 9   Sugawa Akan Kaji Hak Atas Potensi Gas Bumi Blo...        pendidikan
# 10  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...        pendidikan
# 11   KPU NTB Siapkan 25 TPS Khusus untuk Pilkada 2024        pendidikan
# 12  Jelang Pilkada Serentak 2024, Pulau Sumbawa Pa...        pendidikan
# 13  Profil Merry Riana: Penulis Mimpi Sejuta Dolar...        pendidikan
# 14  Raden Cahyo Tawarkan Program Pendidikan Gratis...        pendidikan
# 15  Cawabup Irfan Soroti Jalan Rusak-Sarana Pendid...        pendidikan
# 16  Bang-Ipat Akan Naikkan Beasiswa, 1 Keluarga 1 ...        pendidikan
# 17  Sugawa Akan Libatkan Ahli untuk Grand Design S...        pendidikan
# 18  Paparkan Visi NTB Maju Berdaya Saing, Rohmi-Fi...        pendidikan
# 19  Kesiapan Bali Jelang Program Makan Bergizi Gratis        pendidikan
# 20  Pemprov Bali Siap Bantu Anggaran Program Makan...        pendidikan
# 21  Kari Subali Titip Pendukungnya jika Gagal Jadi...        pendidikan
# 22  Nyoman Parta Sebut Penghapusan UN Bikin Semang...        pendidikan
# 23  Pemprov NTT Kirim Bahan Makanan-Obat untuk Kor...        pendidikan
# 24  Siswa Korban Erupsi Gunung Lewotobi Butuh Bant...        pendidikan
# 25  Telkomsel Perluas Jaringan Telekomunikasi di P...  biaya+pendidikan
# 26  Seluruh Sekolah di Flores Timur Harus Terima S...  biaya+pendidikan
# 27  Diar Tawarkan Pasraman Singkat untuk Pendidika...  biaya+pendidikan
# 28  11.026 Pendaftar PPPK 2024 di Bima Dinyatakan ...  biaya+pendidikan
# 29  Profil Merry Riana: Penulis Mimpi Sejuta Dolar...  biaya+pendidikan
# 30  Sugawa Akan Kaji Hak Atas Potensi Gas Bumi Blo...  biaya+pendidikan
# Filter Wilayah
keywords_filter = ["Tabanan","Singaraja","Denpasar","Badung","Karangasem","Klungkung","Jembrana","Gianyar","Bangli"]

# Build the condition for multiple keywords
pattern = '|'.join(keywords_filter)  # Create a pattern that matches any of the keywords

# Filter out rows where 'Description' contains the keyword
berita_detik_2 = pd.DataFrame(berita_detik[berita_detik['content'].str.contains(pattern, case=False, na=False)])

# Show the filtered DataFrame
print(berita_detik_2.shape)
berita_detik_2
# Out:
# (27, 6)
#                                                 title           keyword  \
# 0   Diar Tawarkan Pasraman Singkat untuk Pendidika...        pendidikan
# 2   Winuntara: Sistem Pendidikan Bangli Era Sedana...        pendidikan
# 6   Kampanye di Klungkung, Koster-Giri Janjikan Ke...        pendidikan
# 7   Disdikpora Denpasar Siap Ajarkan Mata Pelajara...        pendidikan
# 8   Bangun Nasionalisme Anak Muda, Subrata Ingatka...        pendidikan
# 10  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...        pendidikan
# 14  Raden Cahyo Tawarkan Program Pendidikan Gratis...        pendidikan
# 16  Bang-Ipat Akan Naikkan Beasiswa, 1 Keluarga 1 ...        pendidikan
# 17  Sugawa Akan Libatkan Ahli untuk Grand Design S...        pendidikan
# 19  Kesiapan Bali Jelang Program Makan Bergizi Gratis        pendidikan
# 21  Kari Subali Titip Pendukungnya jika Gagal Jadi...        pendidikan
# 22  Nyoman Parta Sebut Penghapusan UN Bikin Semang...        pendidikan
# 27  Diar Tawarkan Pasraman Singkat untuk Pendidika...  biaya+pendidikan
# 32  Disdikpora Denpasar Siap Ajarkan Mata Pelajara...  biaya+pendidikan
# 33  Winuntara: Sistem Pendidikan Bangli Era Sedana...  biaya+pendidikan
# 34  DPRD Badung Dorong Penanganan Lampu Jalan Kerj...  biaya+pendidikan
# 38  Koster Klaim Turyapada Tower Hasilkan Rp 100 M...  biaya+pendidikan
# 39  Beragam Janji Koster-Giri untuk Tingkatkan Kua...  biaya+pendidikan
# 41  Kampanye di Klungkung, Koster-Giri Janjikan Ke...  biaya+pendidikan
# 42  Mulia-PAS Soroti Kasus Bunuh Diri Bali Terting...  biaya+pendidikan
# 44  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...  biaya+pendidikan
# 45  Kesiapan Bali Jelang Program Makan Bergizi Gratis  biaya+pendidikan
# 47  Kari Subali Titip Pendukungnya jika Gagal Jadi...  biaya+pendidikan
# 48  Raden Cahyo Tawarkan Program Pendidikan Gratis...  biaya+pendidikan
# 51  PAS Janji Bangun Rumah Sakit di Kecamatan Gero...               spp
# 52  Kepsek SMKN 1 Klungkung Bantah Kuasai Uang Rat...               spp
# 53  5 Terdakwa Korupsi PNPM di Tabanan Terancam 15...               spp
#
#        source                                               link  \
# 0   detikBali  https://www.detik.com/bali/pilkada/d-7624095/d...
# 2   detikBali  https://www.detik.com/bali/pilkada/d-7624133/w...
# 6   detikBali  https://www.detik.com/bali/pilkada/d-7576263/k...
# 7   detikBali  https://www.detik.com/bali/berita/d-7634612/di...
# 8   detikBali  https://www.detik.com/bali/pilkada/d-7624142/b...
# 10  detikBali  https://www.detik.com/bali/pilkada/d-7607924/t...
# 14  detikBali  https://www.detik.com/bali/pilkada/d-7604982/r...
# 7   Dinas Pendidikan, Kepemudaan dan Olahraga (Dis...
# 8   Calon wakil bupati (cawabup) Bangli nomor urut...
# 10  Pasangan calon (paslon) nomor urut 1, I Nengah...
# 14  Calon bupati Bangli nomor urut 1, Raden Cahyo ...
# 16  Pasangan calon (paslon) bupati dan wakil bupat...
# 17  Calon bupati (cabup) Buleleng nomor urut 1, Ny...
# 19  Pemerintah daerah (pemda) di Bali telah memper...
# 21  Momen sesi tanya jawab antar pasangan calon (p...
# 22  Wacana penerapan kembali Ujian Nasional (UN) s...
# 27  Calon wakil bupati (cawabup) Bangli nomor urut...
# 32  Dinas Pendidikan, Kepemudaan dan Olahraga (Dis...
# 33  Calon wakil bupati (cawabup) Bangli nomor urut...
# 34  Ketua DPRD Badung I Gusti Anom Gumanti mengata...
# 38  Pasangan calon (paslon) nomor urut 2 Wayan Kos...
# 39  Pasangan calon (paslon) nomor urut 2 Wayan Kos...
# 41  Calon gubernur dan wakil gubernur Bali nomor u...
# 42  Pasangan calon (paslon) nomor urut 1 Made Muli...
# 44  Pasangan calon (paslon) nomor urut 1, I Nengah...
# 45  Pemerintah daerah (pemda) di Bali telah memper...
# 47  Momen sesi tanya jawab antar pasangan calon (p...
# 48  Calon bupati Bangli nomor urut 1, Raden Cahyo ...
# 51  Pasangan calon (paslon) gubernur dan wakil gub...
# 52  Kepala Sekolah Menengah Kejuruan Negeri (SMKN)...
# 53  I Ketut Suwena (69), Anak Agung Ngurah Anom Wi...

# %%
# Build the regular expression pattern with word boundaries
pattern = r'\b(' + '|'.join(keywords_scrap) + r')\b'

# Filter rows where 'Title' contains the keyword as a whole word (case insensitive)
berita_detik_3 = berita_detik_2[berita_detik_2['title'].str.contains(pattern, case=False, na=False)]

# Show the filtered DataFrame
print(berita_detik_3.shape)
berita_detik_3
# Out:
# (11, 6)
# C:\Users\asus\AppData\Local\Temp\ipykernel_21016\1307647291.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   berita_detik_3 = berita_detik_2[berita_detik_2['title'].str.contains(pattern, case=False, na=False)]
#                                                 title           keyword  \
# 0   Diar Tawarkan Pasraman Singkat untuk Pendidika...        pendidikan
# 2   Winuntara: Sistem Pendidikan Bangli Era Sedana...        pendidikan
# 6   Kampanye di Klungkung, Koster-Giri Janjikan Ke...        pendidikan
# 10  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...        pendidikan
# 14  Raden Cahyo Tawarkan Program Pendidikan Gratis...        pendidikan
# 17  Sugawa Akan Libatkan Ahli untuk Grand Design S...        pendidikan
# 27  Diar Tawarkan Pasraman Singkat untuk Pendidika...  biaya+pendidikan
# 33  Winuntara: Sistem Pendidikan Bangli Era Sedana...  biaya+pendidikan
# 41  Kampanye di Klungkung, Koster-Giri Janjikan Ke...  biaya+pendidikan
# 44  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...  biaya+pendidikan
# 48  Raden Cahyo Tawarkan Program Pendidikan Gratis...  biaya+pendidikan
#
#        source                                               link  \
# 0   detikBali  https://www.detik.com/bali/pilkada/d-7624095/d...
# 2   detikBali  https://www.detik.com/bali/pilkada/d-7624133/w...
# 6   detikBali  https://www.detik.com/bali/pilkada/d-7576263/k...
# 10  detikBali  https://www.detik.com/bali/pilkada/d-7607924/t...
# 10   Sabtu, 26 Okt 2024 19:35 WIB
# 14   Kamis, 24 Okt 2024 19:14 WIB
# 17    Rabu, 23 Okt 2024 21:29 WIB
#
#                                               content
# 0   Calon wakil bupati (cawabup) Bangli nomor urut...
# 2   Calon wakil bupati (cawabup) Bangli nomor urut...
# 6   Calon gubernur dan wakil gubernur Bali nomor u...
# 10  Pasangan calon (paslon) nomor urut 1, I Nengah...
# 14  Calon bupati Bangli nomor urut 1, Raden Cahyo ...
# 17  Calon bupati (cabup) Buleleng nomor urut 1, Ny...

# %% [markdown]
# ## 3. RadarBali

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
from datetime import datetime

# Tanggal batas yang ingin dibandingkan
start_date = datetime(2024, 10, 1)  # 1 Oktober 2024
end_date = datetime(2024, 12, 31)  # 31 Desember 2024

# Inisialisasi driver Chrome tanpa mengunduh chromedriver secara manual
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)
# Fungsi untuk melakukan scraping dan mengambil isian kelas latest__subtitle, latest__link, dan latest__date
def get_news(query, start_page, end_page):
    results = []

    print("\nMemulai scrapping RadarBali untuk keyword:", query)
    for page in range(start_page, end_page + 1):
        url = f"https://radarbali.jawapos.com/search?q={query}&sort=latest&page={page}"
        print("Scrapping halaman",page,"dari URL:",url)
        driver.get(url)
        time.sleep(10)  # Tunggu beberapa detik agar halaman selesai dimuat

        # Ambil konten halaman dan buat objek BeautifulSoup
        soup = BeautifulSoup(driver.page_source, "html.parser")

        # Ambil semua elemen dengan class latest__item
        articles = soup.find_all('div', class_='latest__item')

        # Ambil informasi dari setiap artikel
        for article in articles:
            subtitle = article.find('h4', class_='latest__subtitle')
            title = article.find('a', class_='latest__link')
            link = article.find('a', class_='latest__link')['href']
            date = article.find('date', class_='latest__date')

            # Menampilkan hasil jika elemen ditemukan, filter tanggal sesuai yang diinginkan
            if subtitle and title and date:
                date_berita = date.get_text(strip=True)

                # Fungsi untuk mengonversi nama bulan menjadi angka bulan
                def get_month_number(month_name):
                    months = {
                        "Januari": 1,
                        "Februari": 2,
                        "Maret": 3,
                        "April": 4,
                        "Mei": 5,
                        "Juni": 6,
                        "Juli": 7,
                        "Agustus": 8,
                        "September": 9,
                        "Oktober": 10,
                        "November": 11,
                        "Desember": 12
                    }
                    return months.get(month_name)

                # Fungsi untuk mem-parsing tanggal dalam format yang diberikan
                def parse_date(date_str):
                    # Pisahkan hari dan waktu
                    day_part, time_part = date_str.split(" | ")

                    # Ambil tanggal dan bulan dari bagian day_part
                    day_name, day, month_name, year = day_part.split()
                    day = int(day)
                    year = int(year)
                    month = get_month_number(month_name)
                    
                    # Gabungkan menjadi format yang bisa diproses oleh datetime
                    # Format waktu seperti '21:46 WIB', jadi kita hanya perlu ambil jam dan menit
                    time = time_part.replace(" WIB", "")

                    # Gabungkan semuanya ke format yang sesuai dengan datetime
                    date_string = f"{year}-{month:02d}-{day:02d} {time}"

                    # Mengonversi ke objek datetime
                    return datetime.strptime(date_string, "%Y-%m-%d %H:%M")
            
                parsed_date = parse_date(date_berita)

                # Membandingkan apakah parsed_date berada dalam rentang 1 Oktober 2024 sampai 31 Desember 2024
                if start_date <= parsed_date <= end_date:
                    results.append({"title": title.get_text(strip=True), "keyword": query, "source": "RadarBali", "link": link, "date": date.get_text(strip=True), "content": subtitle.get_text(strip=True)})
                    # print("Subtitle:", subtitle.get_text(strip=True))
                    # print("Title:", title.get_text(strip=True))
                    # print("Link:", link)
                    # print("Date:", date.get_text(strip=True))
                    # print('-' * 80)
                else:
                    break

    return results

import pandas as pd

all_news_radarbali = []

for keyword in keywords_scrap:
    search_keyword = keyword.replace(" ", "+")
    news = get_news(search_keyword, start_page=1, end_page=5)

    # Tampilkan jumlah artikel yang berhasil diekstrak untuk keyword ini
    num_articles = len(news)
    print(f"Jumlah artikel yang diekstrak untuk keyword '{keyword}': {num_articles}")

    all_news_radarbali.extend(news)

driver.quit()
# Out:
# Memulai scrapping RadarBali untuk keyword: pendidikan
# Scrapping halaman 1 dari URL: https://radarbali.jawapos.com/search?q=pendidikan&sort=latest&page=1
# Scrapping halaman 2 dari URL: https://radarbali.jawapos.com/search?q=pendidikan&sort=latest&page=2
# Scrapping halaman 3 dari URL: https://radarbali.jawapos.com/search?q=pendidikan&sort=latest&page=3
# Scrapping halaman 4 dari URL: https://radarbali.jawapos.com/search?q=pendidikan&sort=latest&page=4
# Scrapping halaman 5 dari URL: https://radarbali.jawapos.com/search?q=pendidikan&sort=latest&page=5
# Jumlah artikel yang diekstrak untuk keyword 'pendidikan': 27
#
# Memulai scrapping RadarBali untuk keyword: biaya+pendidikan
# Scrapping halaman 1 dari URL: https://radarbali.jawapos.com/search?q=biaya+pendidikan&sort=latest&page=1
# Scrapping halaman 2 dari URL: https://radarbali.jawapos.com/search?q=biaya+pendidikan&sort=latest&page=2
# Scrapping halaman 3 dari URL: https://radarbali.jawapos.com/search?q=biaya+pendidikan&sort=latest&page=3
# Scrapping halaman 4 dari URL: https://radarbali.jawapos.com/search?q=biaya+pendidikan&sort=latest&page=4
# Scrapping halaman 5 dari URL: https://radarbali.jawapos.com/search?q=biaya+pendidikan&sort=latest&page=5
# Jumlah artikel yang diekstrak untuk keyword 'biaya pendidikan': 29
#
# Memulai scrapping RadarBali untuk keyword: spp
# Scrapping halaman 1 dari URL: https://radarbali.jawapos.com/search?q=spp&sort=latest&page=1
# Scrapping halaman 2 dari URL: https://radarbali.jawapos.com/search?q=spp&sort=latest&page=2
# Scrapping halaman 3 dari URL: https://radarbali.jawapos.com/search?q=spp&sort=latest&page=3
# Scrapping halaman 4 dari URL: https://radarbali.jawapos.com/search?q=spp&sort=latest&page=4
# Scrapping halaman 5 dari URL: https://radarbali.jawapos.com/search?q=spp&sort=latest&page=5
# Jumlah artikel yang diekstrak untuk keyword 'spp': 0

# %%
berita_radarbali = pd.DataFrame(all_news_radarbali)
berita_radarbali
# Out:
#                                                 title           keyword  \
# 0   Disdikpora Jembrana Kaji Larangan Liburan Kelu...        pendidikan
# 1   Kuatkan Ekosistem Digital untuk Pendidikan Ber...        pendidikan
# 2   Teken Nota Kesepahaman, KEK Kura Kura Bali – U...        pendidikan
# 3   Pro Kontra Guru Cukur Rambut Murid, Ini Pandan...        pendidikan
# Filter rows where 'Title' contains the keyword as a whole word (case insensitive)
berita_radarbali_3 = berita_radarbali_2.copy()
berita_radarbali_3 = berita_radarbali_2[berita_radarbali_2['title'].str.contains(pattern, case=False, na=False)]

# Show the filtered DataFrame
print(berita_radarbali_3.shape)
berita_radarbali_3
# Out:
# (14, 6)
# C:\Users\asus\AppData\Local\Temp\ipykernel_21016\2112746010.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   berita_radarbali_3 = berita_radarbali_2[berita_radarbali_2['title'].str.contains(pattern, case=False, na=False)]
#                                                 title     keyword     source  \
# 1   Kuatkan Ekosistem Digital untuk Pendidikan Ber...  pendidikan  RadarBali
# 3   Pro Kontra Guru Cukur Rambut Murid, Ini Pandan...  pendidikan  RadarBali
# 5   Wajib Tahu! Ini Lima Program Jitu Pendidikan y...  pendidikan  RadarBali
# 9   Tingkatkan Pendidikan, Gus Par-Pandu Cetak Sat...  pendidikan  RadarBali
# 10  Miles for Smiles’ Charity Fun Run, Mamaka by O...  pendidikan  RadarBali
# 11  Telkomsel Lebih Dekat dengan Gen Z melalui by....  pendidikan  RadarBali
# 15  Suyadinata Disambut Antusias di Banjar Adat Be...  pendidikan  RadarBali
# 16  Koster-Giri akan Bangun Sports Center Bali di ...  pendidikan  RadarBali
# 18  Buntut Konflik Dua Yayasan Pendidikan di Taban...  pendidikan  RadarBali
# 19  Badung Education Fair 2024, Pj. Sekda Badung: ...  pendidikan  RadarBali
# 20  Kisah Aksi Heroik Joni, Si Pemanjat Tiang Bend...  pendidikan  RadarBali
# 22  Astra Daihatsu Motor Donasikan Mobil Perpustak...  pendidikan  RadarBali
# 23  Redea Institute: Nama Baru HighScope Indonesia...  pendidikan  RadarBali
# 24  Rektor Undiksha Kunjungi Shunan University dan...  pendidikan  RadarBali
#
#                                                  link  \
# 1   https://radarbali.jawapos.com/teknologi/705292...
# 3   https://radarbali.jawapos.com/pendidikan/70528...
# 5   https://radarbali.jawapos.com/politika/7052776...
# 9   https://radarbali.jawapos.com/politika/7052434...
# 10  https://radarbali.jawapos.com/berita-daerah/70...
# 11  https://radarbali.jawapos.com/gaya-hidup/70523...
# 15  https://radarbali.jawapos.com/politika/7052134...
# 16  https://radarbali.jawapos.com/politika/7051949...
# 18  https://radarbali.jawapos.com/tabanan/70518197...
# 19  https://radarbali.jawapos.com/badung/705174324...
# 20  https://radarbali.jawapos.com/peristiwa/705168...
# 22  https://radarbali.jawapos.com/otomotif/7051610...
# 23  https://radarbali.jawapos.com/pendidikan/70516...
# 24  https://radarbali.jawapos.com/pendidikan/70515...
#
#                                    date        content
# 1    Sabtu, 9 November 2024 | 09:20 WIB      Teknologi
# 3    Kamis, 7 November 2024 | 20:53 WIB     Pendidikan
# 5   Selasa, 5 November 2024 | 14:21 WIB       Politika
# 9   Minggu, 27 Oktober 2024 | 16:39 WIB       Politika
# 10  Minggu, 27 Oktober 2024 | 08:37 WIB  Berita Daerah
# 11   Kamis, 24 Oktober 2024 | 17:49 WIB     Gaya Hidup
# 15   Sabtu, 19 Oktober 2024 | 07:42 WIB       Politika
# 16   Senin, 14 Oktober 2024 | 15:00 WIB       Politika
# 18   Kamis, 10 Oktober 2024 | 18:05 WIB        Tabanan
# 19   Selasa, 8 Oktober 2024 | 17:50 WIB         Badung
# 20    Senin, 7 Oktober 2024 | 10:50 WIB      Peristiwa
# 22    Jumat, 4 Oktober 2024 | 16:28 WIB       Otomotif
# 23    Jumat, 4 Oktober 2024 | 14:10 WIB     Pendidikan
# 24    Kamis, 3 Oktober 2024 | 09:52 WIB     Pendidikan

# %%
berita_radarbali_4 = berita_radarbali_3.copy()

# Nilai yang ingin kita hapus
values_to_remove = ['Sportmania','Foto Mania','Berita Daerah']
columns_to_check = ['content']

# Hapus baris yang memiliki nilai tersebut di sembarang kolom
berita_radarbali_4 = berita_radarbali_4[~berita_radarbali_4[columns_to_check].apply(lambda row: row.isin(values_to_remove).any(), axis=1)]
print(berita_radarbali_4.shape)
berita_radarbali_4
# Out:
# (13, 6)
#                                                 title     keyword     source  \
# 1   Kuatkan Ekosistem Digital untuk Pendidikan Ber...  pendidikan  RadarBali
# 3   Pro Kontra Guru Cukur Rambut Murid, Ini Pandan...  pendidikan  RadarBali
# 5   Wajib Tahu! Ini Lima Program Jitu Pendidikan y...  pendidikan  RadarBali
# 9   Tingkatkan Pendidikan, Gus Par-Pandu Cetak Sat...  pendidikan  RadarBali
# 11  Telkomsel Lebih Dekat dengan Gen Z melalui by....  pendidikan  RadarBali
# 15  Suyadinata Disambut Antusias di Banjar Adat Be...  pendidikan  RadarBali
# 16  Koster-Giri akan Bangun Sports Center Bali di ...  pendidikan  RadarBali
# 18  Buntut Konflik Dua Yayasan Pendidikan di Taban...  pendidikan  RadarBali
# 19  Badung Education Fair 2024, Pj. Sekda Badung: ...  pendidikan  RadarBali
# 20  Kisah Aksi Heroik Joni, Si Pemanjat Tiang Bend...  pendidikan  RadarBali
# 22  Astra Daihatsu Motor Donasikan Mobil Perpustak...  pendidikan  RadarBali
# 23  Redea Institute: Nama Baru HighScope Indonesia...  pendidikan  RadarBali
# 24  Rektor Undiksha Kunjungi Shunan University dan...  pendidikan  RadarBali
#
#                                                  link  \
# 1   https://radarbali.jawapos.com/teknologi/705292...
# 3   https://radarbali.jawapos.com/pendidikan/70528...
# 5   https://radarbali.jawapos.com/politika/7052776...
# 9   https://radarbali.jawapos.com/politika/7052434...
# 11  https://radarbali.jawapos.com/gaya-hidup/70523...
# 15  https://radarbali.jawapos.com/politika/7052134...
# 16  https://radarbali.jawapos.com/politika/7051949...
# 18  https://radarbali.jawapos.com/tabanan/70518197...
# 19  https://radarbali.jawapos.com/badung/705174324...
# 20  https://radarbali.jawapos.com/peristiwa/705168...
# 22  https://radarbali.jawapos.com/otomotif/7051610...
# 23  https://radarbali.jawapos.com/pendidikan/70516...
# 24  https://radarbali.jawapos.com/pendidikan/70515...
#
#                                    date     content
# 1    Sabtu, 9 November 2024 | 09:20 WIB   Teknologi
# 3    Kamis, 7 November 2024 | 20:53 WIB  Pendidikan
# 5   Selasa, 5 November 2024 | 14:21 WIB    Politika
# 9   Minggu, 27 Oktober 2024 | 16:39 WIB    Politika
# 11   Kamis, 24 Oktober 2024 | 17:49 WIB  Gaya Hidup
# 15   Sabtu, 19 Oktober 2024 | 07:42 WIB    Politika
# 16   Senin, 14 Oktober 2024 | 15:00 WIB    Politika
# 18   Kamis, 10 Oktober 2024 | 18:05 WIB     Tabanan
# 19   Selasa, 8 Oktober 2024 | 17:50 WIB      Badung
# 20    Senin, 7 Oktober 2024 | 10:50 WIB   Peristiwa
# 22    Jumat, 4 Oktober 2024 | 16:28 WIB    Otomotif
# 23    Jumat, 4 Oktober 2024 | 14:10 WIB  Pendidikan
# 24    Kamis, 3 Oktober 2024 | 09:52 WIB  Pendidikan

# %% [markdown]
# ## Export All (Combined)

# %% [markdown]
# ### Raw Data Hasil Scrapping

# %%
# # Import melalui kode ini kalau sudah ada raw data scrapping BaliPost yang terpisah dari proses scrapping diatas (hanya untuk BaliPost)
# berita_balipost = pd.read_excel("C:/Users/asus/OneDrive/BPS/Neraca/berita_sektor15_triwulan4_bali.xlsx")

# %%
# berita_balipost.head()

# %%
berita_detik.head()
# Out:
#                                                title     keyword     source  \
# 0  Diar Tawarkan Pasraman Singkat untuk Pendidika...  pendidikan  detikBali
# 1  George-Walde Janjikan Digitalisasi Pendidikan ...  pendidikan  detikBali
# 2  Winuntara: Sistem Pendidikan Bangli Era Sedana...  pendidikan  detikBali
# 3  Seluruh Sekolah di Flores Timur Harus Terima S...  pendidikan  detikBali
# 4  Telkomsel Perluas Jaringan Telekomunikasi di P...  pendidikan  detikBali
#
#                                                 link  \
# 0  https://www.detik.com/bali/pilkada/d-7624095/d...
# 1  https://www.detik.com/bali/pilkada/d-7619320/g...
# 2  https://www.detik.com/bali/pilkada/d-7624133/w...
# 3  https://www.detik.com/bali/nusra/d-7635203/sel...
# 4  https://www.detik.com/bali/bisnis/d-7635597/te...
#
#                             date  \
# 0  Selasa, 05 Nov 2024 19:49 WIB
# 1   Sabtu, 02 Nov 2024 20:44 WIB
# 2  Selasa, 05 Nov 2024 20:29 WIB
# 3  Selasa, 12 Nov 2024 18:06 WIB
# 4  Selasa, 12 Nov 2024 23:45 WIB
#
#                                              content
# 0  Calon wakil bupati (cawabup) Bangli nomor urut...
# 1  Calon wali kota (cawalkot) Kupang nomor urut 3...
# 2  Calon wakil bupati (cawabup) Bangli nomor urut...
# 3  Pemerintah Flores Timur memastikan anak-anak p...
# 4  Telkomsel kembali perluas jaringan telekomunik...

# %%
berita_radarbali.head()
# Out:
#                                                title     keyword     source  \
# 0  Disdikpora Jembrana Kaji Larangan Liburan Kelu...  pendidikan  RadarBali
# 1  Kuatkan Ekosistem Digital untuk Pendidikan Ber...  pendidikan  RadarBali
# 2  Teken Nota Kesepahaman, KEK Kura Kura Bali – U...  pendidikan  RadarBali
# 3  Pro Kontra Guru Cukur Rambut Murid, Ini Pandan...  pendidikan  RadarBali
# 4  Koster-Giri Hadiri Uji Publik didepan 1300 Mah...  pendidikan  RadarBali
#
#                                                 link  \
# 0  https://radarbali.jawapos.com/jembrana/7053107...
# 1  https://radarbali.jawapos.com/teknologi/705292...
# 2  https://radarbali.jawapos.com/pariwisata/70528...
# 3  https://radarbali.jawapos.com/pendidikan/70528...
# 4  https://radarbali.jawapos.com/politika/7052833...
#
#                                   date     content
# 0  Kamis, 14 November 2024 | 12:35 WIB    Jembrana
# 1   Sabtu, 9 November 2024 | 09:20 WIB   Teknologi
# 2   Jumat, 8 November 2024 | 06:43 WIB  Pariwisata
# 3   Kamis, 7 November 2024 | 20:53 WIB  Pendidikan
# 4    Rabu, 6 November 2024 | 20:19 WIB    Politika

# %%
# Tambahkan berita_balipost pada pd_concat jika data scrapping bali post tersedia
raw_data_combined = pd.concat([berita_detik, berita_radarbali], ignore_index=True) # Hilangkan berita_balipost jika tidak ada hasil scrapping dari BaliPost
# raw_data_combined = raw_data_combined.drop('Unnamed: 0', axis=1)
raw_data_combined
# Out:
#                                                  title           keyword  \
# 0    Diar Tawarkan Pasraman Singkat untuk Pendidika...        pendidikan
# 1    George-Walde Janjikan Digitalisasi Pendidikan ...        pendidikan
# 2    Winuntara: Sistem Pendidikan Bangli Era Sedana...        pendidikan
# 3    Seluruh Sekolah di Flores Timur Harus Terima S...        pendidikan
# 4    Telkomsel Perluas Jaringan Telekomunikasi di P...        pendidikan
# ..                                                 ...               ...
# 106  Astra Daihatsu Motor Donasikan Mobil Perpustak...  biaya+pendidikan
# 107  Redea Institute: Nama Baru HighScope Indonesia...  biaya+pendidikan
# 108  Rektor Undiksha Kunjungi Shunan University dan...  biaya+pendidikan
# 109  Pertemuan Bersama Dubes RI untuk Jepang, Rekto...  biaya+pendidikan
# 110  Koster-Giri, Kolaborasi Pemimpin Visioner dan ...  biaya+pendidikan
#
#         source                                               link  \
# 0    detikBali  https://www.detik.com/bali/pilkada/d-7624095/d...
# 1    detikBali  https://www.detik.com/bali/pilkada/d-7619320/g...
# 2    detikBali  https://www.detik.com/bali/pilkada/d-7624133/w...
# 3    detikBali  https://www.detik.com/bali/nusra/d-7635203/sel...
# 4    detikBali  https://www.detik.com/bali/bisnis/d-7635597/te...
# ..         ...                                                ...
# 106  RadarBali  https://radarbali.jawapos.com/otomotif/7051610...
# 107  RadarBali  https://radarbali.jawapos.com/pendidikan/70516...
# 108  RadarBali  https://radarbali.jawapos.com/pendidikan/70515...
# 109  RadarBali  https://radarbali.jawapos.com/pendidikan/70515...
# 110  RadarBali  https://radarbali.jawapos.com/politika/7051548...
#
#                                   date  \
# 0        Selasa, 05 Nov 2024 19:49 WIB
# 1         Sabtu, 02 Nov 2024 20:44 WIB
# 2        Selasa, 05 Nov 2024 20:29 WIB
# 3        Selasa, 12 Nov 2024 18:06 WIB
# 4        Selasa, 12 Nov 2024 23:45 WIB
# ..                                 ...
# 106  Jumat, 4 Oktober 2024 | 16:28 WIB
# 107  Jumat, 4 Oktober 2024 | 14:10 WIB
# 108  Kamis, 3 Oktober 2024 | 09:52 WIB
# 109  Kamis, 3 Oktober 2024 | 09:50 WIB
# 110  Kamis, 3 Oktober 2024 | 03:51 WIB
#
#                                                content
# 0    Calon wakil bupati (cawabup) Bangli nomor urut...
# 1    Calon wali kota (cawalkot) Kupang nomor urut 3...
# 2    Calon wakil bupati (cawabup) Bangli nomor urut...
# 3    Pemerintah Flores Timur memastikan anak-anak p...
# 4    Telkomsel kembali perluas jaringan telekomunik...
# ..                                                 ...
# 106                                           Otomotif
# 107                                         Pendidikan
# 108                                         Pendidikan
# 109                                         Pendidikan
# 110                                           Politika
#
# [111 rows x 6 columns]

# %%
raw_data_combined.to_excel("C:/Users/asus/OneDrive/BPS/Neraca/beritaraw_combined_sektor15_2024_triwulan4_bali.xlsx")

# %% [markdown]
# ### Clean Data

# %%
# print(berita_balipost_3.shape)
# berita_balipost_3.head()

# %%
print(berita_detik_4.shape)
berita_detik_4.head()
# Out:
# (6, 6)
#                                                 title     keyword     source  \
# 0   Diar Tawarkan Pasraman Singkat untuk Pendidika...  pendidikan  detikBali
# 2   Winuntara: Sistem Pendidikan Bangli Era Sedana...  pendidikan  detikBali
# 6   Kampanye di Klungkung, Koster-Giri Janjikan Ke...  pendidikan  detikBali
# 10  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...  pendidikan  detikBali
# 14  Raden Cahyo Tawarkan Program Pendidikan Gratis...  pendidikan  detikBali
#
#                                                  link  \
# 0   https://www.detik.com/bali/pilkada/d-7624095/d...
# 2   https://www.detik.com/bali/pilkada/d-7624133/w...
# 6   https://www.detik.com/bali/pilkada/d-7576263/k...
# 10  https://www.detik.com/bali/pilkada/d-7607924/t...
# 14  https://www.detik.com/bali/pilkada/d-7604982/r...
#
#                              date  \
# 0   Selasa, 05 Nov 2024 19:49 WIB
# 2   Selasa, 05 Nov 2024 20:29 WIB
# 6    Senin, 07 Okt 2024 15:31 WIB
# 10   Sabtu, 26 Okt 2024 19:35 WIB
# 14   Kamis, 24 Okt 2024 19:14 WIB
#
#                                               content
# 0   Calon wakil bupati (cawabup) Bangli nomor urut...
# 2   Calon wakil bupati (cawabup) Bangli nomor urut...
# 6   Calon gubernur dan wakil gubernur Bali nomor u...
# 10  Pasangan calon (paslon) nomor urut 1, I Nengah...
# 14  Calon bupati Bangli nomor urut 1, Raden Cahyo ...

# %%
print(berita_radarbali_4.shape)
berita_radarbali_4.head()
# Out:
# (13, 6)
#                                                 title     keyword     source  \
# 1   Kuatkan Ekosistem Digital untuk Pendidikan Ber...  pendidikan  RadarBali
# 3   Pro Kontra Guru Cukur Rambut Murid, Ini Pandan...  pendidikan  RadarBali
# 5   Wajib Tahu! Ini Lima Program Jitu Pendidikan y...  pendidikan  RadarBali
# 9   Tingkatkan Pendidikan, Gus Par-Pandu Cetak Sat...  pendidikan  RadarBali
# 11  Telkomsel Lebih Dekat dengan Gen Z melalui by....  pendidikan  RadarBali
#
#                                                  link  \
# 1   https://radarbali.jawapos.com/teknologi/705292...
# 3   https://radarbali.jawapos.com/pendidikan/70528...
# 5   https://radarbali.jawapos.com/politika/7052776...
# 9   https://radarbali.jawapos.com/politika/7052434...
# 11  https://radarbali.jawapos.com/gaya-hidup/70523...
#
#                                    date     content
# 1    Sabtu, 9 November 2024 | 09:20 WIB   Teknologi
# 3    Kamis, 7 November 2024 | 20:53 WIB  Pendidikan
# 5   Selasa, 5 November 2024 | 14:21 WIB    Politika
# 9   Minggu, 27 Oktober 2024 | 16:39 WIB    Politika
# 11   Kamis, 24 Oktober 2024 | 17:49 WIB  Gaya Hidup

# %%
# Tambahkan berita_balipost_3 pada pd_concat jika data scrapping bali post tersedia
clean_data_combined = pd.concat([berita_detik_4, berita_radarbali_4], ignore_index=True)
# clean_data_combined = clean_data_combined.drop('Unnamed: 0', axis=1)
clean_data_combined
# Out:
#                                                 title     keyword     source  \
# 0   Diar Tawarkan Pasraman Singkat untuk Pendidika...  pendidikan  detikBali
# 1   Winuntara: Sistem Pendidikan Bangli Era Sedana...  pendidikan  detikBali
# 2   Kampanye di Klungkung, Koster-Giri Janjikan Ke...  pendidikan  detikBali
# 3   Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...  pendidikan  detikBali
# 4   Raden Cahyo Tawarkan Program Pendidikan Gratis...  pendidikan  detikBali
# 5   Sugawa Akan Libatkan Ahli untuk Grand Design S...  pendidikan  detikBali
# 6   Kuatkan Ekosistem Digital untuk Pendidikan Ber...  pendidikan  RadarBali
# 7   Pro Kontra Guru Cukur Rambut Murid, Ini Pandan...  pendidikan  RadarBali
# 8   Wajib Tahu! Ini Lima Program Jitu Pendidikan y...  pendidikan  RadarBali
# 9   Tingkatkan Pendidikan, Gus Par-Pandu Cetak Sat...  pendidikan  RadarBali
# 10  Telkomsel Lebih Dekat dengan Gen Z melalui by....  pendidikan  RadarBali
# 11  Suyadinata Disambut Antusias di Banjar Adat Be...  pendidikan  RadarBali
# 12  Koster-Giri akan Bangun Sports Center Bali di ...  pendidikan  RadarBali
# 13  Buntut Konflik Dua Yayasan Pendidikan di Taban...  pendidikan  RadarBali
# 14  Badung Education Fair 2024, Pj. Sekda Badung: ...  pendidikan  RadarBali
# 15  Kisah Aksi Heroik Joni, Si Pemanjat Tiang Bend...  pendidikan  RadarBali
# 16  Astra Daihatsu Motor Donasikan Mobil Perpustak...  pendidikan  RadarBali
# 17  Redea Institute: Nama Baru HighScope Indonesia...  pendidikan  RadarBali
# 18  Rektor Undiksha Kunjungi Shunan University dan...  pendidikan  RadarBali
#
#                                                  link  \
# 0   https://www.detik.com/bali/pilkada/d-7624095/d...
# 1   https://www.detik.com/bali/pilkada/d-7624133/w...
# 2   https://www.detik.com/bali/pilkada/d-7576263/k...
# 3   https://www.detik.com/bali/pilkada/d-7607924/t...
# 4   https://www.detik.com/bali/pilkada/d-7604982/r...
# 5   https://www.detik.com/bali/pilkada/d-7603459/s...
# 6   https://radarbali.jawapos.com/teknologi/705292...
# 7   https://radarbali.jawapos.com/pendidikan/70528...
# 8   https://radarbali.jawapos.com/politika/7052776...
# 9   https://radarbali.jawapos.com/politika/7052434...
# 10  https://radarbali.jawapos.com/gaya-hidup/70523...
# 11  https://radarbali.jawapos.com/politika/7052134...
# 12  https://radarbali.jawapos.com/politika/7051949...
# 13  https://radarbali.jawapos.com/tabanan/70518197...
# 14  https://radarbali.jawapos.com/badung/705174324...
# 15  https://radarbali.jawapos.com/peristiwa/705168...
# 16  https://radarbali.jawapos.com/otomotif/7051610...
# 17  https://radarbali.jawapos.com/pendidikan/70516...
# 18  https://radarbali.jawapos.com/pendidikan/70515...
#
#                                    date  \
# 0         Selasa, 05 Nov 2024 19:49 WIB
# 1         Selasa, 05 Nov 2024 20:29 WIB
# 2          Senin, 07 Okt 2024 15:31 WIB
# 3          Sabtu, 26 Okt 2024 19:35 WIB
# 4          Kamis, 24 Okt 2024 19:14 WIB
# 5           Rabu, 23 Okt 2024 21:29 WIB
# 6    Sabtu, 9 November 2024 | 09:20 WIB
# 7    Kamis, 7 November 2024 | 20:53 WIB
# 8   Selasa, 5 November 2024 | 14:21 WIB
# 9   Minggu, 27 Oktober 2024 | 16:39 WIB
# 10   Kamis, 24 Oktober 2024 | 17:49 WIB
# 11   Sabtu, 19 Oktober 2024 | 07:42 WIB
# 12   Senin, 14 Oktober 2024 | 15:00 WIB
# 13   Kamis, 10 Oktober 2024 | 18:05 WIB
# 14   Selasa, 8 Oktober 2024 | 17:50 WIB
# 15    Senin, 7 Oktober 2024 | 10:50 WIB
# 16    Jumat, 4 Oktober 2024 | 16:28 WIB
# 17    Jumat, 4 Oktober 2024 | 14:10 WIB
# 18    Kamis, 3 Oktober 2024 | 09:52 WIB
#
#                                               content
# 0   Calon wakil bupati (cawabup) Bangli nomor urut...
# 1   Calon wakil bupati (cawabup) Bangli nomor urut...
# 2   Calon gubernur dan wakil gubernur Bali nomor u...
# 3   Pasangan calon (paslon) nomor urut 1, I Nengah...
# 4   Calon bupati Bangli nomor urut 1, Raden Cahyo ...
# 5   Calon bupati (cabup) Buleleng nomor urut 1, Ny...
# 6                                           Teknologi
# 7                                          Pendidikan
# 8                                            Politika
# 9                                            Politika
# 10                                         Gaya Hidup
# 11                                           Politika
# 12                                           Politika
# 13                                            Tabanan
# 14                                             Badung
# 15                                          Peristiwa
# 16                                           Otomotif
# 17                                         Pendidikan
# 18                                         Pendidikan

# %%
clean_data_combined.to_excel("C:/Users/asus/OneDrive/BPS/Neraca/beritaclean_combined_sektor15_2024_triwulan4_bali.xlsx")

# %% [markdown]
# # **SENTIMENT ANALYSIS**

# %% [markdown]
# ## Dataset Preparation

# %%
clean_data = pd.read_excel("C:/Users/asus/OneDrive/BPS/Neraca/beritaclean_combined_sektor15_2024_triwulan4_bali.xlsx")
clean_data
# Out:
#     Unnamed: 0                                              title     keyword  \
# 0            0  Diar Tawarkan Pasraman Singkat untuk Pendidika...  pendidikan
# 1            1  Winuntara: Sistem Pendidikan Bangli Era Sedana...  pendidikan
# 2            2  Kampanye di Klungkung, Koster-Giri Janjikan Ke...  pendidikan
# 3            3  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...  pendidikan
# 4            4  Raden Cahyo Tawarkan Program Pendidikan Gratis...  pendidikan
# 5            5  Sugawa Akan Libatkan Ahli untuk Grand Design S...  pendidikan
# 6            6  Kuatkan Ekosistem Digital untuk Pendidikan Ber...  pendidikan
# 7            7  Pro Kontra Guru Cukur Rambut Murid, Ini Pandan...  pendidikan
# 8            8  Wajib Tahu! Ini Lima Program Jitu Pendidikan y...  pendidikan
# 18    Kamis, 3 Oktober 2024 | 09:52 WIB
#
#                                               content
# 0   Calon wakil bupati (cawabup) Bangli nomor urut...
# 1   Calon wakil bupati (cawabup) Bangli nomor urut...
# 2   Calon gubernur dan wakil gubernur Bali nomor u...
# 3   Pasangan calon (paslon) nomor urut 1, I Nengah...
# 4   Calon bupati Bangli nomor urut 1, Raden Cahyo ...
# 5   Calon bupati (cabup) Buleleng nomor urut 1, Ny...
# 6                                           Teknologi
# 7                                          Pendidikan
# 8                                            Politika
# 9                                            Politika
# 10                                         Gaya Hidup
# 11                                           Politika
# 12                                           Politika
# 13                                            Tabanan
# 14                                             Badung
# 15                                          Peristiwa
# 16                                           Otomotif
# 17                                         Pendidikan
# 18                                         Pendidikan

# %%
clean_data_2 = clean_data.drop(['link','date','source'], axis=1)
clean_data_2
# Out:
#     Unnamed: 0                                              title     keyword  \
# 0            0  Diar Tawarkan Pasraman Singkat untuk Pendidika...  pendidikan
# 1            1  Winuntara: Sistem Pendidikan Bangli Era Sedana...  pendidikan
# 2            2  Kampanye di Klungkung, Koster-Giri Janjikan Ke...  pendidikan
# 3            3  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...  pendidikan
# 4            4  Raden Cahyo Tawarkan Program Pendidikan Gratis...  pendidikan
# 5            5  Sugawa Akan Libatkan Ahli untuk Grand Design S...  pendidikan
# 6            6  Kuatkan Ekosistem Digital untuk Pendidikan Ber...  pendidikan
# 7            7  Pro Kontra Guru Cukur Rambut Murid, Ini Pandan...  pendidikan
# 8            8  Wajib Tahu! Ini Lima Program Jitu Pendidikan y...  pendidikan
# 9            9  Tingkatkan Pendidikan, Gus Par-Pandu Cetak Sat...  pendidikan
# 10          10  Telkomsel Lebih Dekat dengan Gen Z melalui by....  pendidikan
# 11          11  Suyadinata Disambut Antusias di Banjar Adat Be...  pendidikan
# 12          12  Koster-Giri akan Bangun Sports Center Bali di ...  pendidikan
# 13          13  Buntut Konflik Dua Yayasan Pendidikan di Taban...  pendidikan
# 14          14  Badung Education Fair 2024, Pj. Sekda Badung: ...  pendidikan
# 15          15  Kisah Aksi Heroik Joni, Si Pemanjat Tiang Bend...  pendidikan
# 16          16  Astra Daihatsu Motor Donasikan Mobil Perpustak...  pendidikan
# 17          17  Redea Institute: Nama Baru HighScope Indonesia...  pendidikan
# 18          18  Rektor Undiksha Kunjungi Shunan University dan...  pendidikan
#
#                                               content
# 0   Calon wakil bupati (cawabup) Bangli nomor urut...
# 1   Calon wakil bupati (cawabup) Bangli nomor urut...
# 2   Calon gubernur dan wakil gubernur Bali nomor u...
# 3   Pasangan calon (paslon) nomor urut 1, I Nengah...
# 4   Calon bupati Bangli nomor urut 1, Raden Cahyo ...
# 5   Calon bupati (cabup) Buleleng nomor urut 1, Ny...
# 6                                           Teknologi
# 7                                          Pendidikan
# 8                                            Politika
# 9                                            Politika
# 10                                         Gaya Hidup
# 11                                           Politika
# 12                                           Politika
# 13                                            Tabanan
# 14                                             Badung
# 15                                          Peristiwa
# 16                                           Otomotif
# 17                                         Pendidikan
# 18                                         Pendidikan

# %% [markdown]
# ## Preprocessing Judul Bahasa Indonesia

# %%
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from transformers import BertTokenizer

# Download stopwords dari NLTK
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Inisialisasi Stemmer (Sastrawi)
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Tokenizer IndoBERT (atau BERT)
tokenizer = BertTokenizer.from_pretrained('indolem/indobert-base-uncased')

# %%
# Fungsi Preprocessing
def preprocess_text(text):
    # 1. Mengubah teks ke huruf kecil
    text = text.lower()

    # 2. Menghapus URL, mention, hashtag, dan angka
    text = re.sub(r"http\S+|www\S+|https\S+", "", text)  # Menghapus URL
    text = re.sub(r"@\w+", "", text)  # Menghapus mention (@username)
    text = re.sub(r"#\w+", "", text)  # Menghapus hashtag (#hashtag)
    text = re.sub(r"\d+", "", text)  # Menghapus angka

    # 3. Menghapus tanda baca (jika diperlukan)
    text = re.sub(r"[^\w\s]", "", text)  # Menghapus tanda baca

    # 4. Tokenisasi menggunakan NLTK
    words = word_tokenize(text)  # Memecah kalimat menjadi kata

    # # 5. Menghapus stop words (menggunakan NLTK)
    # stop_words = set(stopwords.words('indonesian'))
    # words = [word for word in words if word not in stop_words]

    # 6. Stemming dengan Sastrawi
    words = [stemmer.stem(word) for word in words]

    # 7. Menggabungkan kembali kata-kata menjadi kalimat
    cleaned_text = " ".join(words)

    # 8. Tokenisasi menggunakan IndoBERT tokenizer (optional: untuk input model)
    input_ids = tokenizer.encode(cleaned_text, add_special_tokens=True)
    
    return cleaned_text, input_ids

# %%
clean_data_3 = clean_data_2.copy()

# Terapkan fungsi preprocess_text ke kolom 'description'
clean_data_3['cleaned_title'], clean_data_3['input_ids'] = zip(*clean_data_3['title'].apply(preprocess_text))

# %%
print(clean_data_3.shape)
clean_data_3
# Out:
# (19, 6)
#     Unnamed: 0                                              title     keyword  \
# 0            0  Diar Tawarkan Pasraman Singkat untuk Pendidika...  pendidikan
# 1            1  Winuntara: Sistem Pendidikan Bangli Era Sedana...  pendidikan
# 2            2  Kampanye di Klungkung, Koster-Giri Janjikan Ke...  pendidikan
# 3            3  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...  pendidikan
# 4            4  Raden Cahyo Tawarkan Program Pendidikan Gratis...  pendidikan
# 5            5  Sugawa Akan Libatkan Ahli untuk Grand Design S...  pendidikan
# 6            6  Kuatkan Ekosistem Digital untuk Pendidikan Ber...  pendidikan
# 7            7  Pro Kontra Guru Cukur Rambut Murid, Ini Pandan...  pendidikan
# 8            8  Wajib Tahu! Ini Lima Program Jitu Pendidikan y...  pendidikan
# 9            9  Tingkatkan Pendidikan, Gus Par-Pandu Cetak Sat...  pendidikan
# 10          10  Telkomsel Lebih Dekat dengan Gen Z melalui by....  pendidikan
# 11          11  Suyadinata Disambut Antusias di Banjar Adat Be...  pendidikan
# 12          12  Koster-Giri akan Bangun Sports Center Bali di ...  pendidikan
# 13          13  Buntut Konflik Dua Yayasan Pendidikan di Taban...  pendidikan
# 14          14  Badung Education Fair 2024, Pj. Sekda Badung: ...  pendidikan
# 15          15  Kisah Aksi Heroik Joni, Si Pemanjat Tiang Bend...  pendidikan
# 16          16  Astra Daihatsu Motor Donasikan Mobil Perpustak...  pendidikan
# 17          17  Redea Institute: Nama Baru HighScope Indonesia...  pendidikan
# 18          18  Rektor Undiksha Kunjungi Shunan University dan...  pendidikan
#
#                                               content  \
# 0   Calon wakil bupati (cawabup) Bangli nomor urut...
# 1   Calon wakil bupati (cawabup) Bangli nomor urut...
# 2   Calon gubernur dan wakil gubernur Bali nomor u...
# 3   Pasangan calon (paslon) nomor urut 1, I Nengah...
# 4   Calon bupati Bangli nomor urut 1, Raden Cahyo ...
# 5   Calon bupati (cabup) Buleleng nomor urut 1, Ny...
# 6                                           Teknologi
# 7                                          Pendidikan
# 8                                            Politika
# 9                                            Politika
# 10                                         Gaya Hidup
# 11                                           Politika
# 12                                           Politika
# 13                                            Tabanan
# 14                                             Badung
# 15                                          Peristiwa
# 16                                           Otomotif
# 17                                         Pendidikan
# 18                                         Pendidikan
#
#                                         cleaned_title  \
# 0    diar tawar pasraman singkat untuk didik karakter
# 1   winuntara sistem didik bangli era dana artadia...
# 2   kampanye di klungkung kostergiri janji kesehat...
# 3   tambadana janji beri pendidikanpelatihan bagi ...
# 4   raden cahyo tawar program didik gratisbuka jar...
# 5   sugawa akan libat ahli untuk grand design sing...
# 6   kuat ekosistem digital untuk didik lanjut di i...
# 7   pro kontra guru cukur rambut murid ini pandang...
# 8   wajib tahu ini lima program jitu didik yang ak...
# 9   tingkat didik gus parpandu cetak satu kk satu ...
# 10  telkomsel lebih dekat dengan gen z lalu byu da...
# 11  suyadinata sambut antusias di banjar adat bela...
# 12  kostergiri akan bangun sports center bal di ba...
# 13  buntut konflik dua yayasan didik di taban akhi...
# 14  badung education fair pj sekda badung tetap de...
# 15  kisah aksi heroik joni si panjat tiang bendera...
# 16  astra daihatsu motor donasi mobil pustaka dan ...
# 17  redea institute nama baru highscope indonesia ...
# 18  rektor undiksha kunjung shunan university dan ...
#
#                                             input_ids
# 0   [3, 9135, 11373, 1746, 7090, 935, 5530, 1559, ...
# 1   [3, 7089, 2694, 1527, 2289, 8820, 2031, 2004, ...
# 2   [3, 4917, 1485, 26080, 27217, 3810, 1667, 6453...
# 3   [3, 3703, 20378, 6453, 8448, 2332, 12835, 2692...
# 4   [3, 7535, 31627, 11373, 2525, 8820, 6938, 2806...
# 5   [3, 7838, 1813, 1634, 5388, 1481, 3390, 1559, ...
# 6   [3, 3180, 12772, 6559, 1559, 8820, 4319, 1485,...
# 7   [3, 3572, 10406, 3030, 2297, 1514, 6685, 4233,...
# 8   [3, 5273, 2818, 1540, 2715, 2525, 18680, 8820,...
# 9   [3, 2842, 8820, 4220, 1810, 4298, 10974, 8437,...
# 10  [3, 20259, 1716, 2935, 1545, 2051, 68, 2068, 3...
# 11  [3, 25595, 15122, 1640, 16816, 11592, 1485, 57...
# 12  [3, 27217, 3810, 1667, 1634, 7593, 16779, 6637...
# 13  [3, 18173, 4161, 1854, 5354, 8820, 1485, 3761,...
# 14  [3, 21769, 14514, 10235, 15558, 1631, 1808, 21...
# 15  [3, 4036, 3171, 30594, 26403, 1764, 12243, 148...
# 16  [3, 17586, 11440, 9662, 3321, 4299, 29953, 294...
# 17  [3, 4300, 2481, 9519, 1966, 1836, 8863, 10814,...
# 18  [3, 7334, 25506, 7138, 2516, 11632, 28339, 147...

# %% [markdown]
# ## Translate Judul ke Bahasa Inggris dan Preprocessing

# %%
pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2022.6.15.1)
# Requirement already satisfied: hstspreload in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.11.1)
# Requirement already satisfied: sniffio in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Fungsi translator

# %%
from googletrans import Translator
import pandas as pd

# Fungsi untuk menerjemahkan teks ke bahasa Inggris
def translate_to_english(text):
    translator = Translator()
    try:
        translated_text = translator.translate(text, dest='en').text
        return translated_text
    except Exception as e:
        print(f"Error translating text: {e}")
        return text

# %%
clean_data_4 = clean_data_3.copy()

# Menerapkan fungsi translate_to_english pada kolom "Title"
clean_data_4['title_translated'] = clean_data_4['title'].apply(translate_to_english)

# Menampilkan dataframe setelah perubahan
print(clean_data_4.shape)
clean_data_4
# Out:
# (19, 7)
#     Unnamed: 0                                              title     keyword  \
# 0            0  Diar Tawarkan Pasraman Singkat untuk Pendidika...  pendidikan
# 1            1  Winuntara: Sistem Pendidikan Bangli Era Sedana...  pendidikan
# 2            2  Kampanye di Klungkung, Koster-Giri Janjikan Ke...  pendidikan
# 3            3  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...  pendidikan
# 4            4  Raden Cahyo Tawarkan Program Pendidikan Gratis...  pendidikan
# 5            5  Sugawa Akan Libatkan Ahli untuk Grand Design S...  pendidikan
# 6            6  Kuatkan Ekosistem Digital untuk Pendidikan Ber...  pendidikan
# 7            7  Pro Kontra Guru Cukur Rambut Murid, Ini Pandan...  pendidikan
# 8            8  Wajib Tahu! Ini Lima Program Jitu Pendidikan y...  pendidikan
# 9            9  Tingkatkan Pendidikan, Gus Par-Pandu Cetak Sat...  pendidikan
# 10          10  Telkomsel Lebih Dekat dengan Gen Z melalui by....  pendidikan
# 11          11  Suyadinata Disambut Antusias di Banjar Adat Be...  pendidikan
# 12          12  Koster-Giri akan Bangun Sports Center Bali di ...  pendidikan
# 13          13  Buntut Konflik Dua Yayasan Pendidikan di Taban...  pendidikan
# 14          14  Badung Education Fair 2024, Pj. Sekda Badung: ...  pendidikan
# 15          15  Kisah Aksi Heroik Joni, Si Pemanjat Tiang Bend...  pendidikan
# 16          16  Astra Daihatsu Motor Donasikan Mobil Perpustak...  pendidikan
# 17          17  Redea Institute: Nama Baru HighScope Indonesia...  pendidikan
# 18          18  Rektor Undiksha Kunjungi Shunan University dan...  pendidikan
#
#                                               content  \
# 0   Calon wakil bupati (cawabup) Bangli nomor urut...
# 1   Calon wakil bupati (cawabup) Bangli nomor urut...
# 2   Calon gubernur dan wakil gubernur Bali nomor u...
# 3   Pasangan calon (paslon) nomor urut 1, I Nengah...
# 4   Calon bupati Bangli nomor urut 1, Raden Cahyo ...
# 5   Calon bupati (cabup) Buleleng nomor urut 1, Ny...
# 6                                           Teknologi
# 7                                          Pendidikan
# 8                                            Politika
# 9                                            Politika
# 10                                         Gaya Hidup
# 11                                           Politika
# 12                                           Politika
# 13                                            Tabanan
# 14                                             Badung
# 15                                          Peristiwa
# 16                                           Otomotif
# 17                                         Pendidikan
# 18                                         Pendidikan
#
#                                         cleaned_title  \
# 0    diar tawar pasraman singkat untuk didik karakter
# 1   winuntara sistem didik bangli era dana artadia...
# 2   kampanye di klungkung kostergiri janji kesehat...
# 3   tambadana janji beri pendidikanpelatihan bagi ...
# 4   raden cahyo tawar program didik gratisbuka jar...
# 5   sugawa akan libat ahli untuk grand design sing...
# 6   kuat ekosistem digital untuk didik lanjut di i...
# 7   pro kontra guru cukur rambut murid ini pandang...
# 8   wajib tahu ini lima program jitu didik yang ak...
# 9   tingkat didik gus parpandu cetak satu kk satu ...
# 10  telkomsel lebih dekat dengan gen z lalu byu da...
# 11  suyadinata sambut antusias di banjar adat bela...
# 12  kostergiri akan bangun sports center bal di ba...
# 13  buntut konflik dua yayasan didik di taban akhi...
# 14  badung education fair pj sekda badung tetap de...
# 15  kisah aksi heroik joni si panjat tiang bendera...
# 16  astra daihatsu motor donasi mobil pustaka dan ...
# 17  redea institute nama baru highscope indonesia ...
# 18  rektor undiksha kunjung shunan university dan ...
#
#                                             input_ids  \
# 0   [3, 9135, 11373, 1746, 7090, 935, 5530, 1559, ...
# 1   [3, 7089, 2694, 1527, 2289, 8820, 2031, 2004, ...
# 2   [3, 4917, 1485, 26080, 27217, 3810, 1667, 6453...
# 3   [3, 3703, 20378, 6453, 8448, 2332, 12835, 2692...
# 4   [3, 7535, 31627, 11373, 2525, 8820, 6938, 2806...
# 5   [3, 7838, 1813, 1634, 5388, 1481, 3390, 1559, ...
# 6   [3, 3180, 12772, 6559, 1559, 8820, 4319, 1485,...
# 7   [3, 3572, 10406, 3030, 2297, 1514, 6685, 4233,...
# 8   [3, 5273, 2818, 1540, 2715, 2525, 18680, 8820,...
# 9   [3, 2842, 8820, 4220, 1810, 4298, 10974, 8437,...
# 10  [3, 20259, 1716, 2935, 1545, 2051, 68, 2068, 3...
# 11  [3, 25595, 15122, 1640, 16816, 11592, 1485, 57...
# 12  [3, 27217, 3810, 1667, 1634, 7593, 16779, 6637...
# 13  [3, 18173, 4161, 1854, 5354, 8820, 1485, 3761,...
# 14  [3, 21769, 14514, 10235, 15558, 1631, 1808, 21...
# 15  [3, 4036, 3171, 30594, 26403, 1764, 12243, 148...
# 16  [3, 17586, 11440, 9662, 3321, 4299, 29953, 294...
# 17  [3, 4300, 2481, 9519, 1966, 1836, 8863, 10814,...
# 18  [3, 7334, 25506, 7138, 2516, 11632, 28339, 147...
#
#                                      title_translated
# 0   Diar offers a short pasraman for character edu...
# 1   Winuntara: The Bangli Era Sedana Arta-Diaru-Di...
# 2   Campaign in Klungkung, Koster-Giri promises fr...
# 3   Tamba-dana promise to give education-training ...
# 4   Raden Cahyo Offers Free Education Programs-Ope...
# 5   Sugawa Will Involve Experts to Grand Design Si...
# 6   Strengthen digital ecosystems for sustainable ...
# 7   Pros and cons of student hair shaving teachers...
# 8   Must know!These are the five accurate educatio...
# 9   Increase education, Gus Par-gucks Print One KK...
# 10  Telkomsel is closer to Gen Z through by.U and ...
# 11  Suyadinata was welcomed enthusiastically in Ba...
# 12  Koster-Giri will build a Sports Center in Bali...
# 13  The aftermath of the conflict of two education...
# 14  Badung Education Fair 2024, PJ.Badung Regional...
# 15  The story of the heroic action of Joni, the fl...
# 16  Astra Daihatsu Motor donates library cars and ...
# 17  Redea Institute: New Name of the Highscope Ind...
# 18  Undiksha Chancellor Visit Shunan University an...

# %%
import nltk
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import spacy
# Load the model
nlp = spacy.load("en_core_web_sm")

# Download NLTK resources (if not already done)
nltk.download('punkt')
nltk.download('stopwords')

# Load spaCy English model for lemmatization
nlp = spacy.load("en_core_web_sm")

def clean_text(text):
    """
    Perform basic text cleaning including:
    - Lowercasing
    - Removing punctuation and special characters
    - Removing extra spaces
    """
    # Convert to lowercase
    text = text.lower()

    # Remove punctuation and special characters (using regular expressions)
    text = re.sub(f"[{string.punctuation}]", "", text)

    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# def remove_stopwords(text):
#     """
#     Remove stopwords from the text.
#     """
#     stop_words = set(stopwords.words('english'))
#     word_tokens = word_tokenize(text)
    
#     # Filter out stopwords
#     filtered_text = [word for word in word_tokens if word not in stop_words]
    
#     return ' '.join(filtered_text)

def lemmatize_text(text):
    """
    Lemmatize the text to reduce words to their base form.
    """
    doc = nlp(text)
    
    # Lemmatize each token (word) and join them back into a string
    lemmatized_text = " ".join([token.lemma_ for token in doc])
    
    return lemmatized_text

def preprocess_text(text):
    """
    Complete preprocessing pipeline:
    1. Clean the text (remove punctuation, lowercase)
    2. Remove stopwords
    3. Lemmatize the text
    """
    text = clean_text(text)
    # text = remove_stopwords(text)
    text = lemmatize_text(text)
    
    return text
# Out:
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:1144: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\tensor\python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
clean_data_4['cleaned_title_translated'] = clean_data_4['title_translated'].apply(preprocess_text)

print(clean_data_4.shape)
clean_data_4
# Out:
# (19, 8)
#     Unnamed: 0                                              title     keyword  \
# 0            0  Diar Tawarkan Pasraman Singkat untuk Pendidika...  pendidikan
# 1            1  Winuntara: Sistem Pendidikan Bangli Era Sedana...  pendidikan
# 2            2  Kampanye di Klungkung, Koster-Giri Janjikan Ke...  pendidikan
# 3            3  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...  pendidikan
# 4            4  Raden Cahyo Tawarkan Program Pendidikan Gratis...  pendidikan
# 5            5  Sugawa Akan Libatkan Ahli untuk Grand Design S...  pendidikan
# 6            6  Kuatkan Ekosistem Digital untuk Pendidikan Ber...  pendidikan
# 7            7  Pro Kontra Guru Cukur Rambut Murid, Ini Pandan...  pendidikan
# 8            8  Wajib Tahu! Ini Lima Program Jitu Pendidikan y...  pendidikan
# 9            9  Tingkatkan Pendidikan, Gus Par-Pandu Cetak Sat...  pendidikan
# 10          10  Telkomsel Lebih Dekat dengan Gen Z melalui by....  pendidikan
# 11          11  Suyadinata Disambut Antusias di Banjar Adat Be...  pendidikan
# 12          12  Koster-Giri akan Bangun Sports Center Bali di ...  pendidikan
# 13          13  Buntut Konflik Dua Yayasan Pendidikan di Taban...  pendidikan
# 14          14  Badung Education Fair 2024, Pj. Sekda Badung: ...  pendidikan
# 15          15  Kisah Aksi Heroik Joni, Si Pemanjat Tiang Bend...  pendidikan
# 16          16  Astra Daihatsu Motor Donasikan Mobil Perpustak...  pendidikan
# 17          17  Redea Institute: Nama Baru HighScope Indonesia...  pendidikan
# 18          18  Rektor Undiksha Kunjungi Shunan University dan...  pendidikan
#
#                                               content  \
# 0   Calon wakil bupati (cawabup) Bangli nomor urut...
# 1   Calon wakil bupati (cawabup) Bangli nomor urut...
# 2   Calon gubernur dan wakil gubernur Bali nomor u...
# 3   Pasangan calon (paslon) nomor urut 1, I Nengah...
# 4   Calon bupati Bangli nomor urut 1, Raden Cahyo ...
# 5   Calon bupati (cabup) Buleleng nomor urut 1, Ny...
# 6                                           Teknologi
# 7                                          Pendidikan
# 8                                            Politika
# 9                                            Politika
# 10                                         Gaya Hidup
# 11                                           Politika
# 12                                           Politika
# 13                                            Tabanan
# 14                                             Badung
# 15                                          Peristiwa
# 16                                           Otomotif
# 17                                         Pendidikan
# 18                                         Pendidikan
#
#                                         cleaned_title  \
# 0    diar tawar pasraman singkat untuk didik karakter
# 1   winuntara sistem didik bangli era dana artadia...
# 2   kampanye di klungkung kostergiri janji kesehat...
# 3   tambadana janji beri pendidikanpelatihan bagi ...
# 4   raden cahyo tawar program didik gratisbuka jar...
# 5   sugawa akan libat ahli untuk grand design sing...
# 6   kuat ekosistem digital untuk didik lanjut di i...
# 7   pro kontra guru cukur rambut murid ini pandang...
# 8   wajib tahu ini lima program jitu didik yang ak...
# 9   tingkat didik gus parpandu cetak satu kk satu ...
# 10  telkomsel lebih dekat dengan gen z lalu byu da...
# 11  suyadinata sambut antusias di banjar adat bela...
# 12  kostergiri akan bangun sports center bal di ba...
# 13  buntut konflik dua yayasan didik di taban akhi...
# 14  badung education fair pj sekda badung tetap de...
# 15  kisah aksi heroik joni si panjat tiang bendera...
# 16  astra daihatsu motor donasi mobil pustaka dan ...
# 17  redea institute nama baru highscope indonesia ...
# 18  rektor undiksha kunjung shunan university dan ...
#
#                                             input_ids  \
# 0   [3, 9135, 11373, 1746, 7090, 935, 5530, 1559, ...
# 1   [3, 7089, 2694, 1527, 2289, 8820, 2031, 2004, ...
# 2   [3, 4917, 1485, 26080, 27217, 3810, 1667, 6453...
# 3   [3, 3703, 20378, 6453, 8448, 2332, 12835, 2692...
# 4   [3, 7535, 31627, 11373, 2525, 8820, 6938, 2806...
# 5   [3, 7838, 1813, 1634, 5388, 1481, 3390, 1559, ...
# 6   [3, 3180, 12772, 6559, 1559, 8820, 4319, 1485,...
# 7   [3, 3572, 10406, 3030, 2297, 1514, 6685, 4233,...
# 8   [3, 5273, 2818, 1540, 2715, 2525, 18680, 8820,...
# 9   [3, 2842, 8820, 4220, 1810, 4298, 10974, 8437,...
# 10  [3, 20259, 1716, 2935, 1545, 2051, 68, 2068, 3...
# 11  [3, 25595, 15122, 1640, 16816, 11592, 1485, 57...
# 12  [3, 27217, 3810, 1667, 1634, 7593, 16779, 6637...
# 13  [3, 18173, 4161, 1854, 5354, 8820, 1485, 3761,...
# 14  [3, 21769, 14514, 10235, 15558, 1631, 1808, 21...
# 15  [3, 4036, 3171, 30594, 26403, 1764, 12243, 148...
# 16  [3, 17586, 11440, 9662, 3321, 4299, 29953, 294...
# 17  [3, 4300, 2481, 9519, 1966, 1836, 8863, 10814,...
# 18  [3, 7334, 25506, 7138, 2516, 11632, 28339, 147...
#
#                                      title_translated  \
# 0   Diar offers a short pasraman for character edu...
# 1   Winuntara: The Bangli Era Sedana Arta-Diaru-Di...
# 2   Campaign in Klungkung, Koster-Giri promises fr...
# 3   Tamba-dana promise to give education-training ...
# 4   Raden Cahyo Offers Free Education Programs-Ope...
# 5   Sugawa Will Involve Experts to Grand Design Si...
# 6   Strengthen digital ecosystems for sustainable ...
# 7   Pros and cons of student hair shaving teachers...
# 8   Must know!These are the five accurate educatio...
# 9   Increase education, Gus Par-gucks Print One KK...
# 10  Telkomsel is closer to Gen Z through by.U and ...
# 11  Suyadinata was welcomed enthusiastically in Ba...
# 12  Koster-Giri will build a Sports Center in Bali...
# 13  The aftermath of the conflict of two education...
# 14  Badung Education Fair 2024, PJ.Badung Regional...
# 15  The story of the heroic action of Joni, the fl...
# 16  Astra Daihatsu Motor donates library cars and ...
# 17  Redea Institute: New Name of the Highscope Ind...
# 18  Undiksha Chancellor Visit Shunan University an...
#
#                              cleaned_title_translated
# 0   diar offer a short pasraman for character educ...
# 1   winuntara the bangli era sedana artadiarudiaru...
# 2   campaign in klungkung kostergiri promise free ...
# 3   tambadana promise to give educationtraine for ...
# 4   raden cahyo offer free education programsopen ...
# 5   sugawa will involve expert to grand design sin...
# 6   strengthen digital ecosystem for sustainable e...
# 7   pro and con of student hair shaving teacher th...
# 8   must knowthese be the five accurate education ...
# 9   increase education gus parguck print one kk on...
# 10  telkomsel be close to gen z through byu and pl...
# 11  suyadinata be welcome enthusiastically in banj...
# 12  kostergiri will build a sport center in bali i...
# 13  the aftermath of the conflict of two education...
# 14  badung education fair 2024 pjbadung regional s...
# 15  the story of the heroic action of joni the fla...
# 16  astra daihatsu motor donate library car and ot...
# 17  redea institute new name of the highscope indo...
# 18  undiksha chancellor visit shunan university an...

# %% [markdown]
# ## Sentimen Decision + Word Cloud + Export Result

# %%
data_ready = clean_data_4.copy()
data_ready.head()
# Out:
#    Unnamed: 0                                              title     keyword  \
# 0           0  Diar Tawarkan Pasraman Singkat untuk Pendidika...  pendidikan
# 1           1  Winuntara: Sistem Pendidikan Bangli Era Sedana...  pendidikan
# 2           2  Kampanye di Klungkung, Koster-Giri Janjikan Ke...  pendidikan
# 3           3  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...  pendidikan
# 4           4  Raden Cahyo Tawarkan Program Pendidikan Gratis...  pendidikan
#
#                                              content  \
# 0  Calon wakil bupati (cawabup) Bangli nomor urut...
# 1  Calon wakil bupati (cawabup) Bangli nomor urut...
# 2  Calon gubernur dan wakil gubernur Bali nomor u...
# 3  Pasangan calon (paslon) nomor urut 1, I Nengah...
# 4  Calon bupati Bangli nomor urut 1, Raden Cahyo ...
#
#                                        cleaned_title  \
# 0   diar tawar pasraman singkat untuk didik karakter
# 1  winuntara sistem didik bangli era dana artadia...
# 2  kampanye di klungkung kostergiri janji kesehat...
# 3  tambadana janji beri pendidikanpelatihan bagi ...
# 4  raden cahyo tawar program didik gratisbuka jar...
#
#                                            input_ids  \
# 0  [3, 9135, 11373, 1746, 7090, 935, 5530, 1559, ...
# 1  [3, 7089, 2694, 1527, 2289, 8820, 2031, 2004, ...
# 2  [3, 4917, 1485, 26080, 27217, 3810, 1667, 6453...
# 3  [3, 3703, 20378, 6453, 8448, 2332, 12835, 2692...
# 4  [3, 7535, 31627, 11373, 2525, 8820, 6938, 2806...
#
#                                     title_translated  \
# 0  Diar offers a short pasraman for character edu...
# 1  Winuntara: The Bangli Era Sedana Arta-Diaru-Di...
# 2  Campaign in Klungkung, Koster-Giri promises fr...
# 3  Tamba-dana promise to give education-training ...
# 4  Raden Cahyo Offers Free Education Programs-Ope...
#
#                             cleaned_title_translated
# 0  diar offer a short pasraman for character educ...
# 1  winuntara the bangli era sedana artadiarudiaru...
# 2  campaign in klungkung kostergiri promise free ...
# 3  tambadana promise to give educationtraine for ...
# 4  raden cahyo offer free education programsopen ...

# %% [markdown]
# ### 1. TextBlob

# %% [markdown]
# #### Sentiment

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (8.1.3)
# Requirement already satisfied: joblib in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (2022.9.13)
# Requirement already satisfied: tqdm in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (4.64.1)
# Requirement already satisfied: colorama in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
data_sentiment1 = data_ready[['keyword','title_translated','cleaned_title_translated']]
data_sentiment1
# Out:
#        keyword                                   title_translated  \
# 0   pendidikan  Diar offers a short pasraman for character edu...
# 1   pendidikan  Winuntara: The Bangli Era Sedana Arta-Diaru-Di...
# 2   pendidikan  Campaign in Klungkung, Koster-Giri promises fr...
# 3   pendidikan  Tamba-dana promise to give education-training ...
# 4   pendidikan  Raden Cahyo Offers Free Education Programs-Ope...
# 5   pendidikan  Sugawa Will Involve Experts to Grand Design Si...
# 6   pendidikan  Strengthen digital ecosystems for sustainable ...
# 7   pendidikan  Pros and cons of student hair shaving teachers...
# 8   pendidikan  Must know!These are the five accurate educatio...
# 9   pendidikan  Increase education, Gus Par-gucks Print One KK...
# 10  pendidikan  Telkomsel is closer to Gen Z through by.U and ...
# 11  pendidikan  Suyadinata was welcomed enthusiastically in Ba...
# 12  pendidikan  Koster-Giri will build a Sports Center in Bali...
# 13  pendidikan  The aftermath of the conflict of two education...
# 14  pendidikan  Badung Education Fair 2024, PJ.Badung Regional...
# 15  pendidikan  The story of the heroic action of Joni, the fl...
# 16  pendidikan  Astra Daihatsu Motor donates library cars and ...
# 17  pendidikan  Redea Institute: New Name of the Highscope Ind...
# 18  pendidikan  Undiksha Chancellor Visit Shunan University an...
#
#                              cleaned_title_translated
# 0   diar offer a short pasraman for character educ...
# 1   winuntara the bangli era sedana artadiarudiaru...
# 2   campaign in klungkung kostergiri promise free ...
# 3   tambadana promise to give educationtraine for ...
# 4   raden cahyo offer free education programsopen ...
# 5   sugawa will involve expert to grand design sin...
# 6   strengthen digital ecosystem for sustainable e...
# 7   pro and con of student hair shaving teacher th...
# 8   must knowthese be the five accurate education ...
# 9   increase education gus parguck print one kk on...
# 10  telkomsel be close to gen z through byu and pl...
# 11  suyadinata be welcome enthusiastically in banj...
# 12  kostergiri will build a sport center in bali i...
# 13  the aftermath of the conflict of two education...
# 14  badung education fair 2024 pjbadung regional s...
# 15  the story of the heroic action of joni the fla...
# 16  astra daihatsu motor donate library car and ot...
# 17  redea institute new name of the highscope indo...
# 18  undiksha chancellor visit shunan university an...

# %%
import pandas as pd
from textblob import TextBlob

# Pastikan kolom yang berisi alasan berhenti berlangganan dinamai 'reason'
# Jika nama kolom berbeda, ubah 'reason' sesuai dengan nama kolom yang benar
def get_sentiment(text):
    analysis = TextBlob(text)
    # Mengambil nilai sentimen
    return analysis.sentiment.polarity

# Menambahkan kolom baru untuk menyimpan nilai sentimen
data_sentiment1['sentiment_score_english'] = data_sentiment1['cleaned_title_translated'].apply(get_sentiment)

# Mengkategorikan sentimen
def categorize_sentiment(score):
    if score > 0:
        return 'Positif'
    elif score < 0:
        return 'Negatif'
    else:
        return 'Netral'

data_sentiment1['sentiment_category_english'] = data_sentiment1['sentiment_score_english'].apply(categorize_sentiment)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_21016\3177936794.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment1['sentiment_score_english'] = data_sentiment1['cleaned_title_translated'].apply(get_sentiment)
# C:\Users\asus\AppData\Local\Temp\ipykernel_21016\3177936794.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment1['sentiment_category_english'] = data_sentiment1['sentiment_score_english'].apply(categorize_sentiment)

# %%
data_sentiment1
# Out:
#        keyword                                   title_translated  \
# 0   pendidikan  Diar offers a short pasraman for character edu...
# 1   pendidikan  Winuntara: The Bangli Era Sedana Arta-Diaru-Di...
# 2   pendidikan  Campaign in Klungkung, Koster-Giri promises fr...
# 3   pendidikan  Tamba-dana promise to give education-training ...
# 4   pendidikan  Raden Cahyo Offers Free Education Programs-Ope...
# 5   pendidikan  Sugawa Will Involve Experts to Grand Design Si...
# 6   pendidikan  Strengthen digital ecosystems for sustainable ...
# 7   pendidikan  Pros and cons of student hair shaving teachers...
# 8   pendidikan  Must know!These are the five accurate educatio...
# 9   pendidikan  Increase education, Gus Par-gucks Print One KK...
# 10  pendidikan  Telkomsel is closer to Gen Z through by.U and ...
# 11  pendidikan  Suyadinata was welcomed enthusiastically in Ba...
# 12  pendidikan  Koster-Giri will build a Sports Center in Bali...
# 13  pendidikan  The aftermath of the conflict of two education...
# 14  pendidikan  Badung Education Fair 2024, PJ.Badung Regional...
# 15  pendidikan  The story of the heroic action of Joni, the fl...
# 16  pendidikan  Astra Daihatsu Motor donates library cars and ...
# 17  pendidikan  Redea Institute: New Name of the Highscope Ind...
# 18  pendidikan  Undiksha Chancellor Visit Shunan University an...
#
#                              cleaned_title_translated  \
# 0   diar offer a short pasraman for character educ...
# 1   winuntara the bangli era sedana artadiarudiaru...
# 2   campaign in klungkung kostergiri promise free ...
# 3   tambadana promise to give educationtraine for ...
# 4   raden cahyo offer free education programsopen ...
# 5   sugawa will involve expert to grand design sin...
# 6   strengthen digital ecosystem for sustainable e...
# 7   pro and con of student hair shaving teacher th...
# 8   must knowthese be the five accurate education ...
# 9   increase education gus parguck print one kk on...
# 10  telkomsel be close to gen z through byu and pl...
# 11  suyadinata be welcome enthusiastically in banj...
# 12  kostergiri will build a sport center in bali i...
# 13  the aftermath of the conflict of two education...
# 14  badung education fair 2024 pjbadung regional s...
# 15  the story of the heroic action of joni the fla...
# 16  astra daihatsu motor donate library car and ot...
# 17  redea institute new name of the highscope indo...
# 18  undiksha chancellor visit shunan university an...
#
#     sentiment_score_english sentiment_category_english
# 0                  0.000000                     Netral
# 1                  0.000000                     Netral
# 2                  0.400000                    Positif
# 3                 -0.125000                    Negatif
# 4                  0.400000                    Positif
# 5                  0.375000                    Positif
# 6                  0.000000                     Netral
# 7                  0.000000                     Netral
# 8                  0.400000                    Positif
# 9                  0.000000                     Netral
# 10                 0.250000                    Positif
# 11                 0.600000                    Positif
# 12                -0.100000                    Negatif
# 13                 0.125000                    Positif
# 14                 0.700000                    Positif
# 15                 0.300000                    Positif
# 16                -0.125000                    Negatif
# 17                 0.136364                    Positif
# 18                 0.150000                    Positif

# %%
sentiment_counts1 = data_sentiment1['sentiment_category_english'].value_counts()
sentiment_counts1
# Out:
# sentiment_category_english
# Positif    11
# Netral      5
# Negatif     3
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style of the plot using seaborn
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts1.index, y=sentiment_counts1.values, palette='viridis')

# Add labels and title
plt.title('Sentiment Category Distribution (Indonesia)', fontsize=16)
plt.xlabel('Sentiment Category', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Display the values on top of the bars
for i in range(len(sentiment_counts1)):
    plt.text(i, sentiment_counts1.values[i] + 0.5, 
             sentiment_counts1.values[i], 
             ha='center', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# #### Word Cloud (All and Based on Sentiment)

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (1.26.0)
# Requirement already satisfied: pillow in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: matplotlib in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (4.36.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all text from the 'Churn_Reason' column into a single string
text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1['cleaned_title_translated'])

# Create a word cloud
wordcloud_inggris = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_inggris, interpolation='bilinear')
plt.axis('off')  # Remove axes
plt.show()

# %% [markdown]
# Based on Sentiment

# %%
# Sentimen Positif
if data_sentiment1[data_sentiment1['sentiment_category_english'] == "Positif"].shape[0] != 0:
    data_sentiment1_positif = data_sentiment1[data_sentiment1['sentiment_category_english'] == "Positif"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_positif['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_positif_inggris = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_positif_inggris, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else:
    print("Tidak ada sentimen positif pada berita")

# %%
# Sentimen Negatif
if data_sentiment1[data_sentiment1['sentiment_category_english'] == "Negatif"].shape[0] != 0:
    data_sentiment1_negatif = data_sentiment1[data_sentiment1['sentiment_category_english'] == "Negatif"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_negatif['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_negatif_inggris = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_negatif_inggris, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen negatif pada berita")

# %%
# Sentimen Netral
if data_sentiment1[data_sentiment1['sentiment_category_english'] == "Netral"].shape[0] != 0:
    data_sentiment1_netral = data_sentiment1[data_sentiment1['sentiment_category_english'] == "Netral"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_netral['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_netral_inggris = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_netral_inggris, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen netral pada berita")

# %% [markdown]
# ### 2. VADER

# %% [markdown]
# #### Sentiment

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer

# Initialize VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Define a function to get sentiment scores with VADER
def get_sentiment_vader(text):
    # VADER provides a compound score which ranges from -1 (negative) to 1 (positive)
    score = sia.polarity_scores(text)['compound']
    return score

# Apply VADER to get the sentiment scores
data_sentiment1['sentiment_score_english_vader'] = data_sentiment1['cleaned_title_translated'].apply(get_sentiment_vader)

# Categorize sentiment with only 2 categories
def categorize_sentiment(score):
    if score > 0.05:  # Threshold for positive sentiment
        return 'Positif'
    elif score < -0.05:  # Threshold for negative sentiment
        return 'Negatif'
    else:
        return 'Netral'  # Scores between -0.05 and 0.05 considered neutral

data_sentiment1['sentiment_category_english_vader'] = data_sentiment1['sentiment_score_english_vader'].apply(categorize_sentiment)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_21016\17249303.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment1['sentiment_score_english_vader'] = data_sentiment1['cleaned_title_translated'].apply(get_sentiment_vader)
# C:\Users\asus\AppData\Local\Temp\ipykernel_21016\17249303.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment1['sentiment_category_english_vader'] = data_sentiment1['sentiment_score_english_vader'].apply(categorize_sentiment)

# %%
data_sentiment1.head()
# Out:
#       keyword                                   title_translated  \
# 0  pendidikan  Diar offers a short pasraman for character edu...
# 1  pendidikan  Winuntara: The Bangli Era Sedana Arta-Diaru-Di...
# 2  pendidikan  Campaign in Klungkung, Koster-Giri promises fr...
# 3  pendidikan  Tamba-dana promise to give education-training ...
# 4  pendidikan  Raden Cahyo Offers Free Education Programs-Ope...
#
#                             cleaned_title_translated  sentiment_score_english  \
# 0  diar offer a short pasraman for character educ...                    0.000
# 1  winuntara the bangli era sedana artadiarudiaru...                    0.000
# 2  campaign in klungkung kostergiri promise free ...                    0.400
# 3  tambadana promise to give educationtraine for ...                   -0.125
# 4  raden cahyo offer free education programsopen ...                    0.400
#
#   sentiment_category_english  sentiment_score_english_vader  \
# 0                     Netral                         0.0000
# 1                     Netral                         0.1531
# 2                    Positif                         0.6808
# 3                    Negatif                         0.3182
# 4                    Positif                         0.5106
#
#   sentiment_category_english_vader
# 0                           Netral
# 1                          Positif
# 2                          Positif
# 3                          Positif
# 4                          Positif

# %%
sentiment_counts1_vader = data_sentiment1['sentiment_category_english_vader'].value_counts()
sentiment_counts1_vader
# Out:
# sentiment_category_english_vader
# Positif    14
# Netral      4
# Negatif     1
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style of the plot using seaborn
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts1_vader.index, y=sentiment_counts1_vader.values, palette='viridis')

# Add labels and title
plt.title('Sentiment Category Distribution (Indonesia)', fontsize=16)
plt.xlabel('Sentiment Category', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Display the values on top of the bars
for i in range(len(sentiment_counts1_vader)):
    plt.text(i, sentiment_counts1_vader.values[i] + 0.5, 
             sentiment_counts1_vader.values[i], 
             ha='center', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# #### Word Cloud (Based on Sentiment Only)

# %%
# Sentimen Positif
if data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Positif"].shape[0] != 0:
    data_sentiment1_positif_vader = data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Positif"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_positif_vader['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_positif_inggris_vader = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_positif_inggris_vader, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen positif pada berita")

# %%
# Sentimen Negatif
if data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Negatif"].shape[0] != 0:
    data_sentiment1_negatif_vader = data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Negatif"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_negatif_vader['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_negatif_inggris_vader = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_negatif_inggris_vader, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen negatif pada berita")

# %%
# Sentimen Netral
if data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Netral"].shape[0] != 0:
    data_sentiment1_netral_vader = data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Netral"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_netral_vader['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_netral_inggris_vader = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_netral_inggris_vader, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen netral pada berita")

# %% [markdown]
# ### 3. IndoBERT

# %% [markdown]
# #### Sentiment

# %%
pip install transforms torch
# Out:
# Requirement already satisfied: transforms in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (0.2.1)
# Requirement already satisfied: torch in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (2.5.1)
# Requirement already satisfied: filelock in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
data_sentiment2 = data_ready[['keyword','title','cleaned_title','content']]
data_sentiment2
# Out:
#        keyword                                              title  \
# 0   pendidikan  Diar Tawarkan Pasraman Singkat untuk Pendidika...
# 1   pendidikan  Winuntara: Sistem Pendidikan Bangli Era Sedana...
# 2   pendidikan  Kampanye di Klungkung, Koster-Giri Janjikan Ke...
# 3   pendidikan  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...
# 4   pendidikan  Raden Cahyo Tawarkan Program Pendidikan Gratis...
# 5   pendidikan  Sugawa Akan Libatkan Ahli untuk Grand Design S...
# 6   pendidikan  Kuatkan Ekosistem Digital untuk Pendidikan Ber...
# 7   pendidikan  Pro Kontra Guru Cukur Rambut Murid, Ini Pandan...
# 8   pendidikan  Wajib Tahu! Ini Lima Program Jitu Pendidikan y...
# 9   pendidikan  Tingkatkan Pendidikan, Gus Par-Pandu Cetak Sat...
# 10  pendidikan  Telkomsel Lebih Dekat dengan Gen Z melalui by....
# 11  pendidikan  Suyadinata Disambut Antusias di Banjar Adat Be...
# 12  pendidikan  Koster-Giri akan Bangun Sports Center Bali di ...
# 13  pendidikan  Buntut Konflik Dua Yayasan Pendidikan di Taban...
# 14  pendidikan  Badung Education Fair 2024, Pj. Sekda Badung: ...
# 15  pendidikan  Kisah Aksi Heroik Joni, Si Pemanjat Tiang Bend...
# 16  pendidikan  Astra Daihatsu Motor Donasikan Mobil Perpustak...
# 17  pendidikan  Redea Institute: Nama Baru HighScope Indonesia...
# 18  pendidikan  Rektor Undiksha Kunjungi Shunan University dan...
#
#                                         cleaned_title  \
# 0    diar tawar pasraman singkat untuk didik karakter
# 1   winuntara sistem didik bangli era dana artadia...
# 2   kampanye di klungkung kostergiri janji kesehat...
# 3   tambadana janji beri pendidikanpelatihan bagi ...
# 4   raden cahyo tawar program didik gratisbuka jar...
# 5   sugawa akan libat ahli untuk grand design sing...
# 6   kuat ekosistem digital untuk didik lanjut di i...
# 7   pro kontra guru cukur rambut murid ini pandang...
# 8   wajib tahu ini lima program jitu didik yang ak...
# 9   tingkat didik gus parpandu cetak satu kk satu ...
# 10  telkomsel lebih dekat dengan gen z lalu byu da...
# 11  suyadinata sambut antusias di banjar adat bela...
# 12  kostergiri akan bangun sports center bal di ba...
# 13  buntut konflik dua yayasan didik di taban akhi...
# 14  badung education fair pj sekda badung tetap de...
# 15  kisah aksi heroik joni si panjat tiang bendera...
# 16  astra daihatsu motor donasi mobil pustaka dan ...
# 17  redea institute nama baru highscope indonesia ...
# 18  rektor undiksha kunjung shunan university dan ...
#
#                                               content
# 0   Calon wakil bupati (cawabup) Bangli nomor urut...
# 1   Calon wakil bupati (cawabup) Bangli nomor urut...
# 2   Calon gubernur dan wakil gubernur Bali nomor u...
# 3   Pasangan calon (paslon) nomor urut 1, I Nengah...
# 4   Calon bupati Bangli nomor urut 1, Raden Cahyo ...
# 5   Calon bupati (cabup) Buleleng nomor urut 1, Ny...
# 6                                           Teknologi
# 7                                          Pendidikan
# 8                                            Politika
# 9                                            Politika
# 10                                         Gaya Hidup
# 11                                           Politika
# 12                                           Politika
# 13                                            Tabanan
# 14                                             Badung
# 15                                          Peristiwa
# 16                                           Otomotif
# 17                                         Pendidikan
# 18                                         Pendidikan

# %%
from transformers import BertForSequenceClassification, BertTokenizer
import torch

# Load the saved model and tokenizer
model_load_path = "C:/Users/asus/OneDrive/BPS/Neraca/smsa_bpsbali_indobert_model"  # The path where the model is saved
tokenizer_load_path = "C:/Users/asus/OneDrive/BPS/Neraca/smsa_bpsbali_indobert_tokenizer"  # The path where the tokenizer is saved

# Load the model and tokenizer
model = BertForSequenceClassification.from_pretrained(model_load_path)
tokenizer = BertTokenizer.from_pretrained(tokenizer_load_path)

# %%
from torch.nn.functional import softmax  # Softmax function to convert logits to probabilities

# Initialize an empty list to collect predictions
sentiment_predict = []
probabilities = []

# Loop through the cleaned titles
for text in data_sentiment2['cleaned_title']:
    # Tokenize the input text
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)

    # Make prediction
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():  # Disable gradients for inference
        outputs = model(**inputs)

    # Get the logits (raw scores)
    logits = outputs.logits
    
    # Apply softmax to convert logits to probabilities
    probs = softmax(logits, dim=-1)  # Softmax along the class dimension (last dimension)

    # Get the predicted class (index of max logit)
    predicted_class = logits.argmax(dim=-1).item()

    # Get the probability of the predicted class
    predicted_prob = probs[0, predicted_class].item()

    # Convert prediction to string label
    if predicted_class == 0:
        sentiment_label = "positif"
    elif predicted_class == 1:
        sentiment_label = "netral"
    else:
        sentiment_label = "negatif"

    # Append the sentiment label and its probability
    sentiment_predict.append(sentiment_label)
    probabilities.append(predicted_prob)

# After the loop, create the DataFrame
sentiment_predict_df = pd.DataFrame({
    'sentiment': sentiment_predict,
    'probability': probabilities
})

# Add it as a new column to the original DataFrame
data_sentiment2['sentiment_score_indonesia'] = sentiment_predict_df['probability']
data_sentiment2['sentiment_category_indonesia'] = sentiment_predict_df['sentiment']

# Optionally, you can print the DataFrame to check the results
data_sentiment2
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_21016\1096017218.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment2['sentiment_score_indonesia'] = sentiment_predict_df['probability']
# C:\Users\asus\AppData\Local\Temp\ipykernel_21016\1096017218.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment2['sentiment_category_indonesia'] = sentiment_predict_df['sentiment']
#        keyword                                              title  \
# 0   pendidikan  Diar Tawarkan Pasraman Singkat untuk Pendidika...
# 1   pendidikan  Winuntara: Sistem Pendidikan Bangli Era Sedana...
# 2   pendidikan  Kampanye di Klungkung, Koster-Giri Janjikan Ke...
# 3   pendidikan  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...
# 4   pendidikan  Raden Cahyo Tawarkan Program Pendidikan Gratis...
# 5   pendidikan  Sugawa Akan Libatkan Ahli untuk Grand Design S...
# 6   pendidikan  Kuatkan Ekosistem Digital untuk Pendidikan Ber...
# 7   pendidikan  Pro Kontra Guru Cukur Rambut Murid, Ini Pandan...
# 8   pendidikan  Wajib Tahu! Ini Lima Program Jitu Pendidikan y...
# 9   pendidikan  Tingkatkan Pendidikan, Gus Par-Pandu Cetak Sat...
# 10  pendidikan  Telkomsel Lebih Dekat dengan Gen Z melalui by....
# 11  pendidikan  Suyadinata Disambut Antusias di Banjar Adat Be...
# 12  pendidikan  Koster-Giri akan Bangun Sports Center Bali di ...
# 13  pendidikan  Buntut Konflik Dua Yayasan Pendidikan di Taban...
# 14  pendidikan  Badung Education Fair 2024, Pj. Sekda Badung: ...
# 15  pendidikan  Kisah Aksi Heroik Joni, Si Pemanjat Tiang Bend...
# 16  pendidikan  Astra Daihatsu Motor Donasikan Mobil Perpustak...
# 17  pendidikan  Redea Institute: Nama Baru HighScope Indonesia...
# 18  pendidikan  Rektor Undiksha Kunjungi Shunan University dan...
#
#                                         cleaned_title  \
# 0    diar tawar pasraman singkat untuk didik karakter
# 1   winuntara sistem didik bangli era dana artadia...
# 2   kampanye di klungkung kostergiri janji kesehat...
# 3   tambadana janji beri pendidikanpelatihan bagi ...
# 4   raden cahyo tawar program didik gratisbuka jar...
# 5   sugawa akan libat ahli untuk grand design sing...
# 6   kuat ekosistem digital untuk didik lanjut di i...
# 7   pro kontra guru cukur rambut murid ini pandang...
# 8   wajib tahu ini lima program jitu didik yang ak...
# 9   tingkat didik gus parpandu cetak satu kk satu ...
# 10  telkomsel lebih dekat dengan gen z lalu byu da...
# 11  suyadinata sambut antusias di banjar adat bela...
# 12  kostergiri akan bangun sports center bal di ba...
# 13  buntut konflik dua yayasan didik di taban akhi...
# 14  badung education fair pj sekda badung tetap de...
# 15  kisah aksi heroik joni si panjat tiang bendera...
# 16  astra daihatsu motor donasi mobil pustaka dan ...
# 17  redea institute nama baru highscope indonesia ...
# 18  rektor undiksha kunjung shunan university dan ...
#
#                                               content  \
# 0   Calon wakil bupati (cawabup) Bangli nomor urut...
# 1   Calon wakil bupati (cawabup) Bangli nomor urut...
# 2   Calon gubernur dan wakil gubernur Bali nomor u...
# 3   Pasangan calon (paslon) nomor urut 1, I Nengah...
# 4   Calon bupati Bangli nomor urut 1, Raden Cahyo ...
# 5   Calon bupati (cabup) Buleleng nomor urut 1, Ny...
# 6                                           Teknologi
# 7                                          Pendidikan
# 8                                            Politika
# 9                                            Politika
# 10                                         Gaya Hidup
# 11                                           Politika
# 12                                           Politika
# 13                                            Tabanan
# 14                                             Badung
# 15                                          Peristiwa
# 16                                           Otomotif
# 17                                         Pendidikan
# 18                                         Pendidikan
#
#     sentiment_score_indonesia sentiment_category_indonesia
# 0                    0.993038                       netral
# 1                    0.944724                       netral
# 2                    0.975180                       netral
# 3                    0.994953                       netral
# 4                    0.997021                       netral
# 5                    0.955547                       netral
# 6                    0.633294                      positif
# 7                    0.991652                       netral
# 8                    0.985573                       netral
# 9                    0.997276                       netral
# 10                   0.913461                       netral
# 11                   0.946501                       netral
# 12                   0.853383                       netral
# 13                   0.987931                       netral
# 14                   0.991547                       netral
# 15                   0.921224                       netral
# 16                   0.989731                       netral
# 17                   0.991575                       netral
# 18                   0.917009                       netral

# %%
sentiment_counts2 = data_sentiment2['sentiment_category_indonesia'].value_counts()
sentiment_counts2
# Out:
# sentiment_category_indonesia
# netral     18
# positif     1
# Name: count, dtype: int64

# %%
import seaborn as sns

# Set the style of the plot using seaborn
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts2.index, y=sentiment_counts2.values, palette='viridis')

# Add labels and title
plt.title('Sentiment Category Distribution (Indonesia)', fontsize=16)
plt.xlabel('Sentiment Category', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Display the values on top of the bars
for i in range(len(sentiment_counts2)):
    plt.text(i, sentiment_counts2.values[i] + 0.5, 
             sentiment_counts2.values[i], 
             ha='center', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# #### Word Cloud (All and Based on Sentiment)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all text from the 'Churn_Reason' column into a single string
text = " ".join(cleaned_title for cleaned_title in data_sentiment2['cleaned_title'])

# Create a word cloud
wordcloud_indonesia = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_indonesia, interpolation='bilinear')
plt.axis('off')  # Remove axes
plt.show()

# %% [markdown]
# Based on Sentiment

# %%
# Sentimen Positif
if data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "positif"].shape[0] != 0:
    data_sentiment2_positif = data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "positif"]

    text = " ".join(cleaned_title for cleaned_title in data_sentiment2_positif['cleaned_title'])

    # Create a word cloud
    wordcloud_positif_indonesia = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_positif_indonesia, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen positif pada berita")

# %%
# Sentimen Negatif
if data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "negatif"].shape[0] != 0:
    data_sentiment2_negatif = data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "negatif"]

    text = " ".join(cleaned_title for cleaned_title in data_sentiment2_negatif['cleaned_title'])

    # Create a word cloud
    wordcloud_negatif_indonesia = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_negatif_indonesia, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen negatif pada berita")
# Out:
# Tidak ada sentimen negatif pada berita

# %%
# Sentimen Netral
if data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "netral"].shape[0] != 0:
    data_sentiment2_netral = data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "netral"]

    text = " ".join(cleaned_title for cleaned_title in data_sentiment2_netral['cleaned_title'])

    # Create a word cloud
    wordcloud_netral_indonesia = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_netral_indonesia, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen netral pada berita")

# %% [markdown]
# ### Export Result

# %%
print(data_sentiment1.shape)
data_sentiment1.head()
# Out:
# (19, 7)
#       keyword                                   title_translated  \
# 0  pendidikan  Diar offers a short pasraman for character edu...
# 1  pendidikan  Winuntara: The Bangli Era Sedana Arta-Diaru-Di...
# 2  pendidikan  Campaign in Klungkung, Koster-Giri promises fr...
# 3  pendidikan  Tamba-dana promise to give education-training ...
# 4  pendidikan  Raden Cahyo Offers Free Education Programs-Ope...
#
#                             cleaned_title_translated  sentiment_score_english  \
# 0  diar offer a short pasraman for character educ...                    0.000
# 1  winuntara the bangli era sedana artadiarudiaru...                    0.000
# 2  campaign in klungkung kostergiri promise free ...                    0.400
# 3  tambadana promise to give educationtraine for ...                   -0.125
# 4  raden cahyo offer free education programsopen ...                    0.400
#
#   sentiment_category_english  sentiment_score_english_vader  \
# 0                     Netral                         0.0000
# 1                     Netral                         0.1531
# 2                    Positif                         0.6808
# 3                    Negatif                         0.3182
# 4                    Positif                         0.5106
#
#   sentiment_category_english_vader
# 0                           Netral
# 1                          Positif
# 2                          Positif
# 3                          Positif
# 4                          Positif

# %%
print(data_sentiment2.shape)
data_sentiment2.head()
# Out:
# (19, 6)
#       keyword                                              title  \
# 0  pendidikan  Diar Tawarkan Pasraman Singkat untuk Pendidika...
# 1  pendidikan  Winuntara: Sistem Pendidikan Bangli Era Sedana...
# 2  pendidikan  Kampanye di Klungkung, Koster-Giri Janjikan Ke...
# 3  pendidikan  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...
# 4  pendidikan  Raden Cahyo Tawarkan Program Pendidikan Gratis...
#
#                                        cleaned_title  \
# 0   diar tawar pasraman singkat untuk didik karakter
# 1  winuntara sistem didik bangli era dana artadia...
# 2  kampanye di klungkung kostergiri janji kesehat...
# 3  tambadana janji beri pendidikanpelatihan bagi ...
# 4  raden cahyo tawar program didik gratisbuka jar...
#
#                                              content  \
# 0  Calon wakil bupati (cawabup) Bangli nomor urut...
# 1  Calon wakil bupati (cawabup) Bangli nomor urut...
# 2  Calon gubernur dan wakil gubernur Bali nomor u...
# 3  Pasangan calon (paslon) nomor urut 1, I Nengah...
# 4  Calon bupati Bangli nomor urut 1, Raden Cahyo ...
#
#    sentiment_score_indonesia sentiment_category_indonesia
# 0                   0.993038                       netral
# 1                   0.944724                       netral
# 2                   0.975180                       netral
# 3                   0.994953                       netral
# 4                   0.997021                       netral

# %%
# Assigning columns individually
sentiment_result = data_sentiment2.copy()  # Copy data_sentiment2 to avoid modifying the original

# Assign columns from data_sentiment1 to sentiment_result
sentiment_result['title_translated'] = data_sentiment1['title_translated']
sentiment_result['cleaned_title_translated'] = data_sentiment1['cleaned_title_translated']
sentiment_result['sentiment_category_english'] = data_sentiment1['sentiment_category_english']
sentiment_result['sentiment_score_english'] = data_sentiment1['sentiment_score_english']
sentiment_result['sentiment_category_english_vader'] = data_sentiment1['sentiment_category_english_vader']
sentiment_result['sentiment_score_english_vader'] = data_sentiment1['sentiment_score_english_vader']

print(sentiment_result.shape)
sentiment_result.head()
# Out:
# (19, 12)
#       keyword                                              title  \
# 0  pendidikan  Diar Tawarkan Pasraman Singkat untuk Pendidika...
# 1  pendidikan  Winuntara: Sistem Pendidikan Bangli Era Sedana...
# 2  pendidikan  Kampanye di Klungkung, Koster-Giri Janjikan Ke...
# 3  pendidikan  Tamba-Dana Janji Beri Pendidikan-Pelatihan bag...
# 4  pendidikan  Raden Cahyo Tawarkan Program Pendidikan Gratis...
#
#                                        cleaned_title  \
# 0   diar tawar pasraman singkat untuk didik karakter
# 1  winuntara sistem didik bangli era dana artadia...
# 2  kampanye di klungkung kostergiri janji kesehat...
# 3  tambadana janji beri pendidikanpelatihan bagi ...
# 4  raden cahyo tawar program didik gratisbuka jar...
#
#                                              content  \
# 0  Calon wakil bupati (cawabup) Bangli nomor urut...
# 1  Calon wakil bupati (cawabup) Bangli nomor urut...
# 2  Calon gubernur dan wakil gubernur Bali nomor u...
# 3  Pasangan calon (paslon) nomor urut 1, I Nengah...
# 4  Calon bupati Bangli nomor urut 1, Raden Cahyo ...
#
#    sentiment_score_indonesia sentiment_category_indonesia  \
# 0                   0.993038                       netral
# 1                   0.944724                       netral
# 2                   0.975180                       netral
# 3                   0.994953                       netral
# 4                   0.997021                       netral
#
#                                     title_translated  \
# 0  Diar offers a short pasraman for character edu...
# 1  Winuntara: The Bangli Era Sedana Arta-Diaru-Di...
# 2  Campaign in Klungkung, Koster-Giri promises fr...
# 3  Tamba-dana promise to give education-training ...
# 4  Raden Cahyo Offers Free Education Programs-Ope...
#
#                             cleaned_title_translated  \
# 0  diar offer a short pasraman for character educ...
# 1  winuntara the bangli era sedana artadiarudiaru...
# 2  campaign in klungkung kostergiri promise free ...
# 3  tambadana promise to give educationtraine for ...
# 4  raden cahyo offer free education programsopen ...
#
#   sentiment_category_english  sentiment_score_english  \
# 0                     Netral                    0.000
# 1                     Netral                    0.000
# 2                    Positif                    0.400
# 3                    Negatif                   -0.125
# 4                    Positif                    0.400
#
#   sentiment_category_english_vader  sentiment_score_english_vader
# 0                           Netral                         0.0000
# 1                          Positif                         0.1531
# 2                          Positif                         0.6808
# 3                          Positif                         0.3182
# 4                          Positif                         0.5106

# %%
sentiment_result.to_excel("C:/Users/asus/OneDrive/BPS/Neraca/sentimentresult_sektor15_triwulan4_bali.xlsx")
