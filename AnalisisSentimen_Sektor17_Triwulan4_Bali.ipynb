# %% [markdown]
# # **IMPORT PACKAGE**

# %%
import pandas as pd
import datetime
import os

# %% [markdown]
# # **DATA DEFINITION**

# %% [markdown]
# Pada bagian ini, dipetakan keyword yang akan digunakan untuk proses scrapping (per lapangan usaha), berikut juga dengan batasan waktu dari artikel yang ingin diambil. Di Badan Pusat Statistik, terdapat 17 sektor lapangan usaha, meliputi:
# 1.	Pertanian, Kehutanan, dan Perikanan
# 2.	Pertambangan dan Penggalian
# 3.	Industri Pengolahan
# 4.	Pengadaan Listrik, Gas
# 5.	Pengadaan Air, Pengelolaan Sampah, Limbah dan Daur Ulang
# 6.	Konstruksi
# 7.	Perdagangan Besar dan Eceran, Reparasi Mobil dan Sepeda Motor
# 8.	Transportasi dan Pergudangan
# 9.	Penyediaan Akomodasi dan Makan Minum
# 10.	Informasi dan Komunikasi
# 11.	Jasa Keuangan dan Asuransi
# 12.	Real Estat
# 13.	Jasa Perusahaan
# 14.	Administrasi Pemerintahan, Pertahanan dan Jaminan Sosial Wajib
# 15.	Jasa Pendidikan
# 16.	Jasa Kesehatan dan Kegiatan Sosial
# 17.	Jasa lainnya

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Tentukan keywords dari masing-masing lapangan usaha
key_sektor = ['tempat wisata','hiburan','guide']

keywords_scrap = key_sektor

# Tentukan rentang tanggal
start_date = datetime.date(2024, 10, 1)
end_date = datetime.date(2024, 11, 12)

# %% [markdown]
# # **SCRAPPING, PRE-CLEANING, & EXPORT (Scrapping BaliPost Lama)**

# %% [markdown]
# ## 1. BaliPost

# %% [markdown]
# Fungsi dan package untuk scrapping di balipost ada pada kode di chunk berikut \
# Aktifkan kalau pencarian di balipost sudah berjalan normal (saat kode ini dibuat sangat lambat)

# %%
# import requests
# from bs4 import BeautifulSoup
# import datetime
# import pandas as pd

# # Fungsi untuk melakukan scraping dari BaliPost
# def scrape_balipost(keyword, start_date, end_date, max_results, max_pages):
#     """
#     Fungsi untuk melakukan scraping artikel dari situs BaliPost berdasarkan keyword dan rentang tanggal.

#     Args:
#     - keyword (str): Keyword pencarian.
#     - start_date (datetime.date): Tanggal awal.
#     - end_date (datetime.date): Tanggal akhir.
#     - max_results (int): Maksimum jumlah artikel yang diambil.
#     - max_pages (int): Maksimum jumlah halaman yang diambil.

#     Returns:
#     - results (list): Daftar artikel yang berisi judul, link, tanggal, keyword, dan isi.
#     """
#     results = []

#     # Mengganti spasi dengan tanda "+" untuk keyword yang lebih dari satu kata
#     search_keyword = keyword.replace(" ", "+")
#     base_url = f"https://www.balipost.com/search/{search_keyword}"
#     current_page = 1

#     while len(results) < max_results and current_page <= max_pages:
#         url = f"{base_url}/page/{current_page}" if current_page > 1 else base_url
#         print(f"Scraping halaman {current_page} dari URL: {url}")
#         response = requests.get(url)

#         if response.status_code != 200:
#             print(f"Error saat mengakses halaman {current_page}. Status code: {response.status_code}")
#             break

#         soup = BeautifulSoup(response.content, "html.parser")
#         articles = soup.find_all("div", class_="td_module_10 td_module_wrap td-animation-stack")

#         if not articles:
#             print(f"Tidak ada artikel di halaman {current_page}, berhenti scraping.")
#             break

#         for article in articles:
#             title_element = article.find("h3", class_="entry-title td-module-title")
#             if title_element:
#                 title = title_element.text.strip()
#                 link = article.find("a")["href"]

#                 date_element = article.find("time", class_="entry-date updated td-module-date")
#                 if date_element:
#                     date_str = date_element["datetime"][:10]
#                     date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()

#                     # Cek apakah tanggal artikel dalam rentang yang diinginkan
#                     if not (start_date <= date <= end_date):
#                         continue

#                 content_element = article.find("div", class_="td-excerpt")
#                 content = content_element.text.strip() if content_element else ""

#                 results.append({"title": title, "keyword": keyword, "source": "BaliPost", "link": link, "date": date, "content": content})
#                 if len(results) >= max_results:
#                     break

#         pagination = soup.find("a", class_="page", title=str(current_page + 1))
#         if pagination:
#             current_page += 1
#         else:
#             break

#     return results

# %% [markdown]
# Memulai proses scrapping berita

# %%
# # Step 4: Scraping untuk setiap keyword
# # Takes a LOOOOOOOOOOOONG time

# all_news = []

# for keyword in keywords_scrap:
#     print(f"\nMemulai scraping untuk keyword: {keyword}")
#     news = scrape_balipost(keyword, start_date, end_date, max_results=25, max_pages=3)

#     # Tampilkan jumlah artikel yang berhasil diekstrak untuk keyword ini
#     num_articles = len(news)
#     print(f"Jumlah artikel yang diekstrak untuk keyword '{keyword}': {num_articles}")

#     all_news.extend(news)

# # Step 5: Simpan hasil ke dalam file Excel
# berita_balipost = pd.DataFrame(all_news)
# berita_balipost

# %%
# # Import melalui kode ini kalau sudah ada raw data scrapping BaliPost yang terpisah dari proses scrapping diatas (hanya untuk BaliPost)
# berita_balipost = pd.read_excel("C:/Users/asus/OneDrive/BPS/Neraca/berita_sektor17_triwulan4_bali.xlsx")
# berita_balipost

# %% [markdown]
# Pre-cleaning \
# Hasil Scrapping BaliPost harus difilter terlebih dahulu wilayah (dari isi konten) dan judulnya (kadang tidak sesuai dengan kata yang diinginkan) \
# Contoh: Kata kunci --> Ikan || Judul ditemukan --> DicarIKAN, DijanjIKAN

# %%
# # Keyword to filter out
# keywords_filter = ["TABANAN","SINGARAJA","DENPASAR","MANGUPURA","AMLAPURA","SEMARAPURA","NEGARA","GIANYAR","BANGLI"]

# # Build the condition for multiple keywords
# pattern = '|'.join(keywords_filter)  # Create a pattern that matches any of the keywords

# # Filter out rows where 'Description' contains the keyword
# berita_balipost_2 = pd.DataFrame(berita_balipost[berita_balipost['content'].str.contains(pattern, case=False, na=False)])

# # Show the filtered DataFrame
# print(berita_balipost_2.shape)
# berita_balipost_2

# %%
# # Build the regular expression pattern with word boundaries
# pattern_1 = r'\b(' + '|'.join(keywords_scrap) + r')\b'  # Ensures "Ikan" is a whole word

# # Filter rows where 'Title' contains the keyword as a whole word (case insensitive)
# berita_balipost_3 = berita_balipost_2[berita_balipost_2['title'].str.contains(pattern_1, case=False, na=False)]

# # Show the filtered DataFrame
# print(berita_balipost_3.shape)
# berita_balipost_3

# %%
# # Remove Duplication
# berita_balipost_3 = berita_balipost_3.drop_duplicates(subset='title', keep='first')
# print(berita_balipost_3.shape)
# berita_balipost_3

# %% [markdown]
# ## 2. DetikBali

# %%
import math
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# Define web scraping functions
# Fungsi untuk menuju ke portal berita
def search_url(query, date_start, date_end, pages_num=1):
    url = f"https://www.detik.com/search/searchnews?query={query}&siteid=123&sortby=time&fromdatex={date_start}&todatex={date_end}&page={pages_num}&result_type=relevansi"
    
    print(url)
    response = requests.get(url)
    page = bs(response.content, "html.parser")

    return page

# Fungsi untuk menghitung jumlah artikel di halaman terakhir
def last_page_article_count(query, date_start, date_end, page_num):
    last_page = search_url(query, date_start, date_end, page_num)
    article_list = last_page.find("div", {"class": "list-content"})

    if article_list:
        articles = article_list.find_all('article', class_='list-content__item')           
    article_count = len(articles)
    
    return article_count

def news_search_results(query, date_start, date_end):
    page = search_url(query, date_start, date_end)
    
    pagination = page.find("div", {"class": "pagination"})
    if pagination:
        page_numbers = pagination.find_all('a', class_='pagination__item')
        if page_numbers:
            last_page_number = int(page_numbers[-2].text)

        # Menghitung jumlah artikel di halaman terakhir
        last_page_articles = last_page_article_count(query, date_start, date_end, last_page_number)

        # Menghitung jumlah artikel yang diperoleh
        num = (last_page_number - 1) * 10 + last_page_articles
    else:
        num = 0
        last_page_number = 1
    
    return num, last_page_number

# Fungsi untuk mendapatkan isi konten
def news_get_content(article_url):
    response = requests.get(article_url)
    content_page = bs(response.content, "html.parser")

    content_list = []
    multiple_page = content_page.find("div", {"class": "detail__multiple"})
    if multiple_page:
        multiple_page = [x.get("href") for x in multiple_page.find_all("a")][:-1]
        for page in multiple_page:
            response = requests.get(page)
            content_page = bs(response.content, "html.parser")
            content_list.extend([p.get_text() for p in content_page.find_all("p") if not p.get_text().startswith('\n\n\n\nHalaman\n\n') and
                                p.get_text() not in ['',
                                                    '[Gambas:Instagram]',
                                                    '[Gambas:Video 20detik]',
                                                    '\r\nADVERTISEMENT\r\n',
                                                    '\r\n    ADVERTISEMENT\r\n',
                                                    '\r\n    ADVERTISEMENT\r\n  ',
                                                    '\r\n   ADVERTISEMENT\r\n  ',
                                                    '\r\n   ADVERTISEMENT\r\n',
                                                    '\r\n        SCROLL TO RESUME CONTENT\r\n  ',
                                                    'Selengkapnya di halaman selanjutnya.',
                                                    '\n\t\t\t\t\tAyo share cerita pengalaman dan upload photo album travelingmu di sini.\n\n\t\t\t\t\t\t\t\t\t\t\tSilakan Daftar atau Masuk\n']])
    else:
        content_list.extend([p.get_text() for p in content_page.find_all("p")
                            if p.get_text() not in ['',
                                                    '[Gambas:Instagram]',
                                                    '[Gambas:Video 20detik]',
                                                    '\r\nADVERTISEMENT\r\n',
                                                    '\r\n    ADVERTISEMENT\r\n',
                                                    '\r\n    ADVERTISEMENT\r\n  ',
                                                    '\r\n   ADVERTISEMENT\r\n  ',
                                                    '\r\n   ADVERTISEMENT\r\n',
                                                    '\r\n        SCROLL TO RESUME CONTENT\r\n  ',
                                                    '\n\t\t\t\t\tAyo share cerita pengalaman dan upload photo album travelingmu di sini.\n\n\t\t\t\t\t\t\t\t\t\t\tSilakan Daftar atau Masuk\n']])

    content_list = '\n\n'.join(content_list)

    return content_list

# Fungsi untuk mengecek berita yang merupakan advertorial
def news_advertorial_check(article_url):
    response = requests.get(article_url)
    content_page = bs(response.content, "html.parser")

    author = content_page.find("meta", {"content": "Advertorial"})

    return bool(author)

# Fungsi untuk mencari artikel dengan output adalah jumlah artikel dan halaman terakhir
def search_articles(query, from_date, to_date, ads_article, article_content):
    results_num, last_page = news_search_results(query, from_date, to_date)
        
    print(f"Result num: {results_num}")
    print(f"Last page: {last_page}")

    return results_num, last_page

# Fungsi untuk memperoleh list artikel
def articles_list(query, from_date, to_date, ads_article, article_content, num_articles, last_page):
    article_lists = []
    pages = math.ceil(num_articles / 10)
    
    print("\nMemulai Scrapping dari DetikBali untuk keyword:", query)
    for i in range(1, pages + 1):
        print("Scrapping halaman", i, "dari URL: ")
        page = search_url(query, from_date, to_date, i)
        articles = page.find_all("article", class_="list-content__item")

        for article in articles:
            title = article.find("a", {"class": "media__link"}).get('dtr-ttl')
            category = article.find('h2', class_='media__subtitle').text.strip()
            publish_date = article.find('span', title=True).get('title')
            article_url = article.find("a", {"class": "media__link"}).get('href')
                
            # print(f"Title: {title}")
            # print(f"Category: {category}")
            # print(f"Publish Date: {publish_date}")
            # print(f"Article URL: {article_url}")

            if ads_article and news_advertorial_check(article_url):
                continue
            else:
                if article_content:
                    content = news_get_content(article_url)
                    if (
                        any(title in existing_article["title"] for existing_article in article_lists) or 
                        any(content in existing_article["content"] for existing_article in article_lists)
                    ):
                        continue
                    else:
                        article_lists.append({
                            "title": title,
                            "keyword": query,
                            "source": category,
                            "link": article_url,
                            "date": publish_date,
                            "content": content
                        })
                else:
                    if any(title in existing_article["title"] for existing_article in article_lists):
                        continue
                    else:
                        article_lists.append({
                            "title": title,
                            "keyword": query,
                            "link": article_url,
                            "date": publish_date
                        })
            if len(article_lists) == num_articles:
                break
        if len(article_lists) == num_articles:
            break
            
    print(f"Jumlah artikel dengan kata kunci {keyword}: {len(article_lists)} artikel.")
    data = article_lists
    return data

# %%
# Scraping untuk setiap keyword
all_news_detik = []

for keyword in keywords_scrap:
    search_keyword = keyword.replace(" ", "+")
    news = articles_list(search_keyword, start_date.strftime('%d/%m/%Y'), end_date.strftime('%d/%m/%Y'), False, True, 25, 5)
    all_news_detik.extend(news)

# Simpan hasil ke dalam file Excel
berita_detik = pd.DataFrame(all_news_detik) 
berita_detik
# Out:
# Memulai Scrapping dari DetikBali untuk keyword: tempat+wisata
# Scrapping halaman 1 dari URL:
# https://www.detik.com/search/searchnews?query=tempat+wisata&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=1&result_type=relevansi
# Scrapping halaman 2 dari URL:
# https://www.detik.com/search/searchnews?query=tempat+wisata&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=2&result_type=relevansi
# Scrapping halaman 3 dari URL:
# https://www.detik.com/search/searchnews?query=tempat+wisata&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=3&result_type=relevansi
# Jumlah artikel dengan kata kunci tempat wisata: 25 artikel.
#
# Memulai Scrapping dari DetikBali untuk keyword: hiburan
# Scrapping halaman 1 dari URL:
# https://www.detik.com/search/searchnews?query=hiburan&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=1&result_type=relevansi
# Scrapping halaman 2 dari URL:
# https://www.detik.com/search/searchnews?query=hiburan&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=2&result_type=relevansi
# Scrapping halaman 3 dari URL:
# https://www.detik.com/search/searchnews?query=hiburan&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=3&result_type=relevansi
# Jumlah artikel dengan kata kunci hiburan: 25 artikel.
#
# Memulai Scrapping dari DetikBali untuk keyword: guide
# Scrapping halaman 1 dari URL:
# https://www.detik.com/search/searchnews?query=guide&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=1&result_type=relevansi
# Scrapping halaman 2 dari URL:
# https://www.detik.com/search/searchnews?query=guide&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=2&result_type=relevansi
# Scrapping halaman 3 dari URL:
# https://www.detik.com/search/searchnews?query=guide&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=3&result_type=relevansi
# Jumlah artikel dengan kata kunci guide: 6 artikel.
#                                                 title        keyword  \
# 0   Korban Erupsi Gunung Lewotobi Bisa Memilih Tem...  tempat+wisata
# 1   Usut Pembuang Bayi di Tempat Sampah, Polisi Pe...  tempat+wisata
# 2   Bali: Destinasi Wisata yang Kini Jadi Magnet I...  tempat+wisata
# 3   Rohmi Bakal Sulap Kawasan Pantai Mujang Jadi D...  tempat+wisata
# 4   Bandara Tutup Dua Hari, Sopir Wisata di Labuan...  tempat+wisata
# 5     Iqbal-Dinda Bakal Bikin KEK Wisata Halal di NTB  tempat+wisata
# 6   Polisi yang Terseret Narkoba di Tempat Karaoke...  tempat+wisata
# 7   Hujan hingga Macet Jadi Ancaman Distribusi Log...  tempat+wisata
# 8   Gibran Pastikan Pemerintah Hadir dalam Penanga...  tempat+wisata
# 9   Polisi yang Terciduk di Tempat Karaoke Positif...  tempat+wisata
# 10  Haerul Warisin Klaim Punya Akses Dekat dengan ...  tempat+wisata
# 11  Sutjidra Tawarkan Revitalisasi Terminal-Subsid...  tempat+wisata
# 12  Kapal Wisata Labuan Bajo Waspadai Abu Vulkanik...  tempat+wisata
# 13  Song Jae Rim Diduga Bunuh Diri, Ditemukan Sura...  tempat+wisata
# 14  Polemik Tarif Mancing Rp 5 Juta TN Komodo-Dito...  tempat+wisata
# 15  Alex Funay-Isyak Nuka Berjanji Bangun 1.000 Ru...  tempat+wisata
# 16   KPU NTB Siapkan 25 TPS Khusus untuk Pilkada 2024  tempat+wisata
# 17  Pengawasan Tempat Pembuangan Sampah di Denpasa...  tempat+wisata
# 18  Temui Wamenpar Ni Luh Puspa, Parta Sebut Wisat...  tempat+wisata
# 19  2 Warung-Tempat Penetasan Penyu di Buleleng Ru...  tempat+wisata
# 20  Cabuli Dua Anak Tetangga, Kuli Bangunan Teranc...  tempat+wisata
# 21  Jelang Pilkada Serentak 2024, Pulau Sumbawa Pa...  tempat+wisata
# 22  Komitmen Mulyadi Bangun Desa Wisata hingga Ter...  tempat+wisata
# 23  Temesi Waterfall: Wisata Negeri Dongeng yang A...  tempat+wisata
# 24  Kemenparekraf Kembangkan Pengelolaan Desa Wisa...  tempat+wisata
# 25  Song Jae Rim Diduga Bunuh Diri, Ditemukan Sura...        hiburan
# 26  Polisi Razia Kelab Malam di Kupang, Pemandu La...        hiburan
# 27  Carmen, Gadis Bali Jadi Perhatian Dunia KPop: ...        hiburan
# 28  Momen Prabowo dan Mayor Teddy Nyanyi 'Cucak Ro...        hiburan
# 29  Akademisi UGM Soroti Kurangnya Peran Pemerinta...        hiburan
# 30               Jokowi Tak Ingin IKN Jadi Kota Hantu        hiburan
# 31  Proyek Dermaga Masuk Program Unggulan Gus Par-...        hiburan
# 32  Kasus Korupsi Pemanfaatan Lahan NTB Convention...        hiburan
# 33          Kabar Duka, Marissa Haque Meninggal Dunia        hiburan
# 34  Profil Marissa Haque yang Pernah Jadi Brand Am...        hiburan
# 35  Perusahaan Cucu Soeharto Pinjam Duit Rp 500 M ...        hiburan
# 36  Momen Bule Ikut Lomba Tradisional di Nusa Peni...        hiburan
# 37  Nusa Penida Festival 2024 Sedot 22 Ribu Lebih ...        hiburan
# 38  Belajar Sejarah Kota Kupang Melalui Pameran Me...        hiburan
# 39  6 Penyebab YouTube Tidak Bisa Dibuka di HP dan...        hiburan
# 40  Apa Itu Gelar Honoris Causa? Ini Syarat dan Ta...        hiburan
# 41  Viral Penari Erotis di Plaza Karaoke Mataram, ...        hiburan
# 42  Polda NTB Selidiki Dugaan Penari Erotis di Pla...        hiburan
# 43            Adu Layanan Sleeper Bus di Pulau Dewata        hiburan
# 44  Stuja di Pantai, Kafe Estetik di Bali dengan P...        hiburan
# 45  Frank's Family Terror, Wahana Horor Jelang Hal...        hiburan
# 46  Quartararo Jatuh Cinta dengan Bali-Finns Pesta...        hiburan
# 47  Jadwal Tayang TY Track In Cinemas di Bioskop 1...        hiburan
# 48  Tak Hanya Kembang Api, Warga Berawa juga Keluh...        hiburan
# 49  Viral Pesta Kembang Api Saat Upacara Hindu, MD...        hiburan
# 50  Tour Guide: Turis Kerap Keluhkan Tak Ada Toile...          guide
# 51  Hilang Saat Menyelam, Potongan Tubuh WN AS Dit...          guide
# 52  Loker Bali 6 Oktober 2024, Cek Selengkapnya Di...          guide
# 53  1.000 Penari Rejang Renteng Pukau Turis Asing ...          guide
# 54  Pilu Orang Tua dari Jakarta Jemput Jenazah Ana...          guide
# 55  Belajar Sejarah Kota Kupang Melalui Pameran Me...          guide
#
#        source                                               link  \
# 0   detikBali  https://www.detik.com/bali/nusra/d-7634475/kor...
# 1   detikBali  https://www.detik.com/bali/hukum-dan-kriminal/...
# 2   detikBali  https://www.detik.com/bali/bisnis/d-7632526/ba...
# 3   detikBali  https://www.detik.com/bali/pilkada/d-7633755/r...
# 4   detikBali  https://www.detik.com/bali/nusra/d-7631753/ban...
# 5   detikBali  https://www.detik.com/bali/pilkada/d-7629440/i...
# 6   detikBali  https://www.detik.com/bali/hukum-dan-kriminal/...
# 7   detikBali  https://www.detik.com/bali/pilkada/d-7635495/h...
# 8   detikBali  https://www.detik.com/bali/nusra/d-7635564/gib...
# 9   detikBali  https://www.detik.com/bali/hukum-dan-kriminal/...
# 10  detikBali  https://www.detik.com/bali/pilkada/d-7635432/h...
# 11  detikBali  https://www.detik.com/bali/pilkada/d-7635544/s...
# 12  detikBali  https://www.detik.com/bali/nusra/d-7623539/kap...
# 13  detikBali  https://www.detik.com/bali/berita/d-7635398/so...
# 14  detikBali  https://www.detik.com/bali/nusra/d-7619750/pol...
# 15  detikBali  https://www.detik.com/bali/pilkada/d-7619326/a...
# 16  detikBali  https://www.detik.com/bali/pilkada/d-7635197/k...
# 17  detikBali  https://www.detik.com/bali/berita/d-7569064/pe...
# 18  detikBali  https://www.detik.com/bali/berita/d-7618670/te...
# 19  detikBali  https://www.detik.com/bali/berita/d-7617679/2-...
# 20  detikBali  https://www.detik.com/bali/hukum-dan-kriminal/...
# 21  detikBali  https://www.detik.com/bali/pilkada/d-7634944/j...
# 22  detikBali  https://www.detik.com/bali/pilkada/d-7616497/k...
# 23  detikBali  https://www.detik.com/bali/wisata/d-7583382/te...
# 24  detikBali  https://www.detik.com/bali/berita/d-7579301/ke...
# 25  detikBali  https://www.detik.com/bali/berita/d-7635398/so...
# 26  detikBali  https://www.detik.com/bali/hukum-dan-kriminal/...
# 27  detikBali  https://www.detik.com/bali/bali-bungah/d-76302...
# 28  detikBali  https://www.detik.com/bali/pilkada/d-7620143/m...
# 29  detikBali  https://www.detik.com/bali/berita/d-7613187/ak...
# 30  detikBali  https://www.detik.com/bali/berita/d-7577021/jo...
# 31  detikBali  https://www.detik.com/bali/berita/d-7608906/pr...
# 32  detikBali  https://www.detik.com/bali/hukum-dan-kriminal/...
# 33  detikBali  https://www.detik.com/bali/berita/d-7567769/ka...
# 34  detikBali  https://www.detik.com/bali/berita/d-7569677/pr...
# 35  detikBali  https://www.detik.com/bali/berita/d-7613349/pe...
# 36  detikBali  https://www.detik.com/bali/wisata/d-7585879/mo...
# 37  detikBali  https://www.detik.com/bali/wisata/d-7585525/nu...
# 38  detikBali  https://www.detik.com/bali/wisata/d-7609232/be...
# 39  detikBali  https://www.detik.com/bali/berita/d-7581412/6-...
# 40  detikBali  https://www.detik.com/bali/berita/d-7576322/ap...
# 41  detikBali  https://www.detik.com/bali/hukum-dan-kriminal/...
# 42  detikBali  https://www.detik.com/bali/hukum-dan-kriminal/...
# 43  detikBali  https://www.detik.com/bali/bisnis/d-7583556/ad...
# 44  detikBali  https://www.detik.com/bali/wisata/d-7606891/st...
# 45  detikBali  https://www.detik.com/bali/wisata/d-7599907/fr...
# 46  detikBali  https://www.detik.com/bali/berita/d-7597243/qu...
# 47  detikBali  https://www.detik.com/bali/berita/d-7593377/ja...
# 48  detikBali  https://www.detik.com/bali/berita/d-7591503/ta...
# 49  detikBali  https://www.detik.com/bali/berita/d-7593079/vi...
# 50  detikBali  https://www.detik.com/bali/nusra/d-7597473/tou...
# 51  detikBali  https://www.detik.com/bali/berita/d-7580618/hi...
# 52  detikBali  https://www.detik.com/bali/berita/d-7573956/lo...
# 53  detikBali  https://www.detik.com/bali/wisata/d-7581302/1-...
# 54  detikBali  https://www.detik.com/bali/nusra/d-7582101/pil...
# 55  detikBali  https://www.detik.com/bali/wisata/d-7609232/be...
#
#                              date  \
# 0   Selasa, 12 Nov 2024 12:21 WIB
# 1   Selasa, 12 Nov 2024 10:51 WIB
# 2    Senin, 11 Nov 2024 11:29 WIB
# 3    Senin, 11 Nov 2024 21:11 WIB
# 4   Minggu, 10 Nov 2024 19:09 WIB
# 5    Jumat, 08 Nov 2024 21:11 WIB
# 6   Selasa, 05 Nov 2024 11:27 WIB
# 7   Selasa, 12 Nov 2024 21:00 WIB
# 8   Selasa, 12 Nov 2024 22:24 WIB
# 9    Jumat, 01 Nov 2024 21:47 WIB
# 10  Selasa, 12 Nov 2024 20:14 WIB
# 11  Selasa, 12 Nov 2024 21:50 WIB
# 12  Selasa, 05 Nov 2024 16:08 WIB
# 13  Selasa, 12 Nov 2024 19:47 WIB
# 14  Minggu, 03 Nov 2024 11:16 WIB
# 15   Sabtu, 02 Nov 2024 20:44 WIB
# 16  Selasa, 12 Nov 2024 18:05 WIB
# 17    Rabu, 02 Okt 2024 18:09 WIB
# 18   Sabtu, 02 Nov 2024 12:15 WIB
# 19   Jumat, 01 Nov 2024 16:53 WIB
# 20  Selasa, 12 Nov 2024 16:21 WIB
# 21  Selasa, 12 Nov 2024 16:05 WIB
# 22   Kamis, 31 Okt 2024 21:56 WIB
# 23   Jumat, 11 Okt 2024 19:15 WIB
# 24    Rabu, 09 Okt 2024 12:25 WIB
# 25  Selasa, 12 Nov 2024 19:47 WIB
# 26   Sabtu, 09 Nov 2024 17:23 WIB
# 27   Sabtu, 09 Nov 2024 16:10 WIB
# 28  Minggu, 03 Nov 2024 16:35 WIB
# 29    Rabu, 30 Okt 2024 09:06 WIB
# 30   Senin, 07 Okt 2024 22:28 WIB
# 31  Minggu, 27 Okt 2024 16:50 WIB
# 32   Kamis, 03 Okt 2024 15:11 WIB
# 33    Rabu, 02 Okt 2024 07:13 WIB
# 34   Kamis, 03 Okt 2024 09:57 WIB
# 35    Rabu, 30 Okt 2024 10:49 WIB
# 36  Minggu, 13 Okt 2024 16:50 WIB
# 37  Minggu, 13 Okt 2024 12:10 WIB
# 38  Minggu, 27 Okt 2024 20:33 WIB
# 39   Jumat, 11 Okt 2024 05:30 WIB
# 40  Selasa, 08 Okt 2024 06:30 WIB
# 41   Kamis, 24 Okt 2024 09:48 WIB
# 42    Rabu, 23 Okt 2024 18:12 WIB
# 43   Jumat, 11 Okt 2024 16:55 WIB
# 44   Jumat, 25 Okt 2024 22:35 WIB
# 45  Selasa, 22 Okt 2024 00:24 WIB
# 46  Minggu, 20 Okt 2024 13:48 WIB
# 47   Jumat, 18 Okt 2024 06:30 WIB
# 48    Rabu, 16 Okt 2024 22:08 WIB
# 49   Kamis, 17 Okt 2024 19:04 WIB
# 50  Minggu, 20 Okt 2024 15:55 WIB
# 51   Kamis, 10 Okt 2024 06:22 WIB
# 52  Minggu, 06 Okt 2024 00:30 WIB
# 53   Kamis, 10 Okt 2024 13:33 WIB
# 54   Kamis, 10 Okt 2024 19:31 WIB
# 55  Minggu, 27 Okt 2024 20:33 WIB
#
#                                               content
# 0   Badan Nasional Penanggulangan Bencana (BNPB) m...
# 1   Kasus penemuan jasad bayi perempuan pada tumpu...
# 2   Pulau Bali kini tidak hanya dikenal sebagai de...
# 3   Calon gubernur (cagub) Nusa Tenggara Barat (NT...
# 4   Sopir angkutan wisata di Labuan Bajo, Manggara...
# 5   Pasangan calon (paslon) Lalu Muhammad Iqbal-In...
# 6   Polda Bali menahan Bripka R, yang terseret nar...
# 7   Musim hujan pada November jadi ancaman kelanca...
# 8   Wakil Presiden Gibran Rakabuming Raka memberik...
# 9   Polisi yang terciduk di tempat karaoke positif...
# 10  Calon bupati Lombok Timur nomor urut 2, Haerul...
# 11  Calon bupati Buleleng nomor urut 2 Nyoman Sutj...
# 12  Kantor Kesyahbandaran dan Otoritas Pelabuhan (...
# 13  Informasi berikut ini tidak ditujukan untuk me...
# 14  Kenaikan tarif memancing di perairan Taman Nas...
# 15  Calon wali kota (cawalkot) Kupang nomor urut s...
# 16  Komisi Pemilihan Umum (KPU) Nusa Tenggara Bara...
# 17  Seluruh tempat pembuangan sampah sementara (TP...
# 18  Anggota Dewan Perwakilan Rakyat (DPR) RI asal ...
# 19  Dua warung dan sebuah bangunan penetasan penyu...
# 20  Seorang kuli bangunan bernama Toni Hari Siswan...
# 21  Komisi Pemilihan Umum (KPU) Nusa Tenggara Bara...
# 22  Calon bupati Tabanan nomor urut 1, I Nyoman Mu...
# 23  Setiap orang memiliki preferensi wisata yang b...
# 24  Kementerian Pariwisata dan Ekonomi Kreatif (Ke...
# 25  Informasi berikut ini tidak ditujukan untuk me...
# 26  Seorang pemandu lagu asal Banten berinisial AR...
# 27  Dalam beberapa tahun terakhir, semakin banyak ...
# 28  Presiden Prabowo Subianto dan Sekretaris Kabin...
# 29  Konflik antara Finns Beach Club dan masyarakat...
# 30  Presiden Joko Widodo (Jokowi) ingin agar keram...
# 31  Pasangan calon (paslon) bupati dan wakil bupat...
# 32  Kasus dugaan korupsi pemanfaatan lahan NTB Con...
# 33  Kabar duka datang dari dunia hiburan tanah air...
# 34  Marissa Grace Haque meninggalkan jejak karier ...
# 35  PT Intra Golflink Resorts Tbk (GOLF) melalui a...
# 36  Nusa Penida Festival (NPF) 2024, yang merupaka...
# 37  Penjabat (Pj) Bupati Klungkung, I Nyoman Jendr...
# 38  Kota Kupang memiliki sejarah yang kaya akan tr...
# 39  Saat ini, YouTube telah menjadi salah satu pla...
# 40  Masih ramai di media sosial tentang pemberian ...
# 41  Video yang merekam penari erotis beraksi di sa...
# 42  Kepolisian Daerah Nusa Tenggara Barat (Polda N...
# 43  Sleeper bus atau bus rebah mulai marak selepas...
# 44  Berkunjung ke Pulau Bali kurang lengkap jika t...
# 45  Wahana hiburan di Trans Studio Bali semakin be...
# 46  Sejumlah berita mendapatkan sorotan dari pemba...
# 47  Penggemar K-pop dan Taeyong NCT siap-siap disu...
# 48  Warga di kawasan Berawa, Kuta Utara, Badung, B...
# 49  Patajuh Bandesa Agung Bidang Kerja Sama, Infor...
# 50  Wisatawan yang berkunjung ke Long Pink Beach d...
# 51  Potongan tubuh warga negara (WN) Amerika Serik...
# 52  Bagi kamu para pencari kerja di Bali, simak lo...
# 53  Sebanyak 1.000 penari rejang renteng memukau t...
# 54  Jenazah Kaifad Rafi Mubarok (16), pendaki asal...
# 55  Kota Kupang memiliki sejarah yang kaya akan tr...

# %% [markdown]
# Pre-cleaning

# %%
# Filter Wilayah
keywords_filter = ["Tabanan","Singaraja","Denpasar","Badung","Karangasem","Klungkung","Jembrana","Gianyar","Bangli"]

# Build the condition for multiple keywords
pattern = '|'.join(keywords_filter)  # Create a pattern that matches any of the keywords

# Filter out rows where 'Description' contains the keyword
berita_detik_2 = pd.DataFrame(berita_detik[berita_detik['content'].str.contains(pattern, case=False, na=False)])

# Show the filtered DataFrame
print(berita_detik_2.shape)
berita_detik_2
# Out:
# (23, 6)
#                                                 title        keyword  \
# 6   Polisi yang Terseret Narkoba di Tempat Karaoke...  tempat+wisata
# 7   Hujan hingga Macet Jadi Ancaman Distribusi Log...  tempat+wisata
# 9   Polisi yang Terciduk di Tempat Karaoke Positif...  tempat+wisata
# 11  Sutjidra Tawarkan Revitalisasi Terminal-Subsid...  tempat+wisata
# 17  Pengawasan Tempat Pembuangan Sampah di Denpasa...  tempat+wisata
# 20  Cabuli Dua Anak Tetangga, Kuli Bangunan Teranc...  tempat+wisata
# 22  Komitmen Mulyadi Bangun Desa Wisata hingga Ter...  tempat+wisata
# 23  Temesi Waterfall: Wisata Negeri Dongeng yang A...  tempat+wisata
# 24  Kemenparekraf Kembangkan Pengelolaan Desa Wisa...  tempat+wisata
# 28  Momen Prabowo dan Mayor Teddy Nyanyi 'Cucak Ro...        hiburan
# 29  Akademisi UGM Soroti Kurangnya Peran Pemerinta...        hiburan
# 31  Proyek Dermaga Masuk Program Unggulan Gus Par-...        hiburan
# 35  Perusahaan Cucu Soeharto Pinjam Duit Rp 500 M ...        hiburan
# 36  Momen Bule Ikut Lomba Tradisional di Nusa Peni...        hiburan
# 37  Nusa Penida Festival 2024 Sedot 22 Ribu Lebih ...        hiburan
# 43            Adu Layanan Sleeper Bus di Pulau Dewata        hiburan
# 44  Stuja di Pantai, Kafe Estetik di Bali dengan P...        hiburan
# 46  Quartararo Jatuh Cinta dengan Bali-Finns Pesta...        hiburan
# 47  Jadwal Tayang TY Track In Cinemas di Bioskop 1...        hiburan
# 48  Tak Hanya Kembang Api, Warga Berawa juga Keluh...        hiburan
# 49  Viral Pesta Kembang Api Saat Upacara Hindu, MD...        hiburan
# 52  Loker Bali 6 Oktober 2024, Cek Selengkapnya Di...          guide
# 53  1.000 Penari Rejang Renteng Pukau Turis Asing ...          guide
#
#        source                                               link  \
# 6   detikBali  https://www.detik.com/bali/hukum-dan-kriminal/...
# 7   detikBali  https://www.detik.com/bali/pilkada/d-7635495/h...
# 9   detikBali  https://www.detik.com/bali/hukum-dan-kriminal/...
# 11  detikBali  https://www.detik.com/bali/pilkada/d-7635544/s...
# 17  detikBali  https://www.detik.com/bali/berita/d-7569064/pe...
# 20  detikBali  https://www.detik.com/bali/hukum-dan-kriminal/...
# 22  detikBali  https://www.detik.com/bali/pilkada/d-7616497/k...
# 23  detikBali  https://www.detik.com/bali/wisata/d-7583382/te...
# 24  detikBali  https://www.detik.com/bali/berita/d-7579301/ke...
# 28  detikBali  https://www.detik.com/bali/pilkada/d-7620143/m...
# 29  detikBali  https://www.detik.com/bali/berita/d-7613187/ak...
# 31  detikBali  https://www.detik.com/bali/berita/d-7608906/pr...
# 35  detikBali  https://www.detik.com/bali/berita/d-7613349/pe...
# 36  detikBali  https://www.detik.com/bali/wisata/d-7585879/mo...
# 37  detikBali  https://www.detik.com/bali/wisata/d-7585525/nu...
# 43  detikBali  https://www.detik.com/bali/bisnis/d-7583556/ad...
# 44  detikBali  https://www.detik.com/bali/wisata/d-7606891/st...
# 46  detikBali  https://www.detik.com/bali/berita/d-7597243/qu...
# 47  detikBali  https://www.detik.com/bali/berita/d-7593377/ja...
# 48  detikBali  https://www.detik.com/bali/berita/d-7591503/ta...
# 49  detikBali  https://www.detik.com/bali/berita/d-7593079/vi...
# 52  detikBali  https://www.detik.com/bali/berita/d-7573956/lo...
# 53  detikBali  https://www.detik.com/bali/wisata/d-7581302/1-...
#
#                              date  \
# 6   Selasa, 05 Nov 2024 11:27 WIB
# 7   Selasa, 12 Nov 2024 21:00 WIB
# 9    Jumat, 01 Nov 2024 21:47 WIB
# 11  Selasa, 12 Nov 2024 21:50 WIB
# 17    Rabu, 02 Okt 2024 18:09 WIB
# 20  Selasa, 12 Nov 2024 16:21 WIB
# 22   Kamis, 31 Okt 2024 21:56 WIB
# 23   Jumat, 11 Okt 2024 19:15 WIB
# 24    Rabu, 09 Okt 2024 12:25 WIB
# 28  Minggu, 03 Nov 2024 16:35 WIB
# 29    Rabu, 30 Okt 2024 09:06 WIB
# 31  Minggu, 27 Okt 2024 16:50 WIB
# 35    Rabu, 30 Okt 2024 10:49 WIB
# 36  Minggu, 13 Okt 2024 16:50 WIB
# 37  Minggu, 13 Okt 2024 12:10 WIB
# 43   Jumat, 11 Okt 2024 16:55 WIB
# 44   Jumat, 25 Okt 2024 22:35 WIB
# 46  Minggu, 20 Okt 2024 13:48 WIB
# 47   Jumat, 18 Okt 2024 06:30 WIB
# 48    Rabu, 16 Okt 2024 22:08 WIB
# 49   Kamis, 17 Okt 2024 19:04 WIB
# 52  Minggu, 06 Okt 2024 00:30 WIB
# 53   Kamis, 10 Okt 2024 13:33 WIB
#
#                                               content
# 6   Polda Bali menahan Bripka R, yang terseret nar...
# 7   Musim hujan pada November jadi ancaman kelanca...
# 9   Polisi yang terciduk di tempat karaoke positif...
# 11  Calon bupati Buleleng nomor urut 2 Nyoman Sutj...
# 17  Seluruh tempat pembuangan sampah sementara (TP...
# 20  Seorang kuli bangunan bernama Toni Hari Siswan...
# 22  Calon bupati Tabanan nomor urut 1, I Nyoman Mu...
# 23  Setiap orang memiliki preferensi wisata yang b...
# 24  Kementerian Pariwisata dan Ekonomi Kreatif (Ke...
# 28  Presiden Prabowo Subianto dan Sekretaris Kabin...
# 29  Konflik antara Finns Beach Club dan masyarakat...
# 31  Pasangan calon (paslon) bupati dan wakil bupat...
# 35  PT Intra Golflink Resorts Tbk (GOLF) melalui a...
# 36  Nusa Penida Festival (NPF) 2024, yang merupaka...
# 37  Penjabat (Pj) Bupati Klungkung, I Nyoman Jendr...
# 43  Sleeper bus atau bus rebah mulai marak selepas...
# 44  Berkunjung ke Pulau Bali kurang lengkap jika t...
# 46  Sejumlah berita mendapatkan sorotan dari pemba...
# 47  Penggemar K-pop dan Taeyong NCT siap-siap disu...
# 48  Warga di kawasan Berawa, Kuta Utara, Badung, B...
# 49  Patajuh Bandesa Agung Bidang Kerja Sama, Infor...
# 52  Bagi kamu para pencari kerja di Bali, simak lo...
# 53  Sebanyak 1.000 penari rejang renteng memukau t...

# %%
# Build the regular expression pattern with word boundaries
pattern = r'\b(' + '|'.join(keywords_scrap) + r')\b'

# Filter rows where 'Title' contains the keyword as a whole word (case insensitive)
berita_detik_3 = berita_detik_2[berita_detik_2['title'].str.contains(pattern, case=False, na=False)]

# Show the filtered DataFrame
print(berita_detik_3.shape)
berita_detik_3
# Out:
# (0, 6)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11996\1307647291.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   berita_detik_3 = berita_detik_2[berita_detik_2['title'].str.contains(pattern, case=False, na=False)]
# Empty DataFrame
# Columns: [title, keyword, source, link, date, content]
# Index: []

# %% [markdown]
# Menghapus berita yang duplikat

# %%
# Remove Duplication
berita_detik_4 = berita_detik_3.drop_duplicates(subset='title', keep='first')
print(berita_detik_4.shape)
berita_detik_4
# Out:
# (0, 6)
# Empty DataFrame
# Columns: [title, keyword, source, link, date, content]
# Index: []

# %% [markdown]
# ## 3. RadarBali

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
from datetime import datetime

# Tanggal batas yang ingin dibandingkan
start_date = datetime(2024, 10, 1)  # 1 Oktober 2024
end_date = datetime(2024, 12, 31)  # 31 Desember 2024

# Inisialisasi driver Chrome tanpa mengunduh chromedriver secara manual
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)
# Fungsi untuk melakukan scraping dan mengambil isian kelas latest__subtitle, latest__link, dan latest__date
def get_news(query, start_page, end_page):
    results = []

    print("\nMemulai scrapping RadarBali untuk keyword:", query)
    for page in range(start_page, end_page + 1):
        url = f"https://radarbali.jawapos.com/search?q={query}&sort=latest&page={page}"
        print("Scrapping halaman",page,"dari URL:",url)
        driver.get(url)
        time.sleep(10)  # Tunggu beberapa detik agar halaman selesai dimuat

        # Ambil konten halaman dan buat objek BeautifulSoup
        soup = BeautifulSoup(driver.page_source, "html.parser")

        # Ambil semua elemen dengan class latest__item
        articles = soup.find_all('div', class_='latest__item')

        # Ambil informasi dari setiap artikel
        for article in articles:
            subtitle = article.find('h4', class_='latest__subtitle')
            title = article.find('a', class_='latest__link')
            link = article.find('a', class_='latest__link')['href']
            date = article.find('date', class_='latest__date')

            # Menampilkan hasil jika elemen ditemukan, filter tanggal sesuai yang diinginkan
            if subtitle and title and date:
                date_berita = date.get_text(strip=True)

                # Fungsi untuk mengonversi nama bulan menjadi angka bulan
                def get_month_number(month_name):
                    months = {
                        "Januari": 1,
                        "Februari": 2,
                        "Maret": 3,
                        "April": 4,
                        "Mei": 5,
                        "Juni": 6,
                        "Juli": 7,
                        "Agustus": 8,
                        "September": 9,
                        "Oktober": 10,
                        "November": 11,
                        "Desember": 12
                    }
                    return months.get(month_name)

                # Fungsi untuk mem-parsing tanggal dalam format yang diberikan
                def parse_date(date_str):
                    # Pisahkan hari dan waktu
                    day_part, time_part = date_str.split(" | ")

                    # Ambil tanggal dan bulan dari bagian day_part
                    day_name, day, month_name, year = day_part.split()
                    day = int(day)
                    year = int(year)
                    month = get_month_number(month_name)
                    
                    # Gabungkan menjadi format yang bisa diproses oleh datetime
                    # Format waktu seperti '21:46 WIB', jadi kita hanya perlu ambil jam dan menit
                    time = time_part.replace(" WIB", "")

                    # Gabungkan semuanya ke format yang sesuai dengan datetime
                    date_string = f"{year}-{month:02d}-{day:02d} {time}"

                    # Mengonversi ke objek datetime
                    return datetime.strptime(date_string, "%Y-%m-%d %H:%M")
            
                parsed_date = parse_date(date_berita)

                # Membandingkan apakah parsed_date berada dalam rentang 1 Oktober 2024 sampai 31 Desember 2024
                if start_date <= parsed_date <= end_date:
                    results.append({"title": title.get_text(strip=True), "keyword": query, "source": "RadarBali", "link": link, "date": date.get_text(strip=True), "content": subtitle.get_text(strip=True)})
                    # print("Subtitle:", subtitle.get_text(strip=True))
                    # print("Title:", title.get_text(strip=True))
                    # print("Link:", link)
                    # print("Date:", date.get_text(strip=True))
                    # print('-' * 80)
                else:
                    break

    return results

import pandas as pd

all_news_radarbali = []

for keyword in keywords_scrap:
    search_keyword = keyword.replace(" ", "+")
    news = get_news(search_keyword, start_page=1, end_page=5)

    # Tampilkan jumlah artikel yang berhasil diekstrak untuk keyword ini
    num_articles = len(news)
    print(f"Jumlah artikel yang diekstrak untuk keyword '{keyword}': {num_articles}")

    all_news_radarbali.extend(news)

driver.quit()
# Out:
# Memulai scrapping RadarBali untuk keyword: tempat+wisata
# Scrapping halaman 1 dari URL: https://radarbali.jawapos.com/search?q=tempat+wisata&sort=latest&page=1
# Scrapping halaman 2 dari URL: https://radarbali.jawapos.com/search?q=tempat+wisata&sort=latest&page=2
# Scrapping halaman 3 dari URL: https://radarbali.jawapos.com/search?q=tempat+wisata&sort=latest&page=3
# Scrapping halaman 4 dari URL: https://radarbali.jawapos.com/search?q=tempat+wisata&sort=latest&page=4
# Scrapping halaman 5 dari URL: https://radarbali.jawapos.com/search?q=tempat+wisata&sort=latest&page=5
# Jumlah artikel yang diekstrak untuk keyword 'tempat wisata': 50
#
# Memulai scrapping RadarBali untuk keyword: hiburan
# Scrapping halaman 1 dari URL: https://radarbali.jawapos.com/search?q=hiburan&sort=latest&page=1
# Scrapping halaman 2 dari URL: https://radarbali.jawapos.com/search?q=hiburan&sort=latest&page=2
# Scrapping halaman 3 dari URL: https://radarbali.jawapos.com/search?q=hiburan&sort=latest&page=3
# Scrapping halaman 4 dari URL: https://radarbali.jawapos.com/search?q=hiburan&sort=latest&page=4
# Scrapping halaman 5 dari URL: https://radarbali.jawapos.com/search?q=hiburan&sort=latest&page=5
# Jumlah artikel yang diekstrak untuk keyword 'hiburan': 9
#
# Memulai scrapping RadarBali untuk keyword: guide
# Scrapping halaman 1 dari URL: https://radarbali.jawapos.com/search?q=guide&sort=latest&page=1
# Scrapping halaman 2 dari URL: https://radarbali.jawapos.com/search?q=guide&sort=latest&page=2
# Scrapping halaman 3 dari URL: https://radarbali.jawapos.com/search?q=guide&sort=latest&page=3
# Scrapping halaman 4 dari URL: https://radarbali.jawapos.com/search?q=guide&sort=latest&page=4
# Scrapping halaman 5 dari URL: https://radarbali.jawapos.com/search?q=guide&sort=latest&page=5
# Jumlah artikel yang diekstrak untuk keyword 'guide': 0

# %%
berita_radarbali = pd.DataFrame(all_news_radarbali)
berita_radarbali
# Out:
#                                                 title        keyword  \
# 0   Bluecross International Lakukan Topping Off, J...  tempat+wisata
# 1   Geliat Lembaga Pers Mahasiswa (LPM)  Khlorofil...  tempat+wisata
# 2   Melihat Lebih Dekat Museum Buleleng, Tempat As...  tempat+wisata
# 3   Dalam Ancaman Nyata Alih Fungsi Lahan, Diam-Di...  tempat+wisata
# 4   Mimih !!! Korban Pembunuhan Taman Pancing Terl...  tempat+wisata
# 5   Bali Jadi Destinasi Utama, Berikut Daftar Temp...  tempat+wisata
# 6   DLHK Kota Denpasar Percantik Lapangan Lumintan...  tempat+wisata
# 7   Pordasi Bali Akan Wujudkan Sport Tourism Komit...  tempat+wisata
# 8   Pilkada Sudah Semakin Dekat, Petugas PTPS  DIm...  tempat+wisata
# 9   Polisi Gelar Razia di Pantai Penimbangan, Temu...  tempat+wisata
# 10  Di Tabanan 850 PTPS Dilantik, Diingatkan untuk...  tempat+wisata
# 11  Dilantik, Sejumlah Pengawas TPS di Buleleng Ta...  tempat+wisata
# 12  Gelar Sidak di Amed, Dewan Karangasem Temukan ...  tempat+wisata
# 13  Izin Sebagai Turis, Ternyata Bekerja Sebagai P...  tempat+wisata
# 14  Selidiki Dugaan Pengeroyokan Pemuda  Tabanan, ...  tempat+wisata
# 15  Pemblokiran Akses Rumah di Perumahan Taman Yas...  tempat+wisata
# 16  Tanah Lot Bakal Dibangun Panggung Pentas Seni ...  tempat+wisata
# 17  Usai Terbakar Api di TPA Bengkala Sudah Padam,...  tempat+wisata
# 18  Rumah Potong Hewan di Tabanan Jadi Keren Setel...  tempat+wisata
# 19  TPA Bengkala, Buleleng, Terbakar, Diduga Akiba...  tempat+wisata
# 20  Simak Program Konkret Koster-Giri Bangun Pariw...  tempat+wisata
# 21  Putri Dosman Pastikan Tempat di Babak Final us...  tempat+wisata
# 22  Dokar Wisata Kota Denpasar Dipastikan Tetap Gr...  tempat+wisata
# 23  Meriah! EIGER Gelar Nobar Film Dokumenter Perj...  tempat+wisata
# 24  Dari Dua Peristiwa Kebakaran di Buleleng (2) :...  tempat+wisata
# 25  Swiss-Belexpress Kuta Tawarkan Pengalaman Bula...  tempat+wisata
# 26  Fakta Baru!  Boks Siluman DK 9953 FD, Tampung ...  tempat+wisata
# 27  Vadel Badjideh Tak Kunjung Dibui, Netizen Mula...  tempat+wisata
# 28  Gegara Anggaran dari Pusat Tak Kunjung Cair, P...  tempat+wisata
# 29  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...  tempat+wisata
# 30  Jual BBM Subsidi ke Kapal Wisata, Pertamina Pa...  tempat+wisata
# 31  SIKAT!!! Polda Bali dan Pertamina Usut Dugaan ...  tempat+wisata
# 32  Turis India yang Terjatuh dari Tebing Angel’s ...  tempat+wisata
# 33  Diduga Korsleting,  Tempat  Pengolahan Kayu Lu...  tempat+wisata
# 34  Ngeri! Salah Satu SPBU di Denpasar diduga Terl...  tempat+wisata
# 35  Luncurkan #RajegBali, Gojek Perkuat Aksesibili...  tempat+wisata
# 36  Wisata Kuliner Bersama LestariDiskon, Dapat Po...  tempat+wisata
# 37  Astaga! Maunya Berfoto Ria, Turis India  Terse...  tempat+wisata
# 38  Ini Hukuman yang Diterima Bahrain Jika Tolak B...  tempat+wisata
# 39  Kena Mental! Federasi Sepak Bola Bahrain Resmi...  tempat+wisata
# 40  Dulu Dibangun dengan Anggaran Rp 2,4 Miliar, G...  tempat+wisata
# 41  TPA Peh, Negara, Mendadak Keluar Asap Lagi, Da...  tempat+wisata
# 42  Tim Putra Jembatan Budaya Tekad Pertahankan Tr...  tempat+wisata
# 43  NAKAL !!! Pasutri Australia Memiliki KTP! Dici...  tempat+wisata
# 44  Ni Luh Suarnadi  Pekerja Migran Asal Buleleng ...  tempat+wisata
# 45  ITDC Gandeng Poltekpar Bali, Tingkatkan Kompet...  tempat+wisata
# 46  Waduh, Oknum Camat di Karangasem Diduga Ikut T...  tempat+wisata
# 47  Koster-Giri Lanjut Bangun Tol Gilimanuk-Mengwi...  tempat+wisata
# 48  Ketika Paslon Adicipta Kunjungi Pasar Rakyat d...  tempat+wisata
# 49  Pengalaman Seru Menyelam di Bali yang Wajib Ka...  tempat+wisata
# 50  Polisi Gelar Razia di Pantai Penimbangan, Temu...        hiburan
# 51  Ini Calon Mantu Shahrukh Khan Pacar Aryan Khan...        hiburan
# 52  Jadi Korban Hanyut di Bali, Jasad Anak Drummer...        hiburan
# 53  Ini Profil Drajat Djumantara Calon Suami Febby...        hiburan
# 54  Biznet Festival Bali 2024: Diramaikan Andra an...        hiburan
# 55  25 Tahun Menikah, Ari Lasso dan Vitta Dessy Be...        hiburan
# 56  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...        hiburan
# 57  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...        hiburan
# 58  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...        hiburan
#
#        source                                               link  \
# 0   RadarBali  https://radarbali.jawapos.com/kesehatan/705310...
# 1   RadarBali  https://radarbali.jawapos.com/denpasar/7053056...
# 2   RadarBali  https://radarbali.jawapos.com/buleleng/7053056...
# 3   RadarBali  https://radarbali.jawapos.com/pariwisata/70530...
# 4   RadarBali  https://radarbali.jawapos.com/berita-daerah/70...
# 5   RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 6   RadarBali  https://radarbali.jawapos.com/denpasar/7052836...
# 7   RadarBali  https://radarbali.jawapos.com/sportmania/70528...
# 8   RadarBali  https://radarbali.jawapos.com/jembrana/7052808...
# 9   RadarBali  https://radarbali.jawapos.com/buleleng/7052805...
# 10  RadarBali  https://radarbali.jawapos.com/tabanan/70527905...
# 11  RadarBali  https://radarbali.jawapos.com/buleleng/7052790...
# 12  RadarBali  https://radarbali.jawapos.com/karangasem/70527...
# 13  RadarBali  https://radarbali.jawapos.com/buleleng/7052738...
# 14  RadarBali  https://radarbali.jawapos.com/hukum-kriminal/7...
# 15  RadarBali  https://radarbali.jawapos.com/hukum-kriminal/7...
# 16  RadarBali  https://radarbali.jawapos.com/pariwisata/70525...
# 17  RadarBali  https://radarbali.jawapos.com/buleleng/7052494...
# 18  RadarBali  https://radarbali.jawapos.com/tabanan/70524559...
# 19  RadarBali  https://radarbali.jawapos.com/buleleng/7052420...
# 20  RadarBali  https://radarbali.jawapos.com/politika/7052392...
# 21  RadarBali  https://radarbali.jawapos.com/sportmania/70523...
# 22  RadarBali  https://radarbali.jawapos.com/denpasar/7052310...
# 23  RadarBali  https://radarbali.jawapos.com/nasional/7052270...
# 24  RadarBali  https://radarbali.jawapos.com/buleleng/7052247...
# 25  RadarBali  https://radarbali.jawapos.com/gaya-hidup/70522...
# 26  RadarBali  https://radarbali.jawapos.com/bali/705222519/f...
# 27  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 28  RadarBali  https://radarbali.jawapos.com/klungkung/705218...
# 29  RadarBali  https://radarbali.jawapos.com/jembrana/7052189...
# 30  RadarBali  https://radarbali.jawapos.com/hukum-kriminal/7...
# 31  RadarBali  https://radarbali.jawapos.com/hukum-kriminal/7...
# 32  RadarBali  https://radarbali.jawapos.com/peristiwa/705209...
# 33  RadarBali  https://radarbali.jawapos.com/peristiwa/705209...
# 34  RadarBali  https://radarbali.jawapos.com/peristiwa/705207...
# 35  RadarBali  https://radarbali.jawapos.com/gaya-hidup/70520...
# 36  RadarBali  https://radarbali.jawapos.com/ekonomi/70520546...
# 37  RadarBali  https://radarbali.jawapos.com/peristiwa/705205...
# 38  RadarBali  https://radarbali.jawapos.com/sportmania/70520...
# 39  RadarBali  https://radarbali.jawapos.com/sportmania/70520...
# 40  RadarBali  https://radarbali.jawapos.com/klungkung/705203...
# 41  RadarBali  https://radarbali.jawapos.com/jembrana/7052019...
# 42  RadarBali  https://radarbali.jawapos.com/sportmania/70520...
# 43  RadarBali  https://radarbali.jawapos.com/hukum-kriminal/7...
# 44  RadarBali  https://radarbali.jawapos.com/features/7051844...
# 45  RadarBali  https://radarbali.jawapos.com/pendidikan/70518...
# 46  RadarBali  https://radarbali.jawapos.com/politika/7051785...
# 47  RadarBali  https://radarbali.jawapos.com/politika/7051758...
# 48  RadarBali  https://radarbali.jawapos.com/politika/7051670...
# 49  RadarBali  https://radarbali.jawapos.com/gaya-hidup/70515...
# 50  RadarBali  https://radarbali.jawapos.com/buleleng/7052805...
# 51  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 52  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 53  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 54  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 55  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 56  RadarBali  https://radarbali.jawapos.com/teknologi/705224...
# 57  RadarBali  https://radarbali.jawapos.com/jembrana/7052189...
# 58  RadarBali  https://radarbali.jawapos.com/ekonomi/70519980...
#
#                                     date                content
# 0    Kamis, 14 November 2024 | 07:52 WIB              Kesehatan
# 1   Selasa, 12 November 2024 | 20:38 WIB               Denpasar
# 2   Selasa, 12 November 2024 | 20:31 WIB               Buleleng
# 3   Selasa, 12 November 2024 | 12:50 WIB             Pariwisata
# 4     Sabtu, 9 November 2024 | 14:22 WIB          Berita Daerah
# 5     Jumat, 8 November 2024 | 23:30 WIB  Hiburan & Seni Budaya
# 6     Kamis, 7 November 2024 | 06:00 WIB               Denpasar
# 7      Rabu, 6 November 2024 | 17:38 WIB             Sportmania
# 8      Rabu, 6 November 2024 | 15:35 WIB               Jembrana
# 9      Rabu, 6 November 2024 | 12:50 WIB               Buleleng
# 10   Selasa, 5 November 2024 | 21:15 WIB                Tabanan
# 11   Selasa, 5 November 2024 | 20:35 WIB               Buleleng
# 12   Selasa, 5 November 2024 | 19:30 WIB             Karangasem
# 13    Senin, 4 November 2024 | 15:52 WIB               Buleleng
# 14    Senin, 4 November 2024 | 07:25 WIB       Hukum & Kriminal
# 15    Jumat, 1 November 2024 | 13:59 WIB       Hukum & Kriminal
# 16     Rabu, 30 Oktober 2024 | 12:50 WIB             Pariwisata
# 17   Selasa, 29 Oktober 2024 | 11:55 WIB               Buleleng
# 18    Senin, 28 Oktober 2024 | 11:35 WIB                Tabanan
# 19   Minggu, 27 Oktober 2024 | 07:55 WIB               Buleleng
# 20    Jumat, 25 Oktober 2024 | 23:00 WIB               Politika
# 21    Kamis, 24 Oktober 2024 | 17:40 WIB             Sportmania
# 22     Rabu, 23 Oktober 2024 | 21:10 WIB               Denpasar
# 23   Selasa, 22 Oktober 2024 | 22:15 WIB               Nasional
# 24   Selasa, 22 Oktober 2024 | 14:05 WIB               Buleleng
# 25   Selasa, 22 Oktober 2024 | 11:48 WIB             Gaya Hidup
# 26    Senin, 21 Oktober 2024 | 20:50 WIB                   Bali
# 27    Senin, 21 Oktober 2024 | 07:00 WIB  Hiburan & Seni Budaya
# 28    Senin, 21 Oktober 2024 | 06:40 WIB              Klungkung
# 29    Senin, 21 Oktober 2024 | 05:15 WIB               Jembrana
# 30    Sabtu, 19 Oktober 2024 | 16:56 WIB       Hukum & Kriminal
# 31    Sabtu, 19 Oktober 2024 | 16:01 WIB       Hukum & Kriminal
# 32    Jumat, 18 Oktober 2024 | 10:05 WIB              Peristiwa
# 33    Jumat, 18 Oktober 2024 | 08:02 WIB              Peristiwa
# 34    Kamis, 17 Oktober 2024 | 16:19 WIB              Peristiwa
# 35    Kamis, 17 Oktober 2024 | 11:01 WIB             Gaya Hidup
# 36    Kamis, 17 Oktober 2024 | 08:06 WIB    Ekonomi & Perbankan
# 37    Kamis, 17 Oktober 2024 | 07:40 WIB              Peristiwa
# 38    Kamis, 17 Oktober 2024 | 06:00 WIB             Sportmania
# 39     Rabu, 16 Oktober 2024 | 19:32 WIB             Sportmania
# 40     Rabu, 16 Oktober 2024 | 19:10 WIB              Klungkung
# 41     Rabu, 16 Oktober 2024 | 12:50 WIB               Jembrana
# 42     Rabu, 16 Oktober 2024 | 11:44 WIB             Sportmania
# 43    Jumat, 11 Oktober 2024 | 13:01 WIB       Hukum & Kriminal
# 44    Jumat, 11 Oktober 2024 | 10:55 WIB               Features
# 45    Jumat, 11 Oktober 2024 | 06:35 WIB             Pendidikan
# 46      Rabu, 9 Oktober 2024 | 18:34 WIB               Politika
# 47      Rabu, 9 Oktober 2024 | 07:33 WIB               Politika
# 48    Minggu, 6 Oktober 2024 | 20:24 WIB               Politika
# 49     Kamis, 3 Oktober 2024 | 20:42 WIB             Gaya Hidup
# 50     Rabu, 6 November 2024 | 12:50 WIB               Buleleng
# 51    Sabtu, 2 November 2024 | 13:21 WIB  Hiburan & Seni Budaya
# 52    Jumat, 1 November 2024 | 08:09 WIB  Hiburan & Seni Budaya
# 53    Kamis, 31 Oktober 2024 | 05:00 WIB  Hiburan & Seni Budaya
# 54   Minggu, 27 Oktober 2024 | 22:31 WIB  Hiburan & Seni Budaya
# 55    Sabtu, 26 Oktober 2024 | 05:11 WIB  Hiburan & Seni Budaya
# 56   Selasa, 22 Oktober 2024 | 12:16 WIB              Teknologi
# 57    Senin, 21 Oktober 2024 | 05:15 WIB               Jembrana
# 58   Selasa, 15 Oktober 2024 | 16:54 WIB    Ekonomi & Perbankan

# %%
# Remove Duplication
berita_radarbali_2 = berita_radarbali.drop_duplicates(subset='title', keep='first')
print(berita_radarbali_2.shape)
berita_radarbali_2
# Out:
# (57, 6)
#                                                 title        keyword  \
# 0   Bluecross International Lakukan Topping Off, J...  tempat+wisata
# 1   Geliat Lembaga Pers Mahasiswa (LPM)  Khlorofil...  tempat+wisata
# 2   Melihat Lebih Dekat Museum Buleleng, Tempat As...  tempat+wisata
# 3   Dalam Ancaman Nyata Alih Fungsi Lahan, Diam-Di...  tempat+wisata
# 4   Mimih !!! Korban Pembunuhan Taman Pancing Terl...  tempat+wisata
# 5   Bali Jadi Destinasi Utama, Berikut Daftar Temp...  tempat+wisata
# 6   DLHK Kota Denpasar Percantik Lapangan Lumintan...  tempat+wisata
# 7   Pordasi Bali Akan Wujudkan Sport Tourism Komit...  tempat+wisata
# 8   Pilkada Sudah Semakin Dekat, Petugas PTPS  DIm...  tempat+wisata
# 9   Polisi Gelar Razia di Pantai Penimbangan, Temu...  tempat+wisata
# 10  Di Tabanan 850 PTPS Dilantik, Diingatkan untuk...  tempat+wisata
# 11  Dilantik, Sejumlah Pengawas TPS di Buleleng Ta...  tempat+wisata
# 12  Gelar Sidak di Amed, Dewan Karangasem Temukan ...  tempat+wisata
# 13  Izin Sebagai Turis, Ternyata Bekerja Sebagai P...  tempat+wisata
# 14  Selidiki Dugaan Pengeroyokan Pemuda  Tabanan, ...  tempat+wisata
# 15  Pemblokiran Akses Rumah di Perumahan Taman Yas...  tempat+wisata
# 16  Tanah Lot Bakal Dibangun Panggung Pentas Seni ...  tempat+wisata
# 17  Usai Terbakar Api di TPA Bengkala Sudah Padam,...  tempat+wisata
# 18  Rumah Potong Hewan di Tabanan Jadi Keren Setel...  tempat+wisata
# 19  TPA Bengkala, Buleleng, Terbakar, Diduga Akiba...  tempat+wisata
# 20  Simak Program Konkret Koster-Giri Bangun Pariw...  tempat+wisata
# 21  Putri Dosman Pastikan Tempat di Babak Final us...  tempat+wisata
# 22  Dokar Wisata Kota Denpasar Dipastikan Tetap Gr...  tempat+wisata
# 23  Meriah! EIGER Gelar Nobar Film Dokumenter Perj...  tempat+wisata
# 24  Dari Dua Peristiwa Kebakaran di Buleleng (2) :...  tempat+wisata
# 25  Swiss-Belexpress Kuta Tawarkan Pengalaman Bula...  tempat+wisata
# 26  Fakta Baru!  Boks Siluman DK 9953 FD, Tampung ...  tempat+wisata
# 27  Vadel Badjideh Tak Kunjung Dibui, Netizen Mula...  tempat+wisata
# 28  Gegara Anggaran dari Pusat Tak Kunjung Cair, P...  tempat+wisata
# 29  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...  tempat+wisata
# 30  Jual BBM Subsidi ke Kapal Wisata, Pertamina Pa...  tempat+wisata
# 31  SIKAT!!! Polda Bali dan Pertamina Usut Dugaan ...  tempat+wisata
# 32  Turis India yang Terjatuh dari Tebing Angel’s ...  tempat+wisata
# 33  Diduga Korsleting,  Tempat  Pengolahan Kayu Lu...  tempat+wisata
# 34  Ngeri! Salah Satu SPBU di Denpasar diduga Terl...  tempat+wisata
# 35  Luncurkan #RajegBali, Gojek Perkuat Aksesibili...  tempat+wisata
# 36  Wisata Kuliner Bersama LestariDiskon, Dapat Po...  tempat+wisata
# 37  Astaga! Maunya Berfoto Ria, Turis India  Terse...  tempat+wisata
# 38  Ini Hukuman yang Diterima Bahrain Jika Tolak B...  tempat+wisata
# 39  Kena Mental! Federasi Sepak Bola Bahrain Resmi...  tempat+wisata
# 40  Dulu Dibangun dengan Anggaran Rp 2,4 Miliar, G...  tempat+wisata
# 41  TPA Peh, Negara, Mendadak Keluar Asap Lagi, Da...  tempat+wisata
# 42  Tim Putra Jembatan Budaya Tekad Pertahankan Tr...  tempat+wisata
# 43  NAKAL !!! Pasutri Australia Memiliki KTP! Dici...  tempat+wisata
# 44  Ni Luh Suarnadi  Pekerja Migran Asal Buleleng ...  tempat+wisata
# 45  ITDC Gandeng Poltekpar Bali, Tingkatkan Kompet...  tempat+wisata
# 46  Waduh, Oknum Camat di Karangasem Diduga Ikut T...  tempat+wisata
# 47  Koster-Giri Lanjut Bangun Tol Gilimanuk-Mengwi...  tempat+wisata
# 48  Ketika Paslon Adicipta Kunjungi Pasar Rakyat d...  tempat+wisata
# 49  Pengalaman Seru Menyelam di Bali yang Wajib Ka...  tempat+wisata
# 51  Ini Calon Mantu Shahrukh Khan Pacar Aryan Khan...        hiburan
# 52  Jadi Korban Hanyut di Bali, Jasad Anak Drummer...        hiburan
# 53  Ini Profil Drajat Djumantara Calon Suami Febby...        hiburan
# 54  Biznet Festival Bali 2024: Diramaikan Andra an...        hiburan
# 55  25 Tahun Menikah, Ari Lasso dan Vitta Dessy Be...        hiburan
# 56  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...        hiburan
# 58  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...        hiburan
#
#        source                                               link  \
# 0   RadarBali  https://radarbali.jawapos.com/kesehatan/705310...
# 1   RadarBali  https://radarbali.jawapos.com/denpasar/7053056...
# 2   RadarBali  https://radarbali.jawapos.com/buleleng/7053056...
# 3   RadarBali  https://radarbali.jawapos.com/pariwisata/70530...
# 4   RadarBali  https://radarbali.jawapos.com/berita-daerah/70...
# 5   RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 6   RadarBali  https://radarbali.jawapos.com/denpasar/7052836...
# 7   RadarBali  https://radarbali.jawapos.com/sportmania/70528...
# 8   RadarBali  https://radarbali.jawapos.com/jembrana/7052808...
# 9   RadarBali  https://radarbali.jawapos.com/buleleng/7052805...
# 10  RadarBali  https://radarbali.jawapos.com/tabanan/70527905...
# 11  RadarBali  https://radarbali.jawapos.com/buleleng/7052790...
# 12  RadarBali  https://radarbali.jawapos.com/karangasem/70527...
# 13  RadarBali  https://radarbali.jawapos.com/buleleng/7052738...
# 14  RadarBali  https://radarbali.jawapos.com/hukum-kriminal/7...
# 15  RadarBali  https://radarbali.jawapos.com/hukum-kriminal/7...
# 16  RadarBali  https://radarbali.jawapos.com/pariwisata/70525...
# 17  RadarBali  https://radarbali.jawapos.com/buleleng/7052494...
# 18  RadarBali  https://radarbali.jawapos.com/tabanan/70524559...
# 19  RadarBali  https://radarbali.jawapos.com/buleleng/7052420...
# 20  RadarBali  https://radarbali.jawapos.com/politika/7052392...
# 21  RadarBali  https://radarbali.jawapos.com/sportmania/70523...
# 22  RadarBali  https://radarbali.jawapos.com/denpasar/7052310...
# 23  RadarBali  https://radarbali.jawapos.com/nasional/7052270...
# 24  RadarBali  https://radarbali.jawapos.com/buleleng/7052247...
# 25  RadarBali  https://radarbali.jawapos.com/gaya-hidup/70522...
# 26  RadarBali  https://radarbali.jawapos.com/bali/705222519/f...
# 27  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 28  RadarBali  https://radarbali.jawapos.com/klungkung/705218...
# 29  RadarBali  https://radarbali.jawapos.com/jembrana/7052189...
# 30  RadarBali  https://radarbali.jawapos.com/hukum-kriminal/7...
# 31  RadarBali  https://radarbali.jawapos.com/hukum-kriminal/7...
# 32  RadarBali  https://radarbali.jawapos.com/peristiwa/705209...
# 33  RadarBali  https://radarbali.jawapos.com/peristiwa/705209...
# 34  RadarBali  https://radarbali.jawapos.com/peristiwa/705207...
# 35  RadarBali  https://radarbali.jawapos.com/gaya-hidup/70520...
# 36  RadarBali  https://radarbali.jawapos.com/ekonomi/70520546...
# 37  RadarBali  https://radarbali.jawapos.com/peristiwa/705205...
# 38  RadarBali  https://radarbali.jawapos.com/sportmania/70520...
# 39  RadarBali  https://radarbali.jawapos.com/sportmania/70520...
# 40  RadarBali  https://radarbali.jawapos.com/klungkung/705203...
# 41  RadarBali  https://radarbali.jawapos.com/jembrana/7052019...
# 42  RadarBali  https://radarbali.jawapos.com/sportmania/70520...
# 43  RadarBali  https://radarbali.jawapos.com/hukum-kriminal/7...
# 44  RadarBali  https://radarbali.jawapos.com/features/7051844...
# 45  RadarBali  https://radarbali.jawapos.com/pendidikan/70518...
# 46  RadarBali  https://radarbali.jawapos.com/politika/7051785...
# 47  RadarBali  https://radarbali.jawapos.com/politika/7051758...
# 48  RadarBali  https://radarbali.jawapos.com/politika/7051670...
# 49  RadarBali  https://radarbali.jawapos.com/gaya-hidup/70515...
# 51  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 52  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 53  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 54  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 55  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 56  RadarBali  https://radarbali.jawapos.com/teknologi/705224...
# 58  RadarBali  https://radarbali.jawapos.com/ekonomi/70519980...
#
#                                     date                content
# 0    Kamis, 14 November 2024 | 07:52 WIB              Kesehatan
# 1   Selasa, 12 November 2024 | 20:38 WIB               Denpasar
# 2   Selasa, 12 November 2024 | 20:31 WIB               Buleleng
# 3   Selasa, 12 November 2024 | 12:50 WIB             Pariwisata
# 4     Sabtu, 9 November 2024 | 14:22 WIB          Berita Daerah
# 5     Jumat, 8 November 2024 | 23:30 WIB  Hiburan & Seni Budaya
# 6     Kamis, 7 November 2024 | 06:00 WIB               Denpasar
# 7      Rabu, 6 November 2024 | 17:38 WIB             Sportmania
# 8      Rabu, 6 November 2024 | 15:35 WIB               Jembrana
# 9      Rabu, 6 November 2024 | 12:50 WIB               Buleleng
# 10   Selasa, 5 November 2024 | 21:15 WIB                Tabanan
# 11   Selasa, 5 November 2024 | 20:35 WIB               Buleleng
# 12   Selasa, 5 November 2024 | 19:30 WIB             Karangasem
# 13    Senin, 4 November 2024 | 15:52 WIB               Buleleng
# 14    Senin, 4 November 2024 | 07:25 WIB       Hukum & Kriminal
# 15    Jumat, 1 November 2024 | 13:59 WIB       Hukum & Kriminal
# 16     Rabu, 30 Oktober 2024 | 12:50 WIB             Pariwisata
# 17   Selasa, 29 Oktober 2024 | 11:55 WIB               Buleleng
# 18    Senin, 28 Oktober 2024 | 11:35 WIB                Tabanan
# 19   Minggu, 27 Oktober 2024 | 07:55 WIB               Buleleng
# 20    Jumat, 25 Oktober 2024 | 23:00 WIB               Politika
# 21    Kamis, 24 Oktober 2024 | 17:40 WIB             Sportmania
# 22     Rabu, 23 Oktober 2024 | 21:10 WIB               Denpasar
# 23   Selasa, 22 Oktober 2024 | 22:15 WIB               Nasional
# 24   Selasa, 22 Oktober 2024 | 14:05 WIB               Buleleng
# 25   Selasa, 22 Oktober 2024 | 11:48 WIB             Gaya Hidup
# 26    Senin, 21 Oktober 2024 | 20:50 WIB                   Bali
# 27    Senin, 21 Oktober 2024 | 07:00 WIB  Hiburan & Seni Budaya
# 28    Senin, 21 Oktober 2024 | 06:40 WIB              Klungkung
# 29    Senin, 21 Oktober 2024 | 05:15 WIB               Jembrana
# 30    Sabtu, 19 Oktober 2024 | 16:56 WIB       Hukum & Kriminal
# 31    Sabtu, 19 Oktober 2024 | 16:01 WIB       Hukum & Kriminal
# 32    Jumat, 18 Oktober 2024 | 10:05 WIB              Peristiwa
# 33    Jumat, 18 Oktober 2024 | 08:02 WIB              Peristiwa
# 34    Kamis, 17 Oktober 2024 | 16:19 WIB              Peristiwa
# 35    Kamis, 17 Oktober 2024 | 11:01 WIB             Gaya Hidup
# 36    Kamis, 17 Oktober 2024 | 08:06 WIB    Ekonomi & Perbankan
# 37    Kamis, 17 Oktober 2024 | 07:40 WIB              Peristiwa
# 38    Kamis, 17 Oktober 2024 | 06:00 WIB             Sportmania
# 39     Rabu, 16 Oktober 2024 | 19:32 WIB             Sportmania
# 40     Rabu, 16 Oktober 2024 | 19:10 WIB              Klungkung
# 41     Rabu, 16 Oktober 2024 | 12:50 WIB               Jembrana
# 42     Rabu, 16 Oktober 2024 | 11:44 WIB             Sportmania
# 43    Jumat, 11 Oktober 2024 | 13:01 WIB       Hukum & Kriminal
# 44    Jumat, 11 Oktober 2024 | 10:55 WIB               Features
# 45    Jumat, 11 Oktober 2024 | 06:35 WIB             Pendidikan
# 46      Rabu, 9 Oktober 2024 | 18:34 WIB               Politika
# 47      Rabu, 9 Oktober 2024 | 07:33 WIB               Politika
# 48    Minggu, 6 Oktober 2024 | 20:24 WIB               Politika
# 49     Kamis, 3 Oktober 2024 | 20:42 WIB             Gaya Hidup
# 51    Sabtu, 2 November 2024 | 13:21 WIB  Hiburan & Seni Budaya
# 52    Jumat, 1 November 2024 | 08:09 WIB  Hiburan & Seni Budaya
# 53    Kamis, 31 Oktober 2024 | 05:00 WIB  Hiburan & Seni Budaya
# 54   Minggu, 27 Oktober 2024 | 22:31 WIB  Hiburan & Seni Budaya
# 55    Sabtu, 26 Oktober 2024 | 05:11 WIB  Hiburan & Seni Budaya
# 56   Selasa, 22 Oktober 2024 | 12:16 WIB              Teknologi
# 58   Selasa, 15 Oktober 2024 | 16:54 WIB    Ekonomi & Perbankan

# %%
# Build the regular expression pattern with word boundaries
pattern = r'\b(' + '|'.join(keywords_scrap) + r')\b'

# Filter rows where 'Title' contains the keyword as a whole word (case insensitive)
berita_radarbali_3 = berita_radarbali_2.copy()
berita_radarbali_3 = berita_radarbali_2[berita_radarbali_2['title'].str.contains(pattern, case=False, na=False)]

# Show the filtered DataFrame
print(berita_radarbali_3.shape)
berita_radarbali_3
# Out:
# (4, 6)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11996\2112746010.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   berita_radarbali_3 = berita_radarbali_2[berita_radarbali_2['title'].str.contains(pattern, case=False, na=False)]
#                                                 title        keyword  \
# 5   Bali Jadi Destinasi Utama, Berikut Daftar Temp...  tempat+wisata
# 29  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...  tempat+wisata
# 56  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...        hiburan
# 58  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...        hiburan
#
#        source                                               link  \
# 5   RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 29  RadarBali  https://radarbali.jawapos.com/jembrana/7052189...
# 56  RadarBali  https://radarbali.jawapos.com/teknologi/705224...
# 58  RadarBali  https://radarbali.jawapos.com/ekonomi/70519980...
#
#                                    date                content
# 5    Jumat, 8 November 2024 | 23:30 WIB  Hiburan & Seni Budaya
# 29   Senin, 21 Oktober 2024 | 05:15 WIB               Jembrana
# 56  Selasa, 22 Oktober 2024 | 12:16 WIB              Teknologi
# 58  Selasa, 15 Oktober 2024 | 16:54 WIB    Ekonomi & Perbankan

# %%
berita_radarbali_4 = berita_radarbali_3.copy()

# Nilai yang ingin kita hapus
values_to_remove = ['Sportmania','Foto Mania','Berita Daerah']
columns_to_check = ['content']

# Hapus baris yang memiliki nilai tersebut di sembarang kolom
berita_radarbali_4 = berita_radarbali_4[~berita_radarbali_4[columns_to_check].apply(lambda row: row.isin(values_to_remove).any(), axis=1)]
print(berita_radarbali_4.shape)
berita_radarbali_4
# Out:
# (4, 6)
#                                                 title        keyword  \
# 5   Bali Jadi Destinasi Utama, Berikut Daftar Temp...  tempat+wisata
# 29  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...  tempat+wisata
# 56  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...        hiburan
# 58  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...        hiburan
#
#        source                                               link  \
# 5   RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 29  RadarBali  https://radarbali.jawapos.com/jembrana/7052189...
# 56  RadarBali  https://radarbali.jawapos.com/teknologi/705224...
# 58  RadarBali  https://radarbali.jawapos.com/ekonomi/70519980...
#
#                                    date                content
# 5    Jumat, 8 November 2024 | 23:30 WIB  Hiburan & Seni Budaya
# 29   Senin, 21 Oktober 2024 | 05:15 WIB               Jembrana
# 56  Selasa, 22 Oktober 2024 | 12:16 WIB              Teknologi
# 58  Selasa, 15 Oktober 2024 | 16:54 WIB    Ekonomi & Perbankan

# %% [markdown]
# ## Export All (Combined)

# %% [markdown]
# ### Raw Data Hasil Scrapping

# %%
# # Import melalui kode ini kalau sudah ada raw data scrapping BaliPost yang terpisah dari proses scrapping diatas (hanya untuk BaliPost)
# berita_balipost = pd.read_excel("C:/Users/asus/OneDrive/BPS/Neraca/berita_sektor17_triwulan4_bali.xlsx")

# %%
# berita_balipost.head()

# %%
berita_detik.head()
# Out:
#                                                title        keyword  \
# 0  Korban Erupsi Gunung Lewotobi Bisa Memilih Tem...  tempat+wisata
# 1  Usut Pembuang Bayi di Tempat Sampah, Polisi Pe...  tempat+wisata
# 2  Bali: Destinasi Wisata yang Kini Jadi Magnet I...  tempat+wisata
# 3  Rohmi Bakal Sulap Kawasan Pantai Mujang Jadi D...  tempat+wisata
# 4  Bandara Tutup Dua Hari, Sopir Wisata di Labuan...  tempat+wisata
#
#       source                                               link  \
# 0  detikBali  https://www.detik.com/bali/nusra/d-7634475/kor...
# 1  detikBali  https://www.detik.com/bali/hukum-dan-kriminal/...
# 2  detikBali  https://www.detik.com/bali/bisnis/d-7632526/ba...
# 3  detikBali  https://www.detik.com/bali/pilkada/d-7633755/r...
# 4  detikBali  https://www.detik.com/bali/nusra/d-7631753/ban...
#
#                             date  \
# 0  Selasa, 12 Nov 2024 12:21 WIB
# 1  Selasa, 12 Nov 2024 10:51 WIB
# 2   Senin, 11 Nov 2024 11:29 WIB
# 3   Senin, 11 Nov 2024 21:11 WIB
# 4  Minggu, 10 Nov 2024 19:09 WIB
#
#                                              content
# 0  Badan Nasional Penanggulangan Bencana (BNPB) m...
# 1  Kasus penemuan jasad bayi perempuan pada tumpu...
# 2  Pulau Bali kini tidak hanya dikenal sebagai de...
# 3  Calon gubernur (cagub) Nusa Tenggara Barat (NT...
# 4  Sopir angkutan wisata di Labuan Bajo, Manggara...

# %%
berita_radarbali.head()
# Out:
#                                                title        keyword  \
# 0  Bluecross International Lakukan Topping Off, J...  tempat+wisata
# 1  Geliat Lembaga Pers Mahasiswa (LPM)  Khlorofil...  tempat+wisata
# 2  Melihat Lebih Dekat Museum Buleleng, Tempat As...  tempat+wisata
# 3  Dalam Ancaman Nyata Alih Fungsi Lahan, Diam-Di...  tempat+wisata
# 4  Mimih !!! Korban Pembunuhan Taman Pancing Terl...  tempat+wisata
#
#       source                                               link  \
# 0  RadarBali  https://radarbali.jawapos.com/kesehatan/705310...
# 1  RadarBali  https://radarbali.jawapos.com/denpasar/7053056...
# 2  RadarBali  https://radarbali.jawapos.com/buleleng/7053056...
# 3  RadarBali  https://radarbali.jawapos.com/pariwisata/70530...
# 4  RadarBali  https://radarbali.jawapos.com/berita-daerah/70...
#
#                                    date        content
# 0   Kamis, 14 November 2024 | 07:52 WIB      Kesehatan
# 1  Selasa, 12 November 2024 | 20:38 WIB       Denpasar
# 2  Selasa, 12 November 2024 | 20:31 WIB       Buleleng
# 3  Selasa, 12 November 2024 | 12:50 WIB     Pariwisata
# 4    Sabtu, 9 November 2024 | 14:22 WIB  Berita Daerah

# %%
# Tambahkan berita_balipost pada pd_concat jika data scrapping bali post tersedia
raw_data_combined = pd.concat([berita_detik, berita_radarbali], ignore_index=True) # Hilangkan berita_balipost jika tidak ada hasil scrapping dari BaliPost
# raw_data_combined = raw_data_combined.drop('Unnamed: 0', axis=1)
raw_data_combined
# Out:
#                                                  title        keyword  \
# 0    Korban Erupsi Gunung Lewotobi Bisa Memilih Tem...  tempat+wisata
# 1    Usut Pembuang Bayi di Tempat Sampah, Polisi Pe...  tempat+wisata
# 2    Bali: Destinasi Wisata yang Kini Jadi Magnet I...  tempat+wisata
# 3    Rohmi Bakal Sulap Kawasan Pantai Mujang Jadi D...  tempat+wisata
# 4    Bandara Tutup Dua Hari, Sopir Wisata di Labuan...  tempat+wisata
# ..                                                 ...            ...
# 110  Biznet Festival Bali 2024: Diramaikan Andra an...        hiburan
# 111  25 Tahun Menikah, Ari Lasso dan Vitta Dessy Be...        hiburan
# 112  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...        hiburan
# 113  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...        hiburan
# 114  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...        hiburan
#
#         source                                               link  \
# 0    detikBali  https://www.detik.com/bali/nusra/d-7634475/kor...
# 1    detikBali  https://www.detik.com/bali/hukum-dan-kriminal/...
# 2    detikBali  https://www.detik.com/bali/bisnis/d-7632526/ba...
# 3    detikBali  https://www.detik.com/bali/pilkada/d-7633755/r...
# 4    detikBali  https://www.detik.com/bali/nusra/d-7631753/ban...
# ..         ...                                                ...
# 110  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 111  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 112  RadarBali  https://radarbali.jawapos.com/teknologi/705224...
# 113  RadarBali  https://radarbali.jawapos.com/jembrana/7052189...
# 114  RadarBali  https://radarbali.jawapos.com/ekonomi/70519980...
#
#                                     date  \
# 0          Selasa, 12 Nov 2024 12:21 WIB
# 1          Selasa, 12 Nov 2024 10:51 WIB
# 2           Senin, 11 Nov 2024 11:29 WIB
# 3           Senin, 11 Nov 2024 21:11 WIB
# 4          Minggu, 10 Nov 2024 19:09 WIB
# ..                                   ...
# 110  Minggu, 27 Oktober 2024 | 22:31 WIB
# 111   Sabtu, 26 Oktober 2024 | 05:11 WIB
# 112  Selasa, 22 Oktober 2024 | 12:16 WIB
# 113   Senin, 21 Oktober 2024 | 05:15 WIB
# 114  Selasa, 15 Oktober 2024 | 16:54 WIB
#
#                                                content
# 0    Badan Nasional Penanggulangan Bencana (BNPB) m...
# 1    Kasus penemuan jasad bayi perempuan pada tumpu...
# 2    Pulau Bali kini tidak hanya dikenal sebagai de...
# 3    Calon gubernur (cagub) Nusa Tenggara Barat (NT...
# 4    Sopir angkutan wisata di Labuan Bajo, Manggara...
# ..                                                 ...
# 110                              Hiburan & Seni Budaya
# 111                              Hiburan & Seni Budaya
# 112                                          Teknologi
# 113                                           Jembrana
# 114                                Ekonomi & Perbankan
#
# [115 rows x 6 columns]

# %%
raw_data_combined.to_excel("C:/Users/asus/OneDrive/BPS/Neraca/beritaraw_combined_sektor17_2024_triwulan4_bali.xlsx")

# %% [markdown]
# ### Clean Data

# %%
# print(berita_balipost_3.shape)
# berita_balipost_3.head()

# %%
print(berita_detik_4.shape)
berita_detik_4.head()
# Out:
# (0, 6)
# Empty DataFrame
# Columns: [title, keyword, source, link, date, content]
# Index: []

# %%
print(berita_radarbali_4.shape)
berita_radarbali_4.head()
# Out:
# (4, 6)
#                                                 title        keyword  \
# 5   Bali Jadi Destinasi Utama, Berikut Daftar Temp...  tempat+wisata
# 29  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...  tempat+wisata
# 56  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...        hiburan
# 58  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...        hiburan
#
#        source                                               link  \
# 5   RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 29  RadarBali  https://radarbali.jawapos.com/jembrana/7052189...
# 56  RadarBali  https://radarbali.jawapos.com/teknologi/705224...
# 58  RadarBali  https://radarbali.jawapos.com/ekonomi/70519980...
#
#                                    date                content
# 5    Jumat, 8 November 2024 | 23:30 WIB  Hiburan & Seni Budaya
# 29   Senin, 21 Oktober 2024 | 05:15 WIB               Jembrana
# 56  Selasa, 22 Oktober 2024 | 12:16 WIB              Teknologi
# 58  Selasa, 15 Oktober 2024 | 16:54 WIB    Ekonomi & Perbankan

# %%
# Tambahkan berita_balipost_3 pada pd_concat jika data scrapping bali post tersedia
clean_data_combined = pd.concat([berita_detik_4, berita_radarbali_4], ignore_index=True)
# clean_data_combined = clean_data_combined.drop('Unnamed: 0', axis=1)
clean_data_combined
# Out:
#                                                title        keyword  \
# 0  Bali Jadi Destinasi Utama, Berikut Daftar Temp...  tempat+wisata
# 1  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...  tempat+wisata
# 2  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...        hiburan
# 3  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...        hiburan
#
#       source                                               link  \
# 0  RadarBali  https://radarbali.jawapos.com/hiburan-budaya/7...
# 1  RadarBali  https://radarbali.jawapos.com/jembrana/7052189...
# 2  RadarBali  https://radarbali.jawapos.com/teknologi/705224...
# 3  RadarBali  https://radarbali.jawapos.com/ekonomi/70519980...
#
#                                   date                content
# 0   Jumat, 8 November 2024 | 23:30 WIB  Hiburan & Seni Budaya
# 1   Senin, 21 Oktober 2024 | 05:15 WIB               Jembrana
# 2  Selasa, 22 Oktober 2024 | 12:16 WIB              Teknologi
# 3  Selasa, 15 Oktober 2024 | 16:54 WIB    Ekonomi & Perbankan

# %%
clean_data_combined.to_excel("C:/Users/asus/OneDrive/BPS/Neraca/beritaclean_combined_sektor17_2024_triwulan4_bali.xlsx")

# %% [markdown]
# # **SENTIMENT ANALYSIS**

# %% [markdown]
# ## Dataset Preparation

# %%
clean_data = pd.read_excel("C:/Users/asus/OneDrive/BPS/Neraca/beritaclean_combined_sektor17_2024_triwulan4_bali.xlsx")
clean_data
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Bali Jadi Destinasi Utama, Berikut Daftar Temp...
# 1           1  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...
# 2           2  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...
# 3           3  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...
#
#          keyword     source  \
# 0  tempat+wisata  RadarBali
# 1  tempat+wisata  RadarBali
# 2        hiburan  RadarBali
# 3        hiburan  RadarBali
#
#                                                 link  \
# 0  https://radarbali.jawapos.com/hiburan-budaya/7...
# 1  https://radarbali.jawapos.com/jembrana/7052189...
# 2  https://radarbali.jawapos.com/teknologi/705224...
# 3  https://radarbali.jawapos.com/ekonomi/70519980...
#
#                                   date                content
# 0   Jumat, 8 November 2024 | 23:30 WIB  Hiburan & Seni Budaya
# 1   Senin, 21 Oktober 2024 | 05:15 WIB               Jembrana
# 2  Selasa, 22 Oktober 2024 | 12:16 WIB              Teknologi
# 3  Selasa, 15 Oktober 2024 | 16:54 WIB    Ekonomi & Perbankan

# %%
clean_data_2 = clean_data.drop(['link','date','source'], axis=1)
clean_data_2
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Bali Jadi Destinasi Utama, Berikut Daftar Temp...
# 1           1  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...
# 2           2  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...
# 3           3  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...
#
#          keyword                content
# 0  tempat+wisata  Hiburan & Seni Budaya
# 1  tempat+wisata               Jembrana
# 2        hiburan              Teknologi
# 3        hiburan    Ekonomi & Perbankan

# %% [markdown]
# ## Preprocessing Judul Bahasa Indonesia

# %%
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from transformers import BertTokenizer

# Download stopwords dari NLTK
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Inisialisasi Stemmer (Sastrawi)
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Tokenizer IndoBERT (atau BERT)
tokenizer = BertTokenizer.from_pretrained('indolem/indobert-base-uncased')

# %%
# Fungsi Preprocessing
def preprocess_text(text):
    # 1. Mengubah teks ke huruf kecil
    text = text.lower()

    # 2. Menghapus URL, mention, hashtag, dan angka
    text = re.sub(r"http\S+|www\S+|https\S+", "", text)  # Menghapus URL
    text = re.sub(r"@\w+", "", text)  # Menghapus mention (@username)
    text = re.sub(r"#\w+", "", text)  # Menghapus hashtag (#hashtag)
    text = re.sub(r"\d+", "", text)  # Menghapus angka

    # 3. Menghapus tanda baca (jika diperlukan)
    text = re.sub(r"[^\w\s]", "", text)  # Menghapus tanda baca

    # 4. Tokenisasi menggunakan NLTK
    words = word_tokenize(text)  # Memecah kalimat menjadi kata

    # # 5. Menghapus stop words (menggunakan NLTK)
    # stop_words = set(stopwords.words('indonesian'))
    # words = [word for word in words if word not in stop_words]

    # 6. Stemming dengan Sastrawi
    words = [stemmer.stem(word) for word in words]

    # 7. Menggabungkan kembali kata-kata menjadi kalimat
    cleaned_text = " ".join(words)

    # 8. Tokenisasi menggunakan IndoBERT tokenizer (optional: untuk input model)
    input_ids = tokenizer.encode(cleaned_text, add_special_tokens=True)
    
    return cleaned_text, input_ids

# %%
clean_data_3 = clean_data_2.copy()

# Terapkan fungsi preprocess_text ke kolom 'description'
clean_data_3['cleaned_title'], clean_data_3['input_ids'] = zip(*clean_data_3['title'].apply(preprocess_text))

# %%
print(clean_data_3.shape)
clean_data_3
# Out:
# (4, 6)
#    Unnamed: 0                                              title  \
# 0           0  Bali Jadi Destinasi Utama, Berikut Daftar Temp...
# 1           1  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...
# 2           2  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...
# 3           3  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...
#
#          keyword                content  \
# 0  tempat+wisata  Hiburan & Seni Budaya
# 1  tempat+wisata               Jembrana
# 2        hiburan              Teknologi
# 3        hiburan    Ekonomi & Perbankan
#
#                                        cleaned_title  \
# 0  bal jadi destinasi utama ikut daftar tempat wi...
# 1  razia gabung tni polri ke tempat hibur malam d...
# 2    wow ini lebih tv samsung padu aman ai dan hibur
# 3  brimo fstvl hadir bidik generasi muda padu can...
#
#                                            input_ids
# 0  [3, 2513, 2359, 21427, 2408, 3354, 3745, 1991,...
# 1  [3, 10557, 30417, 3136, 4095, 1500, 1991, 5602...
# 2  [3, 27066, 1540, 1716, 4605, 22087, 24661, 402...
# 3  [3, 12099, 928, 25258, 2888, 932, 4112, 8034, ...

# %% [markdown]
# ## Translate Judul ke Bahasa Inggris dan Preprocessing

# %%
pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2022.6.15.1)
# Requirement already satisfied: hstspreload in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.11.1)
# Requirement already satisfied: sniffio in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Fungsi translator

# %%
from googletrans import Translator
import pandas as pd

# Fungsi untuk menerjemahkan teks ke bahasa Inggris
def translate_to_english(text):
    translator = Translator()
    try:
        translated_text = translator.translate(text, dest='en').text
        return translated_text
    except Exception as e:
        print(f"Error translating text: {e}")
        return text

# %%
clean_data_4 = clean_data_3.copy()

# Menerapkan fungsi translate_to_english pada kolom "Title"
clean_data_4['title_translated'] = clean_data_4['title'].apply(translate_to_english)

# Menampilkan dataframe setelah perubahan
print(clean_data_4.shape)
clean_data_4
# Out:
# (4, 7)
#    Unnamed: 0                                              title  \
# 0           0  Bali Jadi Destinasi Utama, Berikut Daftar Temp...
# 1           1  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...
# 2           2  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...
# 3           3  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...
#
#          keyword                content  \
# 0  tempat+wisata  Hiburan & Seni Budaya
# 1  tempat+wisata               Jembrana
# 2        hiburan              Teknologi
# 3        hiburan    Ekonomi & Perbankan
#
#                                        cleaned_title  \
# 0  bal jadi destinasi utama ikut daftar tempat wi...
# 1  razia gabung tni polri ke tempat hibur malam d...
# 2    wow ini lebih tv samsung padu aman ai dan hibur
# 3  brimo fstvl hadir bidik generasi muda padu can...
#
#                                            input_ids  \
# 0  [3, 2513, 2359, 21427, 2408, 3354, 3745, 1991,...
# 1  [3, 10557, 30417, 3136, 4095, 1500, 1991, 5602...
# 2  [3, 27066, 1540, 1716, 4605, 22087, 24661, 402...
# 3  [3, 12099, 928, 25258, 2888, 932, 4112, 8034, ...
#
#                                     title_translated
# 0  Bali is the main destination, here is a list o...
# 1  Joint Raids for the Indonesian National Police...
# 2  Wow!These are 4 advantages of Samsung TV, Comb...
# 3  Brimo FSTVL 2024 Present Bidik Young Generatio...

# %%
import nltk
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import spacy
# Load the model
nlp = spacy.load("en_core_web_sm")

# Download NLTK resources (if not already done)
nltk.download('punkt')
nltk.download('stopwords')

# Load spaCy English model for lemmatization
nlp = spacy.load("en_core_web_sm")

def clean_text(text):
    """
    Perform basic text cleaning including:
    - Lowercasing
    - Removing punctuation and special characters
    - Removing extra spaces
    """
    # Convert to lowercase
    text = text.lower()

    # Remove punctuation and special characters (using regular expressions)
    text = re.sub(f"[{string.punctuation}]", "", text)

    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# def remove_stopwords(text):
#     """
#     Remove stopwords from the text.
#     """
#     stop_words = set(stopwords.words('english'))
#     word_tokens = word_tokenize(text)
    
#     # Filter out stopwords
#     filtered_text = [word for word in word_tokens if word not in stop_words]
    
#     return ' '.join(filtered_text)

def lemmatize_text(text):
    """
    Lemmatize the text to reduce words to their base form.
    """
    doc = nlp(text)
    
    # Lemmatize each token (word) and join them back into a string
    lemmatized_text = " ".join([token.lemma_ for token in doc])
    
    return lemmatized_text

def preprocess_text(text):
    """
    Complete preprocessing pipeline:
    1. Clean the text (remove punctuation, lowercase)
    2. Remove stopwords
    3. Lemmatize the text
    """
    text = clean_text(text)
    # text = remove_stopwords(text)
    text = lemmatize_text(text)
    
    return text
# Out:
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:1144: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\tensor\python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
clean_data_4['cleaned_title_translated'] = clean_data_4['title_translated'].apply(preprocess_text)

print(clean_data_4.shape)
clean_data_4
# Out:
# (4, 8)
#    Unnamed: 0                                              title  \
# 0           0  Bali Jadi Destinasi Utama, Berikut Daftar Temp...
# 1           1  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...
# 2           2  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...
# 3           3  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...
#
#          keyword                content  \
# 0  tempat+wisata  Hiburan & Seni Budaya
# 1  tempat+wisata               Jembrana
# 2        hiburan              Teknologi
# 3        hiburan    Ekonomi & Perbankan
#
#                                        cleaned_title  \
# 0  bal jadi destinasi utama ikut daftar tempat wi...
# 1  razia gabung tni polri ke tempat hibur malam d...
# 2    wow ini lebih tv samsung padu aman ai dan hibur
# 3  brimo fstvl hadir bidik generasi muda padu can...
#
#                                            input_ids  \
# 0  [3, 2513, 2359, 21427, 2408, 3354, 3745, 1991,...
# 1  [3, 10557, 30417, 3136, 4095, 1500, 1991, 5602...
# 2  [3, 27066, 1540, 1716, 4605, 22087, 24661, 402...
# 3  [3, 12099, 928, 25258, 2888, 932, 4112, 8034, ...
#
#                                     title_translated  \
# 0  Bali is the main destination, here is a list o...
# 1  Joint Raids for the Indonesian National Police...
# 2  Wow!These are 4 advantages of Samsung TV, Comb...
# 3  Brimo FSTVL 2024 Present Bidik Young Generatio...
#
#                             cleaned_title_translated
# 0  bali be the main destination here be a list of...
# 1  joint raid for the indonesian national police ...
# 2  wowthese be 4 advantage of samsung tv combine ...
# 3  brimo fstvl 2024 present bidik young generatio...

# %% [markdown]
# ## Sentimen Decision + Word Cloud + Export Result

# %%
data_ready = clean_data_4.copy()
data_ready.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Bali Jadi Destinasi Utama, Berikut Daftar Temp...
# 1           1  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...
# 2           2  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...
# 3           3  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...
#
#          keyword                content  \
# 0  tempat+wisata  Hiburan & Seni Budaya
# 1  tempat+wisata               Jembrana
# 2        hiburan              Teknologi
# 3        hiburan    Ekonomi & Perbankan
#
#                                        cleaned_title  \
# 0  bal jadi destinasi utama ikut daftar tempat wi...
# 1  razia gabung tni polri ke tempat hibur malam d...
# 2    wow ini lebih tv samsung padu aman ai dan hibur
# 3  brimo fstvl hadir bidik generasi muda padu can...
#
#                                            input_ids  \
# 0  [3, 2513, 2359, 21427, 2408, 3354, 3745, 1991,...
# 1  [3, 10557, 30417, 3136, 4095, 1500, 1991, 5602...
# 2  [3, 27066, 1540, 1716, 4605, 22087, 24661, 402...
# 3  [3, 12099, 928, 25258, 2888, 932, 4112, 8034, ...
#
#                                     title_translated  \
# 0  Bali is the main destination, here is a list o...
# 1  Joint Raids for the Indonesian National Police...
# 2  Wow!These are 4 advantages of Samsung TV, Comb...
# 3  Brimo FSTVL 2024 Present Bidik Young Generatio...
#
#                             cleaned_title_translated
# 0  bali be the main destination here be a list of...
# 1  joint raid for the indonesian national police ...
# 2  wowthese be 4 advantage of samsung tv combine ...
# 3  brimo fstvl 2024 present bidik young generatio...

# %% [markdown]
# ### 1. TextBlob

# %% [markdown]
# #### Sentiment

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (8.1.3)
# Requirement already satisfied: joblib in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (2022.9.13)
# Requirement already satisfied: tqdm in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (4.64.1)
# Requirement already satisfied: colorama in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
data_sentiment1 = data_ready[['keyword','title_translated','cleaned_title_translated']]
data_sentiment1
# Out:
#          keyword                                   title_translated  \
# 0  tempat+wisata  Bali is the main destination, here is a list o...
# 1  tempat+wisata  Joint Raids for the Indonesian National Police...
# 2        hiburan  Wow!These are 4 advantages of Samsung TV, Comb...
# 3        hiburan  Brimo FSTVL 2024 Present Bidik Young Generatio...
#
#                             cleaned_title_translated
# 0  bali be the main destination here be a list of...
# 1  joint raid for the indonesian national police ...
# 2  wowthese be 4 advantage of samsung tv combine ...
# 3  brimo fstvl 2024 present bidik young generatio...

# %%
import pandas as pd
from textblob import TextBlob

# Pastikan kolom yang berisi alasan berhenti berlangganan dinamai 'reason'
# Jika nama kolom berbeda, ubah 'reason' sesuai dengan nama kolom yang benar
def get_sentiment(text):
    analysis = TextBlob(text)
    # Mengambil nilai sentimen
    return analysis.sentiment.polarity

# Menambahkan kolom baru untuk menyimpan nilai sentimen
data_sentiment1['sentiment_score_english'] = data_sentiment1['cleaned_title_translated'].apply(get_sentiment)

# Mengkategorikan sentimen
def categorize_sentiment(score):
    if score > 0:
        return 'Positif'
    elif score < 0:
        return 'Negatif'
    else:
        return 'Netral'

data_sentiment1['sentiment_category_english'] = data_sentiment1['sentiment_score_english'].apply(categorize_sentiment)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_11996\3177936794.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment1['sentiment_score_english'] = data_sentiment1['cleaned_title_translated'].apply(get_sentiment)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11996\3177936794.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment1['sentiment_category_english'] = data_sentiment1['sentiment_score_english'].apply(categorize_sentiment)

# %%
data_sentiment1
# Out:
#          keyword                                   title_translated  \
# 0  tempat+wisata  Bali is the main destination, here is a list o...
# 1  tempat+wisata  Joint Raids for the Indonesian National Police...
# 2        hiburan  Wow!These are 4 advantages of Samsung TV, Comb...
# 3        hiburan  Brimo FSTVL 2024 Present Bidik Young Generatio...
#
#                             cleaned_title_translated  sentiment_score_english  \
# 0  bali be the main destination here be a list of...                 0.166667
# 1  joint raid for the indonesian national police ...                 0.000000
# 2  wowthese be 4 advantage of samsung tv combine ...                 0.000000
# 3  brimo fstvl 2024 present bidik young generatio...                 0.050000
#
#   sentiment_category_english
# 0                    Positif
# 1                     Netral
# 2                     Netral
# 3                    Positif

# %%
sentiment_counts1 = data_sentiment1['sentiment_category_english'].value_counts()
sentiment_counts1
# Out:
# sentiment_category_english
# Positif    2
# Netral     2
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style of the plot using seaborn
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts1.index, y=sentiment_counts1.values, palette='viridis')

# Add labels and title
plt.title('Sentiment Category Distribution (Indonesia)', fontsize=16)
plt.xlabel('Sentiment Category', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Display the values on top of the bars
for i in range(len(sentiment_counts1)):
    plt.text(i, sentiment_counts1.values[i] + 0.5, 
             sentiment_counts1.values[i], 
             ha='center', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# #### Word Cloud (All and Based on Sentiment)

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (1.26.0)
# Requirement already satisfied: pillow in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: matplotlib in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (4.36.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all text from the 'Churn_Reason' column into a single string
text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1['cleaned_title_translated'])

# Create a word cloud
wordcloud_inggris = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_inggris, interpolation='bilinear')
plt.axis('off')  # Remove axes
plt.show()

# %% [markdown]
# Based on Sentiment

# %%
# Sentimen Positif
if data_sentiment1[data_sentiment1['sentiment_category_english'] == "Positif"].shape[0] != 0:
    data_sentiment1_positif = data_sentiment1[data_sentiment1['sentiment_category_english'] == "Positif"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_positif['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_positif_inggris = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_positif_inggris, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else:
    print("Tidak ada sentimen positif pada berita")

# %%
# Sentimen Negatif
if data_sentiment1[data_sentiment1['sentiment_category_english'] == "Negatif"].shape[0] != 0:
    data_sentiment1_negatif = data_sentiment1[data_sentiment1['sentiment_category_english'] == "Negatif"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_negatif['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_negatif_inggris = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_negatif_inggris, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen negatif pada berita")
# Out:
# Tidak ada sentimen negatif pada berita

# %%
# Sentimen Netral
if data_sentiment1[data_sentiment1['sentiment_category_english'] == "Netral"].shape[0] != 0:
    data_sentiment1_netral = data_sentiment1[data_sentiment1['sentiment_category_english'] == "Netral"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_netral['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_netral_inggris = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_netral_inggris, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen netral pada berita")

# %% [markdown]
# ### 2. VADER

# %% [markdown]
# #### Sentiment

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer

# Initialize VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Define a function to get sentiment scores with VADER
def get_sentiment_vader(text):
    # VADER provides a compound score which ranges from -1 (negative) to 1 (positive)
    score = sia.polarity_scores(text)['compound']
    return score

# Apply VADER to get the sentiment scores
data_sentiment1['sentiment_score_english_vader'] = data_sentiment1['cleaned_title_translated'].apply(get_sentiment_vader)

# Categorize sentiment with only 2 categories
def categorize_sentiment(score):
    if score > 0.05:  # Threshold for positive sentiment
        return 'Positif'
    elif score < -0.05:  # Threshold for negative sentiment
        return 'Negatif'
    else:
        return 'Netral'  # Scores between -0.05 and 0.05 considered neutral

data_sentiment1['sentiment_category_english_vader'] = data_sentiment1['sentiment_score_english_vader'].apply(categorize_sentiment)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_11996\17249303.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment1['sentiment_score_english_vader'] = data_sentiment1['cleaned_title_translated'].apply(get_sentiment_vader)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11996\17249303.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment1['sentiment_category_english_vader'] = data_sentiment1['sentiment_score_english_vader'].apply(categorize_sentiment)

# %%
data_sentiment1.head()
# Out:
#          keyword                                   title_translated  \
# 0  tempat+wisata  Bali is the main destination, here is a list o...
# 1  tempat+wisata  Joint Raids for the Indonesian National Police...
# 2        hiburan  Wow!These are 4 advantages of Samsung TV, Comb...
# 3        hiburan  Brimo FSTVL 2024 Present Bidik Young Generatio...
#
#                             cleaned_title_translated  sentiment_score_english  \
# 0  bali be the main destination here be a list of...                 0.166667
# 1  joint raid for the indonesian national police ...                 0.000000
# 2  wowthese be 4 advantage of samsung tv combine ...                 0.000000
# 3  brimo fstvl 2024 present bidik young generatio...                 0.050000
#
#   sentiment_category_english  sentiment_score_english_vader  \
# 0                    Positif                         0.4588
# 1                     Netral                         0.4215
# 2                     Netral                         0.7351
# 3                    Positif                         0.4215
#
#   sentiment_category_english_vader
# 0                          Positif
# 1                          Positif
# 2                          Positif
# 3                          Positif

# %%
sentiment_counts1_vader = data_sentiment1['sentiment_category_english_vader'].value_counts()
sentiment_counts1_vader
# Out:
# sentiment_category_english_vader
# Positif    4
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style of the plot using seaborn
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts1_vader.index, y=sentiment_counts1_vader.values, palette='viridis')

# Add labels and title
plt.title('Sentiment Category Distribution (Indonesia)', fontsize=16)
plt.xlabel('Sentiment Category', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Display the values on top of the bars
for i in range(len(sentiment_counts1_vader)):
    plt.text(i, sentiment_counts1_vader.values[i] + 0.5, 
             sentiment_counts1_vader.values[i], 
             ha='center', fontsize=12)

# Show the plot
plt.show()
# Out:
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:645: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   g_vals = grouped_vals.get_group(g)

# %% [markdown]
# #### Word Cloud (Based on Sentiment Only)

# %%
# Sentimen Positif
if data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Positif"].shape[0] != 0:
    data_sentiment1_positif_vader = data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Positif"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_positif_vader['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_positif_inggris_vader = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_positif_inggris_vader, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen positif pada berita")

# %%
# Sentimen Negatif
if data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Negatif"].shape[0] != 0:
    data_sentiment1_negatif_vader = data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Negatif"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_negatif_vader['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_negatif_inggris_vader = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_negatif_inggris_vader, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen negatif pada berita")
# Out:
# Tidak ada sentimen negatif pada berita

# %%
# Sentimen Netral
if data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Netral"].shape[0] != 0:
    data_sentiment1_netral_vader = data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Netral"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_netral_vader['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_netral_inggris_vader = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_netral_inggris_vader, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen netral pada berita")
# Out:
# Tidak ada sentimen netral pada berita

# %% [markdown]
# ### 3. IndoBERT

# %% [markdown]
# #### Sentiment

# %%
pip install transforms torch
# Out:
# Requirement already satisfied: transforms in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (0.2.1)
# Requirement already satisfied: torch in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (2.5.1)
# Requirement already satisfied: filelock in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
data_sentiment2 = data_ready[['keyword','title','cleaned_title','content']]
data_sentiment2
# Out:
#          keyword                                              title  \
# 0  tempat+wisata  Bali Jadi Destinasi Utama, Berikut Daftar Temp...
# 1  tempat+wisata  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...
# 2        hiburan  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...
# 3        hiburan  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...
#
#                                        cleaned_title                content
# 0  bal jadi destinasi utama ikut daftar tempat wi...  Hiburan & Seni Budaya
# 1  razia gabung tni polri ke tempat hibur malam d...               Jembrana
# 2    wow ini lebih tv samsung padu aman ai dan hibur              Teknologi
# 3  brimo fstvl hadir bidik generasi muda padu can...    Ekonomi & Perbankan

# %%
from transformers import BertForSequenceClassification, BertTokenizer
import torch

# Load the saved model and tokenizer
model_load_path = "C:/Users/asus/OneDrive/BPS/Neraca/smsa_bpsbali_indobert_model"  # The path where the model is saved
tokenizer_load_path = "C:/Users/asus/OneDrive/BPS/Neraca/smsa_bpsbali_indobert_tokenizer"  # The path where the tokenizer is saved

# Load the model and tokenizer
model = BertForSequenceClassification.from_pretrained(model_load_path)
tokenizer = BertTokenizer.from_pretrained(tokenizer_load_path)

# %%
from torch.nn.functional import softmax  # Softmax function to convert logits to probabilities

# Initialize an empty list to collect predictions
sentiment_predict = []
probabilities = []

# Loop through the cleaned titles
for text in data_sentiment2['cleaned_title']:
    # Tokenize the input text
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)

    # Make prediction
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():  # Disable gradients for inference
        outputs = model(**inputs)

    # Get the logits (raw scores)
    logits = outputs.logits
    
    # Apply softmax to convert logits to probabilities
    probs = softmax(logits, dim=-1)  # Softmax along the class dimension (last dimension)

    # Get the predicted class (index of max logit)
    predicted_class = logits.argmax(dim=-1).item()

    # Get the probability of the predicted class
    predicted_prob = probs[0, predicted_class].item()

    # Convert prediction to string label
    if predicted_class == 0:
        sentiment_label = "positif"
    elif predicted_class == 1:
        sentiment_label = "netral"
    else:
        sentiment_label = "negatif"

    # Append the sentiment label and its probability
    sentiment_predict.append(sentiment_label)
    probabilities.append(predicted_prob)

# After the loop, create the DataFrame
sentiment_predict_df = pd.DataFrame({
    'sentiment': sentiment_predict,
    'probability': probabilities
})

# Add it as a new column to the original DataFrame
data_sentiment2['sentiment_score_indonesia'] = sentiment_predict_df['probability']
data_sentiment2['sentiment_category_indonesia'] = sentiment_predict_df['sentiment']

# Optionally, you can print the DataFrame to check the results
data_sentiment2
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_11996\1096017218.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment2['sentiment_score_indonesia'] = sentiment_predict_df['probability']
# C:\Users\asus\AppData\Local\Temp\ipykernel_11996\1096017218.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment2['sentiment_category_indonesia'] = sentiment_predict_df['sentiment']
#          keyword                                              title  \
# 0  tempat+wisata  Bali Jadi Destinasi Utama, Berikut Daftar Temp...
# 1  tempat+wisata  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...
# 2        hiburan  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...
# 3        hiburan  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...
#
#                                        cleaned_title                content  \
# 0  bal jadi destinasi utama ikut daftar tempat wi...  Hiburan & Seni Budaya
# 1  razia gabung tni polri ke tempat hibur malam d...               Jembrana
# 2    wow ini lebih tv samsung padu aman ai dan hibur              Teknologi
# 3  brimo fstvl hadir bidik generasi muda padu can...    Ekonomi & Perbankan
#
#    sentiment_score_indonesia sentiment_category_indonesia
# 0                   0.820011                       netral
# 1                   0.992928                       netral
# 2                   0.973671                      positif
# 3                   0.958288                       netral

# %%
sentiment_counts2 = data_sentiment2['sentiment_category_indonesia'].value_counts()
sentiment_counts2
# Out:
# sentiment_category_indonesia
# netral     3
# positif    1
# Name: count, dtype: int64

# %%
import seaborn as sns

# Set the style of the plot using seaborn
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts2.index, y=sentiment_counts2.values, palette='viridis')

# Add labels and title
plt.title('Sentiment Category Distribution (Indonesia)', fontsize=16)
plt.xlabel('Sentiment Category', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Display the values on top of the bars
for i in range(len(sentiment_counts2)):
    plt.text(i, sentiment_counts2.values[i] + 0.5, 
             sentiment_counts2.values[i], 
             ha='center', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# #### Word Cloud (All and Based on Sentiment)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all text from the 'Churn_Reason' column into a single string
text = " ".join(cleaned_title for cleaned_title in data_sentiment2['cleaned_title'])

# Create a word cloud
wordcloud_indonesia = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_indonesia, interpolation='bilinear')
plt.axis('off')  # Remove axes
plt.show()

# %% [markdown]
# Based on Sentiment

# %%
# Sentimen Positif
if data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "positif"].shape[0] != 0:
    data_sentiment2_positif = data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "positif"]

    text = " ".join(cleaned_title for cleaned_title in data_sentiment2_positif['cleaned_title'])

    # Create a word cloud
    wordcloud_positif_indonesia = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_positif_indonesia, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen positif pada berita")

# %%
# Sentimen Negatif
if data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "negatif"].shape[0] != 0:
    data_sentiment2_negatif = data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "negatif"]

    text = " ".join(cleaned_title for cleaned_title in data_sentiment2_negatif['cleaned_title'])

    # Create a word cloud
    wordcloud_negatif_indonesia = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_negatif_indonesia, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen negatif pada berita")
# Out:
# Tidak ada sentimen negatif pada berita

# %%
# Sentimen Netral
if data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "netral"].shape[0] != 0:
    data_sentiment2_netral = data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "netral"]

    text = " ".join(cleaned_title for cleaned_title in data_sentiment2_netral['cleaned_title'])

    # Create a word cloud
    wordcloud_netral_indonesia = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_netral_indonesia, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen netral pada berita")

# %% [markdown]
# ### Export Result

# %%
print(data_sentiment1.shape)
data_sentiment1.head()
# Out:
# (4, 7)
#          keyword                                   title_translated  \
# 0  tempat+wisata  Bali is the main destination, here is a list o...
# 1  tempat+wisata  Joint Raids for the Indonesian National Police...
# 2        hiburan  Wow!These are 4 advantages of Samsung TV, Comb...
# 3        hiburan  Brimo FSTVL 2024 Present Bidik Young Generatio...
#
#                             cleaned_title_translated  sentiment_score_english  \
# 0  bali be the main destination here be a list of...                 0.166667
# 1  joint raid for the indonesian national police ...                 0.000000
# 2  wowthese be 4 advantage of samsung tv combine ...                 0.000000
# 3  brimo fstvl 2024 present bidik young generatio...                 0.050000
#
#   sentiment_category_english  sentiment_score_english_vader  \
# 0                    Positif                         0.4588
# 1                     Netral                         0.4215
# 2                     Netral                         0.7351
# 3                    Positif                         0.4215
#
#   sentiment_category_english_vader
# 0                          Positif
# 1                          Positif
# 2                          Positif
# 3                          Positif

# %%
print(data_sentiment2.shape)
data_sentiment2.head()
# Out:
# (4, 6)
#          keyword                                              title  \
# 0  tempat+wisata  Bali Jadi Destinasi Utama, Berikut Daftar Temp...
# 1  tempat+wisata  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...
# 2        hiburan  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...
# 3        hiburan  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...
#
#                                        cleaned_title                content  \
# 0  bal jadi destinasi utama ikut daftar tempat wi...  Hiburan & Seni Budaya
# 1  razia gabung tni polri ke tempat hibur malam d...               Jembrana
# 2    wow ini lebih tv samsung padu aman ai dan hibur              Teknologi
# 3  brimo fstvl hadir bidik generasi muda padu can...    Ekonomi & Perbankan
#
#    sentiment_score_indonesia sentiment_category_indonesia
# 0                   0.820011                       netral
# 1                   0.992928                       netral
# 2                   0.973671                      positif
# 3                   0.958288                       netral

# %%
# Assigning columns individually
sentiment_result = data_sentiment2.copy()  # Copy data_sentiment2 to avoid modifying the original

# Assign columns from data_sentiment1 to sentiment_result
sentiment_result['title_translated'] = data_sentiment1['title_translated']
sentiment_result['cleaned_title_translated'] = data_sentiment1['cleaned_title_translated']
sentiment_result['sentiment_category_english'] = data_sentiment1['sentiment_category_english']
sentiment_result['sentiment_score_english'] = data_sentiment1['sentiment_score_english']
sentiment_result['sentiment_category_english_vader'] = data_sentiment1['sentiment_category_english_vader']
sentiment_result['sentiment_score_english_vader'] = data_sentiment1['sentiment_score_english_vader']

print(sentiment_result.shape)
sentiment_result.head()
# Out:
# (4, 12)
#          keyword                                              title  \
# 0  tempat+wisata  Bali Jadi Destinasi Utama, Berikut Daftar Temp...
# 1  tempat+wisata  Razia Gabungan TNI Polri  ke Tempat Hiburan Ma...
# 2        hiburan  Wow! Ini 4 Kelebihan TV Samsung, Padukan Keama...
# 3        hiburan  BRImo FSTVL 2024 Hadir Bidik Generasi Muda: Pa...
#
#                                        cleaned_title                content  \
# 0  bal jadi destinasi utama ikut daftar tempat wi...  Hiburan & Seni Budaya
# 1  razia gabung tni polri ke tempat hibur malam d...               Jembrana
# 2    wow ini lebih tv samsung padu aman ai dan hibur              Teknologi
# 3  brimo fstvl hadir bidik generasi muda padu can...    Ekonomi & Perbankan
#
#    sentiment_score_indonesia sentiment_category_indonesia  \
# 0                   0.820011                       netral
# 1                   0.992928                       netral
# 2                   0.973671                      positif
# 3                   0.958288                       netral
#
#                                     title_translated  \
# 0  Bali is the main destination, here is a list o...
# 1  Joint Raids for the Indonesian National Police...
# 2  Wow!These are 4 advantages of Samsung TV, Comb...
# 3  Brimo FSTVL 2024 Present Bidik Young Generatio...
#
#                             cleaned_title_translated  \
# 0  bali be the main destination here be a list of...
# 1  joint raid for the indonesian national police ...
# 2  wowthese be 4 advantage of samsung tv combine ...
# 3  brimo fstvl 2024 present bidik young generatio...
#
#   sentiment_category_english  sentiment_score_english  \
# 0                    Positif                 0.166667
# 1                     Netral                 0.000000
# 2                     Netral                 0.000000
# 3                    Positif                 0.050000
#
#   sentiment_category_english_vader  sentiment_score_english_vader
# 0                          Positif                         0.4588
# 1                          Positif                         0.4215
# 2                          Positif                         0.7351
# 3                          Positif                         0.4215

# %%
sentiment_result.to_excel("C:/Users/asus/OneDrive/BPS/Neraca/sentimentresult_sektor17_triwulan4_bali.xlsx")
