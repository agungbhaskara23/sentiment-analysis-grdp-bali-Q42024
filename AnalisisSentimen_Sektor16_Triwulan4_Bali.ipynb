# %% [markdown]
# # **IMPORT PACKAGE**

# %%
import pandas as pd
import datetime
import os

# %% [markdown]
# # **DATA DEFINITION**

# %% [markdown]
# Pada bagian ini, dipetakan keyword yang akan digunakan untuk proses scrapping (per lapangan usaha), berikut juga dengan batasan waktu dari artikel yang ingin diambil. Di Badan Pusat Statistik, terdapat 17 sektor lapangan usaha, meliputi:
# 1.	Pertanian, Kehutanan, dan Perikanan
# 2.	Pertambangan dan Penggalian
# 3.	Industri Pengolahan
# 4.	Pengadaan Listrik, Gas
# 5.	Pengadaan Air, Pengelolaan Sampah, Limbah dan Daur Ulang
# 6.	Konstruksi
# 7.	Perdagangan Besar dan Eceran, Reparasi Mobil dan Sepeda Motor
# 8.	Transportasi dan Pergudangan
# 9.	Penyediaan Akomodasi dan Makan Minum
# 10.	Informasi dan Komunikasi
# 11.	Jasa Keuangan dan Asuransi
# 12.	Real Estat
# 13.	Jasa Perusahaan
# 14.	Administrasi Pemerintahan, Pertahanan dan Jaminan Sosial Wajib
# 15.	Jasa Pendidikan
# 16.	Jasa Kesehatan dan Kegiatan Sosial
# 17.	Jasa lainnya

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Tentukan keywords dari masing-masing lapangan usaha
key_sektor = ['kesehatan','sosial','donasi']

keywords_scrap = key_sektor

# Tentukan rentang tanggal
start_date = datetime.date(2024, 10, 1)
end_date = datetime.date(2024, 11, 12)

# %% [markdown]
# # **SCRAPPING, PRE-CLEANING, & EXPORT (Scrapping BaliPost Lama)**

# %% [markdown]
# ## 1. BaliPost

# %% [markdown]
# Fungsi dan package untuk scrapping di balipost ada pada kode di chunk berikut \
# Aktifkan kalau pencarian di balipost sudah berjalan normal (saat kode ini dibuat sangat lambat)

# %%
# import requests
# from bs4 import BeautifulSoup
# import datetime
# import pandas as pd

# # Fungsi untuk melakukan scraping dari BaliPost
# def scrape_balipost(keyword, start_date, end_date, max_results, max_pages):
#     """
#     Fungsi untuk melakukan scraping artikel dari situs BaliPost berdasarkan keyword dan rentang tanggal.

#     Args:
#     - keyword (str): Keyword pencarian.
#     - start_date (datetime.date): Tanggal awal.
#     - end_date (datetime.date): Tanggal akhir.
#     - max_results (int): Maksimum jumlah artikel yang diambil.
#     - max_pages (int): Maksimum jumlah halaman yang diambil.

#     Returns:
#     - results (list): Daftar artikel yang berisi judul, link, tanggal, keyword, dan isi.
#     """
#     results = []

#     # Mengganti spasi dengan tanda "+" untuk keyword yang lebih dari satu kata
#     search_keyword = keyword.replace(" ", "+")
#     base_url = f"https://www.balipost.com/search/{search_keyword}"
#     current_page = 1

#     while len(results) < max_results and current_page <= max_pages:
#         url = f"{base_url}/page/{current_page}" if current_page > 1 else base_url
#         print(f"Scraping halaman {current_page} dari URL: {url}")
#         response = requests.get(url)

#         if response.status_code != 200:
#             print(f"Error saat mengakses halaman {current_page}. Status code: {response.status_code}")
#             break

#         soup = BeautifulSoup(response.content, "html.parser")
#         articles = soup.find_all("div", class_="td_module_10 td_module_wrap td-animation-stack")

#         if not articles:
#             print(f"Tidak ada artikel di halaman {current_page}, berhenti scraping.")
#             break

#         for article in articles:
#             title_element = article.find("h3", class_="entry-title td-module-title")
#             if title_element:
#                 title = title_element.text.strip()
#                 link = article.find("a")["href"]

#                 date_element = article.find("time", class_="entry-date updated td-module-date")
#                 if date_element:
#                     date_str = date_element["datetime"][:10]
#                     date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()

#                     # Cek apakah tanggal artikel dalam rentang yang diinginkan
#                     if not (start_date <= date <= end_date):
#                         continue

#                 content_element = article.find("div", class_="td-excerpt")
#                 content = content_element.text.strip() if content_element else ""

#                 results.append({"title": title, "keyword": keyword, "source": "BaliPost", "link": link, "date": date, "content": content})
#                 if len(results) >= max_results:
#                     break

#         pagination = soup.find("a", class_="page", title=str(current_page + 1))
#         if pagination:
#             current_page += 1
#         else:
#             break

#     return results

# %% [markdown]
# Memulai proses scrapping berita

# %%
# # Step 4: Scraping untuk setiap keyword
# # Takes a LOOOOOOOOOOOONG time

# all_news = []

# for keyword in keywords_scrap:
#     print(f"\nMemulai scraping untuk keyword: {keyword}")
#     news = scrape_balipost(keyword, start_date, end_date, max_results=25, max_pages=3)

#     # Tampilkan jumlah artikel yang berhasil diekstrak untuk keyword ini
#     num_articles = len(news)
#     print(f"Jumlah artikel yang diekstrak untuk keyword '{keyword}': {num_articles}")

#     all_news.extend(news)

# # Step 5: Simpan hasil ke dalam file Excel
# berita_balipost = pd.DataFrame(all_news)
# berita_balipost

# %%
# # Import melalui kode ini kalau sudah ada raw data scrapping BaliPost yang terpisah dari proses scrapping diatas (hanya untuk BaliPost)
# berita_balipost = pd.read_excel("C:/Users/asus/OneDrive/BPS/Neraca/berita_sektor16_triwulan4_bali.xlsx")
# berita_balipost

# %% [markdown]
# Pre-cleaning \
# Hasil Scrapping BaliPost harus difilter terlebih dahulu wilayah (dari isi konten) dan judulnya (kadang tidak sesuai dengan kata yang diinginkan) \
# Contoh: Kata kunci --> Ikan || Judul ditemukan --> DicarIKAN, DijanjIKAN

# %%
# # Keyword to filter out
# keywords_filter = ["TABANAN","SINGARAJA","DENPASAR","MANGUPURA","AMLAPURA","SEMARAPURA","NEGARA","GIANYAR","BANGLI"]

# # Build the condition for multiple keywords
# pattern = '|'.join(keywords_filter)  # Create a pattern that matches any of the keywords

# # Filter out rows where 'Description' contains the keyword
# berita_balipost_2 = pd.DataFrame(berita_balipost[berita_balipost['content'].str.contains(pattern, case=False, na=False)])

# # Show the filtered DataFrame
# print(berita_balipost_2.shape)
# berita_balipost_2

# %%
# # Build the regular expression pattern with word boundaries
# pattern_1 = r'\b(' + '|'.join(keywords_scrap) + r')\b'  # Ensures "Ikan" is a whole word

# # Filter rows where 'Title' contains the keyword as a whole word (case insensitive)
# berita_balipost_3 = berita_balipost_2[berita_balipost_2['title'].str.contains(pattern_1, case=False, na=False)]

# # Show the filtered DataFrame
# print(berita_balipost_3.shape)
# berita_balipost_3

# %%
# # Remove Duplication
# berita_balipost_3 = berita_balipost_3.drop_duplicates(subset='title', keep='first')
# print(berita_balipost_3.shape)
# berita_balipost_3

# %% [markdown]
# ## 2. DetikBali

# %%
import math
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# Define web scraping functions
# Fungsi untuk menuju ke portal berita
def search_url(query, date_start, date_end, pages_num=1):
    url = f"https://www.detik.com/search/searchnews?query={query}&siteid=123&sortby=time&fromdatex={date_start}&todatex={date_end}&page={pages_num}&result_type=relevansi"
    
    print(url)
    response = requests.get(url)
    page = bs(response.content, "html.parser")

    return page

# Fungsi untuk menghitung jumlah artikel di halaman terakhir
def last_page_article_count(query, date_start, date_end, page_num):
    last_page = search_url(query, date_start, date_end, page_num)
    article_list = last_page.find("div", {"class": "list-content"})

    if article_list:
        articles = article_list.find_all('article', class_='list-content__item')           
    article_count = len(articles)
    
    return article_count

def news_search_results(query, date_start, date_end):
    page = search_url(query, date_start, date_end)
    
    pagination = page.find("div", {"class": "pagination"})
    if pagination:
        page_numbers = pagination.find_all('a', class_='pagination__item')
        if page_numbers:
            last_page_number = int(page_numbers[-2].text)

        # Menghitung jumlah artikel di halaman terakhir
        last_page_articles = last_page_article_count(query, date_start, date_end, last_page_number)

        # Menghitung jumlah artikel yang diperoleh
        num = (last_page_number - 1) * 10 + last_page_articles
    else:
        num = 0
        last_page_number = 1
    
    return num, last_page_number

# Fungsi untuk mendapatkan isi konten
def news_get_content(article_url):
    response = requests.get(article_url)
    content_page = bs(response.content, "html.parser")

    content_list = []
    multiple_page = content_page.find("div", {"class": "detail__multiple"})
    if multiple_page:
        multiple_page = [x.get("href") for x in multiple_page.find_all("a")][:-1]
        for page in multiple_page:
            response = requests.get(page)
            content_page = bs(response.content, "html.parser")
            content_list.extend([p.get_text() for p in content_page.find_all("p") if not p.get_text().startswith('\n\n\n\nHalaman\n\n') and
                                p.get_text() not in ['',
                                                    '[Gambas:Instagram]',
                                                    '[Gambas:Video 20detik]',
                                                    '\r\nADVERTISEMENT\r\n',
                                                    '\r\n    ADVERTISEMENT\r\n',
                                                    '\r\n    ADVERTISEMENT\r\n  ',
                                                    '\r\n   ADVERTISEMENT\r\n  ',
                                                    '\r\n   ADVERTISEMENT\r\n',
                                                    '\r\n        SCROLL TO RESUME CONTENT\r\n  ',
                                                    'Selengkapnya di halaman selanjutnya.',
                                                    '\n\t\t\t\t\tAyo share cerita pengalaman dan upload photo album travelingmu di sini.\n\n\t\t\t\t\t\t\t\t\t\t\tSilakan Daftar atau Masuk\n']])
    else:
        content_list.extend([p.get_text() for p in content_page.find_all("p")
                            if p.get_text() not in ['',
                                                    '[Gambas:Instagram]',
                                                    '[Gambas:Video 20detik]',
                                                    '\r\nADVERTISEMENT\r\n',
                                                    '\r\n    ADVERTISEMENT\r\n',
                                                    '\r\n    ADVERTISEMENT\r\n  ',
                                                    '\r\n   ADVERTISEMENT\r\n  ',
                                                    '\r\n   ADVERTISEMENT\r\n',
                                                    '\r\n        SCROLL TO RESUME CONTENT\r\n  ',
                                                    '\n\t\t\t\t\tAyo share cerita pengalaman dan upload photo album travelingmu di sini.\n\n\t\t\t\t\t\t\t\t\t\t\tSilakan Daftar atau Masuk\n']])

    content_list = '\n\n'.join(content_list)

    return content_list

# Fungsi untuk mengecek berita yang merupakan advertorial
def news_advertorial_check(article_url):
    response = requests.get(article_url)
    content_page = bs(response.content, "html.parser")

    author = content_page.find("meta", {"content": "Advertorial"})

    return bool(author)

# Fungsi untuk mencari artikel dengan output adalah jumlah artikel dan halaman terakhir
def search_articles(query, from_date, to_date, ads_article, article_content):
    results_num, last_page = news_search_results(query, from_date, to_date)
        
    print(f"Result num: {results_num}")
    print(f"Last page: {last_page}")

    return results_num, last_page

# Fungsi untuk memperoleh list artikel
def articles_list(query, from_date, to_date, ads_article, article_content, num_articles, last_page):
    article_lists = []
    pages = math.ceil(num_articles / 10)
    
    print("\nMemulai Scrapping dari DetikBali untuk keyword:", query)
    for i in range(1, pages + 1):
        print("Scrapping halaman", i, "dari URL: ")
        page = search_url(query, from_date, to_date, i)
        articles = page.find_all("article", class_="list-content__item")

        for article in articles:
            title = article.find("a", {"class": "media__link"}).get('dtr-ttl')
            category = article.find('h2', class_='media__subtitle').text.strip()
            publish_date = article.find('span', title=True).get('title')
            article_url = article.find("a", {"class": "media__link"}).get('href')
                
            # print(f"Title: {title}")
            # print(f"Category: {category}")
            # print(f"Publish Date: {publish_date}")
            # print(f"Article URL: {article_url}")

            if ads_article and news_advertorial_check(article_url):
                continue
            else:
                if article_content:
                    content = news_get_content(article_url)
                    if (
                        any(title in existing_article["title"] for existing_article in article_lists) or 
                        any(content in existing_article["content"] for existing_article in article_lists)
                    ):
                        continue
                    else:
                        article_lists.append({
                            "title": title,
                            "keyword": query,
                            "source": category,
                            "link": article_url,
                            "date": publish_date,
                            "content": content
                        })
                else:
                    if any(title in existing_article["title"] for existing_article in article_lists):
                        continue
                    else:
                        article_lists.append({
                            "title": title,
                            "keyword": query,
                            "link": article_url,
                            "date": publish_date
                        })
            if len(article_lists) == num_articles:
                break
        if len(article_lists) == num_articles:
            break
            
    print(f"Jumlah artikel dengan kata kunci {keyword}: {len(article_lists)} artikel.")
    data = article_lists
    return data

# %%
# Scraping untuk setiap keyword
all_news_detik = []

for keyword in keywords_scrap:
    search_keyword = keyword.replace(" ", "+")
    news = articles_list(search_keyword, start_date.strftime('%d/%m/%Y'), end_date.strftime('%d/%m/%Y'), False, True, 25, 5)
    all_news_detik.extend(news)

# Simpan hasil ke dalam file Excel
berita_detik = pd.DataFrame(all_news_detik) 
berita_detik
# Out:
# Memulai Scrapping dari DetikBali untuk keyword: kesehatan
# Scrapping halaman 1 dari URL:
# https://www.detik.com/search/searchnews?query=kesehatan&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=1&result_type=relevansi
# Scrapping halaman 2 dari URL:
# https://www.detik.com/search/searchnews?query=kesehatan&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=2&result_type=relevansi
# Scrapping halaman 3 dari URL:
# https://www.detik.com/search/searchnews?query=kesehatan&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=3&result_type=relevansi
# Jumlah artikel dengan kata kunci kesehatan: 25 artikel.
#
# Memulai Scrapping dari DetikBali untuk keyword: sosial
# Scrapping halaman 1 dari URL:
# https://www.detik.com/search/searchnews?query=sosial&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=1&result_type=relevansi
# Scrapping halaman 2 dari URL:
# https://www.detik.com/search/searchnews?query=sosial&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=2&result_type=relevansi
# Scrapping halaman 3 dari URL:
# https://www.detik.com/search/searchnews?query=sosial&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=3&result_type=relevansi
# Jumlah artikel dengan kata kunci sosial: 25 artikel.
#
# Memulai Scrapping dari DetikBali untuk keyword: donasi
# Scrapping halaman 1 dari URL:
# https://www.detik.com/search/searchnews?query=donasi&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=1&result_type=relevansi
# Scrapping halaman 2 dari URL:
# https://www.detik.com/search/searchnews?query=donasi&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=2&result_type=relevansi
# Scrapping halaman 3 dari URL:
# https://www.detik.com/search/searchnews?query=donasi&siteid=123&sortby=time&fromdatex=01/10/2024&todatex=12/11/2024&page=3&result_type=relevansi
# Jumlah artikel dengan kata kunci donasi: 5 artikel.
#                                                 title    keyword     source  \
# 0   Bahaya Sunat Perempuan: Dari Tradisi ke Masala...  kesehatan  detikBali
# 1   Solusi Mahayastra dan Kakarsana soal Peningkat...  kesehatan  detikBali
# 2   Gibran Pastikan Pemerintah Hadir dalam Penanga...  kesehatan  detikBali
# 3   Akur Janji Bangun RS-Beri Insentif Nakes di Pe...  kesehatan  detikBali
# 4   Paslon Elemen Soroti Ketiadaan Dokter Anestesi...  kesehatan  detikBali
# 5   Telkomsel Perluas Jaringan Telekomunikasi di P...  kesehatan  detikBali
# 6   Song Jae Rim Diduga Bunuh Diri, Ditemukan Sura...  kesehatan  detikBali
# 7   11.026 Pendaftar PPPK 2024 di Bima Dinyatakan ...  kesehatan  detikBali
# 8   Kampanye di Klungkung, Koster-Giri Janjikan Ke...  kesehatan  detikBali
# 9   Dampak Bekerja Sif Malam Terhadap Kesehatan da...  kesehatan  detikBali
# 10  Cara Alami Menurunkan Kolesterol dan Makanan y...  kesehatan  detikBali
# 11  10 Twibbon Hari Kesehatan Sedunia 2024, Cocok ...  kesehatan  detikBali
# 12  Giri Prasta Janjikan Seragam Sekolah dan Layan...  kesehatan  detikBali
# 13  Menkes Ungkap Kanker Stadium I Bisa 90% Sembuh...  kesehatan  detikBali
# 14  Ambara-Adi Mau Tingkatkan Layanan Kesehatan di...  kesehatan  detikBali
# 15  Xiaomi Smart Band 9 Pro Rilis, Lengkap dengan ...  kesehatan  detikBali
# 16  Cegah Stunting, Giri-Brata Janji Tambah Anggar...  kesehatan  detikBali
# 17  Gibran Akan Kunjungi Korban Erupsi Gunung Lewo...  kesehatan  detikBali
# 18  Paparkan Visi NTB Maju Berdaya Saing, Rohmi-Fi...  kesehatan  detikBali
# 19  Debat Perdana Pilbup Lombok Tengah Malam Ini, ...  kesehatan  detikBali
# 20  RSUD Bali Mandara Bakal Kembangkan Terapi Sel ...  kesehatan  detikBali
# 21  Pria 30 Tahun Kena Strok Seusai Dapat Pijat Gr...  kesehatan  detikBali
# 22  Kemenkes Kirim Bantuan Obat hingga Tim Medis u...  kesehatan  detikBali
# 23  Viral TikTokers Ungkap Kopi Americano Tanpa Gu...  kesehatan  detikBali
# 24  Ini Rekomendasi Makanan yang Aman untuk Pender...  kesehatan  detikBali
# 25  Manchester City Kalah 4 Kali Beruntun, #PepOut...     sosial  detikBali
# 26  Song Jae Rim Diduga Bunuh Diri, Ditemukan Sura...     sosial  detikBali
calon wakil gubernur (cawagub) Bali, I Nyoman ...
# 13  Menteri Kesehatan (Menkes) Budi Gunadi Sadikin...
# 14  Duet Gede Ngurah Ambara Putra-I Nengah Yasa Ad...
# 15  Xiaomi turut meluncurkan Xiaomi Smart Band 9 P...
# 16  Calon bupati (cabup) Bangli nomor urut 3, Ida ...
# 17  Wakil Presiden (Wapres) Gibran Rakabuming Raka...
# 18  Pasangan calon (paslon) Sitti Rohmi Djalillah-...
# 19  Debat terbuka perdana kandidat Pemilihan Bupat...
# 20  Pemerintah Provinsi (Pemprov) Bali tengah berf...
# 21  Seorang pria berusia 30 tahun di Ballari, Karn...
# 22  Kementerian Kesehatan (Kemenkes) mengirim bant...
# 23  Pengguna media sosial (medsos) TikTok mengungk...
# 24  Penyakit maag dapat menyerang siapa pun tanpa ...
# 25  Manchester City mengalami kekalahan empat kali...
# 26  Informasi berikut ini tidak ditujukan untuk me...
# 27  Jika kamu bingung memilih caption yang tepat, ...
# 28  Telkomsel kembali perluas jaringan telekomunik...
# 29  Kecelakaan maut beruntun melibatkan 17 kendara...
# 30  Kecelakaan beruntun melibatkan 17 kendaraan te...
# 31  Penjabat (Pj) Gubernur Bali, Sang Made Mahendr...
# 32  Seekor kera putih muncul di sekitar Pura Pasar...
# 33  Pemerintah Kabupaten Badung menggelar Upacara ...
# 34  Menteri Koordinator Bidang Infrastruktur dan P...
# 35  Video yang merekam seorang anggota DPRD NTB da...
# 36  Wakil Presiden (Wapres) Gibran Rakabuming Raka...
# 37  Pangdam I/Bukit Barisan Letjen Mochammad Hasan...
# 38  Lembaga Survei Saiful Mujani Research and Cons...
# 39  Lima ekor anjing ditemukan terkunci selama lim...
# 40  Badan Pengawas Pemilihan Umum (Bawaslu) Bali m...
# 41  Warung Laklak Pengangon, di Desa Bakas, Kecama...
# 42  Wacana proyek pembangunan Bandara Bali Utara y...
# 43  Peringatan Hari Pahlawan 2024 mengangkat tema ...
# 44  Hari Pahlawan diperingati setiap 10 November. ...
# 45  I Gede Robi Supriyanto atau yang akrab disapa ...
# 46  Banyak musisi tanah air seperti Marcel, Sandy ...
# 47  Massa yang menamakan diri Ikatan Mahasiswa dan...
# 48  Dua pasangan calon (paslon) yang berlaga dalam...
# 49  Subak Spirit Festival 2024 menjadi ajang peles...
# 50  Sejumlah warga menggalang donasi untuk pasanga...
# 51  Dinas Perkebunan dan Peternakan (Disbunnak) Fl...
# 52  Isu terkait erupsi Gunung Agung menjadi pembah...
# 53  Bali, yang dikenal dengan keindahan alam dan b...
# 54  Wisata selancar sangat menjanjikan dan berkemb...

# %% [markdown]
# Pre-cleaning

# %%
# Filter Wilayah
keywords_filter = ["Tabanan","Singaraja","Denpasar","Badung","Karangasem","Klungkung","Jembrana","Gianyar","Bangli"]

# Build the condition for multiple keywords
pattern = '|'.join(keywords_filter)  # Create a pattern that matches any of the keywords

# Filter out rows where 'Description' contains the keyword
berita_detik_2 = pd.DataFrame(berita_detik[berita_detik['content'].str.contains(pattern, case=False, na=False)])

# Show the filtered DataFrame
UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   berita_detik_3 = berita_detik_2[berita_detik_2['title'].str.contains(pattern, case=False, na=False)]
#                                                 title    keyword     source  \
# 1   Solusi Mahayastra dan Kakarsana soal Peningkat...  kesehatan  detikBali
# 8   Kampanye di Klungkung, Koster-Giri Janjikan Ke...  kesehatan  detikBali
# 12  Giri Prasta Janjikan Seragam Sekolah dan Layan...  kesehatan  detikBali
# 14  Ambara-Adi Mau Tingkatkan Layanan Kesehatan di...  kesehatan  detikBali
# 16  Cegah Stunting, Giri-Brata Janji Tambah Anggar...  kesehatan  detikBali
# 48  Solusi Mahayastra dan Kakarsana soal Peningkat...     sosial  detikBali
#
#                                                  link  \
# 1   https://www.detik.com/bali/pilkada/d-7630732/s...
# 8   https://www.detik.com/bali/pilkada/d-7576263/k...
# 12  https://www.detik.com/bali/pilkada/d-7585901/g...
# 14  https://www.detik.com/bali/pilkada/d-7625973/a...
# 16  https://www.detik.com/bali/pilkada/d-7605185/c...
# 48  https://www.detik.com/bali/pilkada/d-7630732/s...
#
#                              date  \
# 1    Sabtu, 09 Nov 2024 22:51 WIB
# 8    Senin, 07 Okt 2024 15:31 WIB
# 12  Minggu, 13 Okt 2024 17:10 WIB
# 14    Rabu, 06 Nov 2024 20:45 WIB
# 16   Kamis, 24 Okt 2024 21:32 WIB
# 48   Sabtu, 09 Nov 2024 22:51 WIB
#
#                                               content
# 1   Dua pasangan calon (paslon) yang berlaga dalam...
# 8   Calon gubernur dan wakil gubernur Bali nomor u...
# 12  Calon wakil gubernur (cawagub) Bali, I Nyoman ...
# 14  Duet Gede Ngurah Ambara Putra-I Nengah Yasa Ad...
# 16  Calon bupati (cabup) Bangli nomor urut 3, Ida ...
# 48  Dua pasangan calon (paslon) yang berlaga dalam...

# %% [markdown]
# Menghapus berita yang duplikat

# %%
# Remove Duplication
berita_detik_4 = berita_detik_3.drop_duplicates(subset='title', keep='first')
print(berita_detik_4.shape)
berita_detik_4
# Out:
# (5, 6)
#                                                 title    keyword     source  \
# 1   Solusi Mahayastra dan Kakarsana soal Peningkat...  kesehatan  detikBali
# 8   Kampanye di Klungkung, Koster-Giri Janjikan Ke...  kesehatan  detikBali
# 12  Giri Prasta Janjikan Seragam Sekolah dan Layan...  kesehatan  detikBali
# 14  Ambara-Adi Mau Tingkatkan Layanan Kesehatan di...  kesehatan  detikBali
# 16  Cegah Stunting, Giri-Brata Janji Tambah Anggar...  kesehatan  detikBali
#
#                                                  link  \
# 1   https://www.detik.com/bali/pilkada/d-7630732/s...
# 8   https://www.detik.com/bali/pilkada/d-7576263/k...
# 12  https://www.detik.com/bali/pilkada/d-7585901/g...
# 14  https://www.detik.com/bali/pilkada/d-7625973/a...
# 16  https://www.detik.com/bali/pilkada/d-7605185/c...
#
#                              date  \
# 1    Sabtu, 09 Nov 2024 22:51 WIB
# 8    Senin, 07 Okt 2024 15:31 WIB
# 12  Minggu, 13 Okt 2024 17:10 WIB
# 14    Rabu, 06 Nov 2024 20:45 WIB
# 16   Kamis, 24 Okt 2024 21:32 WIB
#
#                                               content
# 1   Dua pasangan calon (paslon) yang berlaga dalam...
# 8   Calon gubernur dan wakil gubernur Bali nomor u...
# 12  Calon wakil gubernur (cawagub) Bali, I Nyoman ...
# 14  Duet Gede Ngurah Ambara Putra-I Nengah Yasa Ad...
# 16  Calon bupati (cabup) Bangli nomor urut 3, Ida ...

# %% [markdown]
# ## 3. RadarBali

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
from datetime import datetime

# Tanggal batas yang ingin dibandingkan
start_date = datetime(2024, 10, 1)  # 1 Oktober 2024
end_date = datetime(2024, 12, 31)  # 31 Desember 2024

# Inisialisasi driver Chrome tanpa mengunduh chromedriver secara manual
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)
# Fungsi untuk melakukan scraping dan mengambil isian kelas latest__subtitle, latest__link, dan latest__date
def get_news(query, start_page, end_page):
    results = []

    print("\nMemulai scrapping RadarBali untuk keyword:", query)
    for page in range(start_page, end_page + 1):
        url = f"https://radarbali.jawapos.com/search?q={query}&sort=latest&page={page}"
        print("Scrapping halaman",page,"dari URL:",url)
        driver.get(url)
        time.sleep(10)  # Tunggu beberapa detik agar halaman selesai dimuat

        # Ambil konten halaman dan buat objek BeautifulSoup
        soup = BeautifulSoup(driver.page_source, "html.parser")

        # Ambil semua elemen dengan class latest__item
        articles = soup.find_all('div', class_='latest__item')

        # Ambil informasi dari setiap artikel
        for article in articles:
            subtitle = article.find('h4', class_='latest__subtitle')
            title = article.find('a', class_='latest__link')
            link = article.find('a', class_='latest__link')['href']
            date = article.find('date', class_='latest__date')

            # Menampilkan hasil jika elemen ditemukan, filter tanggal sesuai yang diinginkan
            if subtitle and title and date:
                date_berita = date.get_text(strip=True)

                # Fungsi untuk mengonversi nama bulan menjadi angka bulan
                def get_month_number(month_name):
                    months = {
                        "Januari": 1,
                        "Februari": 2,
                        "Maret": 3,
                        "April": 4,
                        "Mei": 5,
                        "Juni": 6,
                        "Juli": 7,
                        "Agustus": 8,
                        "September": 9,
                        "Oktober": 10,
                        "November": 11,
                        "Desember": 12
                    }
                    return months.get(month_name)

                # Fungsi untuk mem-parsing tanggal dalam format yang diberikan
                def parse_date(date_str):
                    # Pisahkan hari dan waktu
                    day_part, time_part = date_str.split(" | ")

                    # Ambil tanggal dan bulan dari bagian day_part
                    day_name, day, month_name, year = day_part.split()
                    day = int(day)
                    year = int(year)
                    month = get_month_number(month_name)
                    
                    # Gabungkan menjadi format yang bisa diproses oleh datetime
                    # Format waktu seperti '21:46 WIB', jadi kita hanya perlu ambil jam dan menit
                    time = time_part.replace(" WIB", "")

                    # Gabungkan semuanya ke format yang sesuai dengan datetime
                    date_string = f"{year}-{month:02d}-{day:02d} {time}"

                    # Mengonversi ke objek datetime
                    return datetime.strptime(date_string, "%Y-%m-%d %H:%M")
            
                parsed_date = parse_date(date_berita)

                # Membandingkan apakah parsed_date berada dalam rentang 1 Oktober 2024 sampai 31 Desember 2024
                if start_date <= parsed_date <= end_date:
                    results.append({"title": title.get_text(strip=True), "keyword": query, "source": "RadarBali", "link": link, "date": date.get_text(strip=True), "content": subtitle.get_text(strip=True)})
                    # print("Subtitle:", subtitle.get_text(strip=True))
                    # print("Title:", title.get_text(strip=True))
                    # print("Link:", link)
                    # print("Date:", date.get_text(strip=True))
                    # print('-' * 80)
                else:
                    break

    return results

import pandas as pd

all_news_radarbali = []

for keyword in keywords_scrap:
    search_keyword = keyword.replace(" ", "+")
    news = get_news(search_keyword, start_page=1, end_page=5)

    # Tampilkan jumlah artikel yang berhasil diekstrak untuk keyword ini
    num_articles = len(news)
    print(f"Jumlah artikel yang diekstrak untuk keyword '{keyword}': {num_articles}")

    all_news_radarbali.extend(news)

driver.quit()
# Out:
# Memulai scrapping RadarBali untuk keyword: kesehatan
# Scrapping halaman 1 dari URL: https://radarbali.jawapos.com/search?q=kesehatan&sort=latest&page=1
# Scrapping halaman 2 dari URL: https://radarbali.jawapos.com/search?q=kesehatan&sort=latest&page=2
# Scrapping halaman 3 dari URL: https://radarbali.jawapos.com/search?q=kesehatan&sort=latest&page=3
# Scrapping halaman 4 dari URL: https://radarbali.jawapos.com/search?q=kesehatan&sort=latest&page=4
# Scrapping halaman 5 dari URL: https://radarbali.jawapos.com/search?q=kesehatan&sort=latest&page=5
# Jumlah artikel yang diekstrak untuk keyword 'kesehatan': 27
#
# Memulai scrapping RadarBali untuk keyword: sosial
# Scrapping halaman 1 dari URL: https://radarbali.jawapos.com/search?q=sosial&sort=latest&page=1
# Scrapping halaman 2 dari URL: https://radarbali.jawapos.com/search?q=sosial&sort=latest&page=2
# Scrapping halaman 3 dari URL: https://radarbali.jawapos.com/search?q=sosial&sort=latest&page=3
# Scrapping halaman 4 dari URL: https://radarbali.jawapos.com/search?q=sosial&sort=latest&page=4
# Scrapping halaman 5 dari URL: https://radarbali.jawapos.com/search?q=sosial&sort=latest&page=5
# Jumlah artikel yang diekstrak untuk keyword 'sosial': 22
#
# Memulai scrapping RadarBali untuk keyword: donasi
# Scrapping halaman 1 dari URL: https://radarbali.jawapos.com/search?q=donasi&sort=latest&page=1
# Scrapping halaman 2 dari URL: https://radarbali.jawapos.com/search?q=donasi&sort=latest&page=2
# Scrapping halaman 3 dari URL: https://radarbali.jawapos.com/search?q=donasi&sort=latest&page=3
# Scrapping halaman 4 dari URL: https://radarbali.jawapos.com/search?q=donasi&sort=latest&page=4
# Scrapping halaman 5 dari URL: https://radarbali.jawapos.com/search?q=donasi&sort=latest&page=5
# Jumlah artikel yang diekstrak untuk keyword 'donasi': 1

# %%
berita_radarbali = pd.DataFrame(all_news_radarbali)
berita_radarbali
# Out:
#                                                 title    keyword     source  \
# 0   Diskes Bali Serius Deteksi Penderita TBC, Peng...  kesehatan  RadarBali
# 1   Layanan Telekonsultasi Kesehatan BPJS Mulai Di...  kesehatan  RadarBali
# 2     Kebiasaan yang Bisa Mengganggu Kesehatan Mental  kesehatan  RadarBali
# 3   Geruduk Kantor Dinas PU Jembrana, Warga Melaya...  kesehatan  RadarBali
# 4   Dari Debat Pilwali Kota Denpasar 2024: Paslon ...  kesehatan  RadarBali
# 5   KEK Sanur: KEK Kesehatan Peringkat Ke- 2 di Se...  kesehatan  RadarBali
# 6   Pertamina Patra Niaga Hadirkan Desa Ramah Anak...  kesehatan  RadarBali
# 7   Pertama di Aplikasi GoPay, Pengguna Bisa Akses...  kesehatan  RadarBali
# 8   Ikuti Perkembangan Zaman, BPOM Sosialisasikan ...  kesehatan  RadarBali
# 9   Hibah DRTPM Kemenristekdikti PMP: Peningkatan ...  kesehatan  RadarBali
# 38    Jumat, 1 November 2024 | 11:29 WIB  Hiburan & Seni Budaya
# 39    Jumat, 25 Oktober 2024 | 21:01 WIB  Hiburan & Seni Budaya
# 40    Jumat, 25 Oktober 2024 | 13:38 WIB  Hiburan & Seni Budaya
# 41    Kamis, 24 Oktober 2024 | 10:23 WIB             Gaya Hidup
# 42   Selasa, 22 Oktober 2024 | 16:13 WIB  Hiburan & Seni Budaya
# 43    Sabtu, 19 Oktober 2024 | 20:20 WIB               Politika
# 44    Sabtu, 19 Oktober 2024 | 20:17 WIB                   Bali
# 45    Kamis, 17 Oktober 2024 | 21:39 WIB                 Badung
# 46      Rabu, 9 Oktober 2024 | 21:34 WIB                 Badung
# 47      Rabu, 9 Oktober 2024 | 15:35 WIB              Klungkung
# 48    Selasa, 1 Oktober 2024 | 22:04 WIB               Denpasar
# 49   Senin, 11 November 2024 | 12:45 WIB  Hiburan & Seni Budaya

# %%
# Remove Duplication
berita_radarbali_2 = berita_radarbali.drop_duplicates(subset='title', keep='first')
print(berita_radarbali_2.shape)
berita_radarbali_2
# Out:
# (50, 6)
#                                                 title    keyword     source  \
# 0   Diskes Bali Serius Deteksi Penderita TBC, Peng...  kesehatan  RadarBali
# 1   Layanan Telekonsultasi Kesehatan BPJS Mulai Di...  kesehatan  RadarBali
# 2     Kebiasaan yang Bisa Mengganggu Kesehatan Mental  kesehatan  RadarBali
# 3   Geruduk Kantor Dinas PU Jembrana, Warga Melaya...  kesehatan  RadarBali
# 4   Dari Debat Pilwali Kota Denpasar 2024: Paslon ...  kesehatan  RadarBali
# 5   KEK Sanur: KEK Kesehatan Peringkat Ke- 2 di Se...  kesehatan  RadarBali
# 6   Pertamina Patra Niaga Hadirkan Desa Ramah Anak...  kesehatan  RadarBali
# 7   Pertama di Aplikasi GoPay, Pengguna Bisa Akses...  kesehatan  RadarBali
# 8   Ikuti Perkembangan Zaman, BPOM Sosialisasikan ...  kesehatan  RadarBali
# 9   Hibah DRTPM Kemenristekdikti PMP: Peningkatan ...  kesehatan  RadarBali
# 10  The Sanur Perkenalkan KEK Kesehatan Sanur ke P...  kesehatan  RadarBali
# 11  Gatra Bali sebagai Aplikasi Usadha dalam Menun...  kesehatan  RadarBali
# 12  Menuju Kesehatan Berkualitas: Sutjidra-Supriat...  kesehatan  RadarBali
# 13  Siap Melayani Peserta JKN, Klinik Pratama Gang...  kesehatan  RadarBali
# 14  Kepemimpinan Satriya Pastikan Biaya Kesehatan ...  kesehatan  RadarBali
# 15  Dari Pelatihan Warga Binaan di Lapas Singaraja...  kesehatan  RadarBali
# 16  Stelatopia+ Dengan Prebiotik: Perawatan Kompre...  kesehatan  RadarBali
# 17  Berikan Layanan Kesehatan Terbaik, Satriya Pro...  kesehatan  RadarBali
# 18  Seminggu Lebih Kerja Keras Padamkan Kebakaran ...  kesehatan  RadarBali
# 19  Pemeriksaan Kesehatan Gratis Suyadinata Disamb...  kesehatan  RadarBali
# 20  Optimalkan Pelayanan Kesehatan Darurat RSUD Bu...  kesehatan  RadarBali
# Filter rows where 'Title' contains the keyword as a whole word (case insensitive)
berita_radarbali_3 = berita_radarbali_2.copy()
berita_radarbali_3 = berita_radarbali_2[berita_radarbali_2['title'].str.contains(pattern, case=False, na=False)]

# Show the filtered DataFrame
print(berita_radarbali_3.shape)
berita_radarbali_3
# Out:
# (26, 6)
# C:\Users\asus\AppData\Local\Temp\ipykernel_14588\2112746010.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   berita_radarbali_3 = berita_radarbali_2[berita_radarbali_2['title'].str.contains(pattern, case=False, na=False)]
#                                                 title    keyword     source  \
# 1   Layanan Telekonsultasi Kesehatan BPJS Mulai Di...  kesehatan  RadarBali
# 2     Kebiasaan yang Bisa Mengganggu Kesehatan Mental  kesehatan  RadarBali
# 4   Dari Debat Pilwali Kota Denpasar 2024: Paslon ...  kesehatan  RadarBali
# 5   KEK Sanur: KEK Kesehatan Peringkat Ke- 2 di Se...  kesehatan  RadarBali
# 6   Pertamina Patra Niaga Hadirkan Desa Ramah Anak...  kesehatan  RadarBali
# 7   Pertama di Aplikasi GoPay, Pengguna Bisa Akses...  kesehatan  RadarBali
# 8   Ikuti Perkembangan Zaman, BPOM Sosialisasikan ...  kesehatan  RadarBali
# 9   Hibah DRTPM Kemenristekdikti PMP: Peningkatan ...  kesehatan  RadarBali
# 10  The Sanur Perkenalkan KEK Kesehatan Sanur ke P...  kesehatan  RadarBali
# 11  Gatra Bali sebagai Aplikasi Usadha dalam Menun...  kesehatan  RadarBali
# 12  Menuju Kesehatan Berkualitas: Sutjidra-Supriat...  kesehatan  RadarBali
# 14  Kepemimpinan Satriya Pastikan Biaya Kesehatan ...  kesehatan  RadarBali
# 15  Dari Pelatihan Warga Binaan di Lapas Singaraja...  kesehatan  RadarBali
# 16  Stelatopia+ Dengan Prebiotik: Perawatan Kompre...  kesehatan  RadarBali
# 17  Berikan Layanan Kesehatan Terbaik, Satriya Pro...  kesehatan  RadarBali
# 18  Seminggu Lebih Kerja Keras Padamkan Kebakaran ...  kesehatan  RadarBali
# 19  Pemeriksaan Kesehatan Gratis Suyadinata Disamb...  kesehatan  RadarBali
# 20  Optimalkan Pelayanan Kesehatan Darurat RSUD Bu...  kesehatan  RadarBali
# 21  Sekolah Pascasarjana dan FKG Unair Inisiasi Pr...  kesehatan  RadarBali
# 22  Melukat dan Pratiti, Perjalanan Kesehatan Spir...  kesehatan  RadarBali
# 23  Koster-Giri akan Bangun Sports Center Bali di ...  kesehatan  RadarBali
# 25  Dari Arifin Panigoro Dialog Seri Ke- 13, Darur...  kesehatan  RadarBali
# 26  Adi Arnawa Prihatin dengan Kondisi Pasutri di ...  kesehatan  RadarBali
# 38  Heboh, Foto Ziva Magnolya Diam-diam Bertunanga...     sosial  RadarBali
# 46  Plt. Bupati Badung Suiasa Sampaikan Penjelasan...     sosial  RadarBali
# 49  Agus Salim Ternyata Berbohong? Terciduk Kamera...     donasi  RadarBali
#
#                                                  link  \
# 1   https://radarbali.jawapos.com/kesehatan/705306...
# 2   https://radarbali.jawapos.com/kesehatan/705295...
# 4   https://radarbali.jawapos.com/denpasar/7052837...
# 49   Senin, 11 November 2024 | 12:45 WIB  Hiburan & Seni Budaya

# %%
berita_radarbali_4 = berita_radarbali_3.copy()

# Nilai yang ingin kita hapus
values_to_remove = ['Sportmania','Foto Mania','Berita Daerah']
columns_to_check = ['content']

# Hapus baris yang memiliki nilai tersebut di sembarang kolom
berita_radarbali_4 = berita_radarbali_4[~berita_radarbali_4[columns_to_check].apply(lambda row: row.isin(values_to_remove).any(), axis=1)]
print(berita_radarbali_4.shape)
berita_radarbali_4
# Out:
# (25, 6)
#                                                 title    keyword     source  \
# 1   Layanan Telekonsultasi Kesehatan BPJS Mulai Di...  kesehatan  RadarBali
# 2     Kebiasaan yang Bisa Mengganggu Kesehatan Mental  kesehatan  RadarBali
# 4   Dari Debat Pilwali Kota Denpasar 2024: Paslon ...  kesehatan  RadarBali
# 5   KEK Sanur: KEK Kesehatan Peringkat Ke- 2 di Se...  kesehatan  RadarBali
# 6   Pertamina Patra Niaga Hadirkan Desa Ramah Anak...  kesehatan  RadarBali
# 7   Pertama di Aplikasi GoPay, Pengguna Bisa Akses...  kesehatan  RadarBali
# 8   Ikuti Perkembangan Zaman, BPOM Sosialisasikan ...  kesehatan  RadarBali
# 9   Hibah DRTPM Kemenristekdikti PMP: Peningkatan ...  kesehatan  RadarBali
# 10  The Sanur Perkenalkan KEK Kesehatan Sanur ke P...  kesehatan  RadarBali
# 11  Gatra Bali sebagai Aplikasi Usadha dalam Menun...  kesehatan  RadarBali
# 12  Menuju Kesehatan Berkualitas: Sutjidra-Supriat...  kesehatan  RadarBali
# 14  Kepemimpinan Satriya Pastikan Biaya Kesehatan ...  kesehatan  RadarBali
# 15  Dari Pelatihan Warga Binaan di Lapas Singaraja...  kesehatan  RadarBali
# 16  Stelatopia+ Dengan Prebiotik: Perawatan Kompre...  kesehatan  RadarBali
# 17  Berikan Layanan Kesehatan Terbaik, Satriya Pro...  kesehatan  RadarBali
# 18  Seminggu Lebih Kerja Keras Padamkan Kebakaran ...  kesehatan  RadarBali
# 19  Pemeriksaan Kesehatan Gratis Suyadinata Disamb...  kesehatan  RadarBali
# 20  Optimalkan Pelayanan Kesehatan Darurat RSUD Bu...  kesehatan  RadarBali
# 21  Sekolah Pascasarjana dan FKG Unair Inisiasi Pr...  kesehatan  RadarBali
# 23  Koster-Giri akan Bangun Sports Center Bali di ...  kesehatan  RadarBali
# 25  Dari Arifin Panigoro Dialog Seri Ke- 13, Darur...  kesehatan  RadarBali
# 26  Adi Arnawa Prihatin dengan Kondisi Pasutri di ...  kesehatan  RadarBali
# 38  Heboh, Foto Ziva Magnolya Diam-diam Bertunanga...     sosial  RadarBali
# 46  Plt. Bupati Badung Suiasa Sampaikan Penjelasan...     sosial  RadarBali
# 49  Agus Salim Ternyata Berbohong? Terciduk Kamera...     donasi  RadarBali
#
#                                                  link  \
# 1   https://radarbali.jawapos.com/kesehatan/705306...
# 2   https://radarbali.jawapos.com/kesehatan/705295...
# 4   https://radarbali.jawapos.com/denpasar/7052837...
# ### Raw Data Hasil Scrapping

# %%
# # Import melalui kode ini kalau sudah ada raw data scrapping BaliPost yang terpisah dari proses scrapping diatas (hanya untuk BaliPost)
# berita_balipost = pd.read_excel("C:/Users/asus/OneDrive/BPS/Neraca/berita_sektor16_triwulan4_bali.xlsx")

# %%
# berita_balipost.head()

# %%
berita_detik.head()
# Out:
#                                                title    keyword     source  \
# 0  Bahaya Sunat Perempuan: Dari Tradisi ke Masala...  kesehatan  detikBali
# 1  Solusi Mahayastra dan Kakarsana soal Peningkat...  kesehatan  detikBali
# 2  Gibran Pastikan Pemerintah Hadir dalam Penanga...  kesehatan  detikBali
# 3  Akur Janji Bangun RS-Beri Insentif Nakes di Pe...  kesehatan  detikBali
# 4  Paslon Elemen Soroti Ketiadaan Dokter Anestesi...  kesehatan  detikBali
#
#                                                 link  \
# 0  https://www.detik.com/bali/nusra/d-7634849/bah...
# 1  https://www.detik.com/bali/pilkada/d-7630732/s...
# 2  https://www.detik.com/bali/nusra/d-7635564/gib...
# 3  https://www.detik.com/bali/pilkada/d-7635325/a...
# 4  https://www.detik.com/bali/pilkada/d-7635253/p...
#
#                             date  \
# 0  Selasa, 12 Nov 2024 15:17 WIB
# 1   Sabtu, 09 Nov 2024 22:51 WIB
# 2  Selasa, 12 Nov 2024 22:24 WIB
# 3  Selasa, 12 Nov 2024 19:08 WIB
# 4  Selasa, 12 Nov 2024 18:33 WIB
#
#                                              content
# 0  Pemerintah Kabupaten Lombok Timur, Nusa Tengga...
# 1  Dua pasangan calon (paslon) yang berlaga dalam...
# 2  Wakil Presiden Gibran Rakabuming Raka memberik...
# 3  Pasangan calon (paslon) bupati-wakil bupati Ma...
# 4  Pasangan calon (paslon) bupati-wakil bupati Ma...

# %%
berita_radarbali.head()
# Out:
#                                                title    keyword     source  \
# 0  Diskes Bali Serius Deteksi Penderita TBC, Peng...  kesehatan  RadarBali
# 1  Layanan Telekonsultasi Kesehatan BPJS Mulai Di...  kesehatan  RadarBali
# 2    Kebiasaan yang Bisa Mengganggu Kesehatan Mental  kesehatan  RadarBali
# 3  Geruduk Kantor Dinas PU Jembrana, Warga Melaya...  kesehatan  RadarBali
# 4  Dari Debat Pilwali Kota Denpasar 2024: Paslon ...  kesehatan  RadarBali
#
#                                                 link  \
# 0  https://radarbali.jawapos.com/kesehatan/705306...
# 1  https://radarbali.jawapos.com/kesehatan/705306...
# 2  https://radarbali.jawapos.com/kesehatan/705295...
# 3  https://radarbali.jawapos.com/jembrana/7052842...
# 4  https://radarbali.jawapos.com/denpasar/7052837...
#
#                                    date    content
# 0    Rabu, 13 November 2024 | 09:07 WIB  Kesehatan
# 1  Selasa, 12 November 2024 | 19:05 WIB  Kesehatan
# 2  Minggu, 10 November 2024 | 09:25 WIB  Kesehatan
# 3    Kamis, 7 November 2024 | 09:35 WIB   Jembrana
# 4     Rabu, 6 November 2024 | 21:34 WIB   Denpasar

# %%
# Tambahkan berita_balipost pada pd_concat jika data scrapping bali post tersedia
raw_data_combined = pd.concat([berita_detik, berita_radarbali], ignore_index=True) # Hilangkan berita_balipost jika tidak ada hasil scrapping dari BaliPost
# raw_data_combined = raw_data_combined.drop('Unnamed: 0', axis=1)
raw_data_combined
# Out:
#                                                  title    keyword     source  \
# 0    Bahaya Sunat Perempuan: Dari Tradisi ke Masala...  kesehatan  detikBali
# 1    Solusi Mahayastra dan Kakarsana soal Peningkat...  kesehatan  detikBali
# 2    Gibran Pastikan Pemerintah Hadir dalam Penanga...  kesehatan  detikBali
# 3    Akur Janji Bangun RS-Beri Insentif Nakes di Pe...  kesehatan  detikBali
# 4    Paslon Elemen Soroti Ketiadaan Dokter Anestesi...  kesehatan  detikBali
# ..                                                 ...        ...        ...
# 100  Pertama Kali di Bali, Ini Tujuan Kajari Badung...     sosial  RadarBali
# 101  Plt. Bupati Badung Suiasa Sampaikan Penjelasan...     sosial  RadarBali
# 102  Astungkara, Sempat Hendak Dihapus, Program San...     sosial  RadarBali
# 103  Buah Lontar Viral Bikin Penasaran, Sehari Terj...     sosial  RadarBali
# 104  Agus Salim Ternyata Berbohong? Terciduk Kamera...     donasi  RadarBali
#
#                                                   link  \
# 0    https://www.detik.com/bali/nusra/d-7634849/bah...
# 1    https://www.detik.com/bali/pilkada/d-7630732/s...
# 2    https://www.detik.com/bali/nusra/d-7635564/gib...
# 3    https://www.detik.com/bali/pilkada/d-7635325/a...
# 4    https://www.detik.com/bali/pilkada/d-7635253/p...
# ..                                                 ...
# 100  https://radarbali.jawapos.com/badung/705208874...
# 101  https://radarbali.jawapos.com/badung/705179382...
# 102  https://radarbali.jawapos.com/klungkung/705176...
# 103  https://radarbali.jawapos.com/denpasar/7051506...
# 104  https://radarbali.jawapos.com/hiburan-budaya/7...
#
#                                     date  \
# 0          Selasa, 12 Nov 2024 15:17 WIB
# 1           Sabtu, 09 Nov 2024 22:51 WIB
# 2          Selasa, 12 Nov 2024 22:24 WIB
# 3          Selasa, 12 Nov 2024 19:08 WIB
# 4          Selasa, 12 Nov 2024 18:33 WIB
# ..                                   ...
# 100   Kamis, 17 Oktober 2024 | 21:39 WIB
# 101     Rabu, 9 Oktober 2024 | 21:34 WIB
# 102     Rabu, 9 Oktober 2024 | 15:35 WIB
# 103   Selasa, 1 Oktober 2024 | 22:04 WIB
# 104  Senin, 11 November 2024 | 12:45 WIB
#
#                                                content
# 0    Pemerintah Kabupaten Lombok Timur, Nusa Tengga...
# 1    Dua pasangan calon (paslon) yang berlaga dalam...
# 2    Wakil Presiden Gibran Rakabuming Raka memberik...
# 3    Pasangan calon (paslon) bupati-wakil bupati Ma...
# 4    Pasangan calon (paslon) bupati-wakil bupati Ma...
# ..                                                 ...
# 100                                             Badung
# 101                                             Badung
# 102                                          Klungkung
# 103                                           Denpasar
# 104                              Hiburan & Seni Budaya
#
# [105 rows x 6 columns]

# %%
raw_data_combined.to_excel("C:/Users/asus/OneDrive/BPS/Neraca/beritaraw_combined_sektor16_2024_triwulan4_bali.xlsx")

# %% [markdown]
# ### Clean Data

# %%
# print(berita_balipost_3.shape)
# berita_balipost_3.head()

# %%
print(berita_detik_4.shape)
berita_detik_4.head()
# Out:
# (5, 6)
#                                                 title    keyword     source  \
# 1   Solusi Mahayastra dan Kakarsana soal Peningkat...  kesehatan  detikBali
# 8   Kampanye di Klungkung, Koster-Giri Janjikan Ke...  kesehatan  detikBali
# 12  Giri Prasta Janjikan Seragam Sekolah dan Layan...  kesehatan  detikBali
# 14  Ambara-Adi Mau Tingkatkan Layanan Kesehatan di...  kesehatan  detikBali
# 16  Cegah Stunting, Giri-Brata Janji Tambah Anggar...  kesehatan  detikBali
#
#                                                  link  \
# 1   https://www.detik.com/bali/pilkada/d-7630732/s...
# 8   https://www.detik.com/bali/pilkada/d-7576263/k...
# 12  https://www.detik.com/bali/pilkada/d-7585901/g...
# 14  https://www.detik.com/bali/pilkada/d-7625973/a...
# 16  https://www.detik.com/bali/pilkada/d-7605185/c...
#
#                              date  \
# 1    Sabtu, 09 Nov 2024 22:51 WIB
# 8    Senin, 07 Okt 2024 15:31 WIB
# 12  Minggu, 13 Okt 2024 17:10 WIB
# 14    Rabu, 06 Nov 2024 20:45 WIB
# 16   Kamis, 24 Okt 2024 21:32 WIB
#
#                                               content
# 1   Dua pasangan calon (paslon) yang berlaga dalam...
# 8   Calon gubernur dan wakil gubernur Bali nomor u...
# 12  Calon wakil gubernur (cawagub) Bali, I Nyoman ...
# 14  Duet Gede Ngurah Ambara Putra-I Nengah Yasa Ad...
# 16  Calon bupati (cabup) Bangli nomor urut 3, Ida ...

# %%
print(berita_radarbali_4.shape)
berita_radarbali_4.head()
# Out:
# (25, 6)
#                                                title    keyword     source  \
# 1  Layanan Telekonsultasi Kesehatan BPJS Mulai Di...  kesehatan  RadarBali
# 2    Kebiasaan yang Bisa Mengganggu Kesehatan Mental  kesehatan  RadarBali
# 4  Dari Debat Pilwali Kota Denpasar 2024: Paslon ...  kesehatan  RadarBali
# 5  KEK Sanur: KEK Kesehatan Peringkat Ke- 2 di Se...  kesehatan  RadarBali
# 6  Pertamina Patra Niaga Hadirkan Desa Ramah Anak...  kesehatan  RadarBali
#
#                                                 link  \
# 1  https://radarbali.jawapos.com/kesehatan/705306...
# 2  https://radarbali.jawapos.com/kesehatan/705295...
# 4  https://radarbali.jawapos.com/denpasar/7052837...
# 5  https://radarbali.jawapos.com/pariwisata/70527...
# 6  https://radarbali.jawapos.com/ekonomi/70526950...
#
#                                    date              content
# 1  Selasa, 12 November 2024 | 19:05 WIB            Kesehatan
# 2  Minggu, 10 November 2024 | 09:25 WIB            Kesehatan
# 4     Rabu, 6 November 2024 | 21:34 WIB             Denpasar
# 5   Selasa, 5 November 2024 | 18:33 WIB           Pariwisata
# 6   Minggu, 3 November 2024 | 11:48 WIB  Ekonomi & Perbankan

# %%
# Tambahkan berita_balipost_3 pada pd_concat jika data scrapping bali post tersedia
clean_data_combined = pd.concat([berita_detik_4, berita_radarbali_4], ignore_index=True)
# clean_data_combined = clean_data_combined.drop('Unnamed: 0', axis=1)
clean_data_combined
# Out:
#                                                 title    keyword     source  \
# 0   Solusi Mahayastra dan Kakarsana soal Peningkat...  kesehatan  detikBali
# 1   Kampanye di Klungkung, Koster-Giri Janjikan Ke...  kesehatan  detikBali
# 2   Giri Prasta Janjikan Seragam Sekolah dan Layan...  kesehatan  detikBali
# 3   Ambara-Adi Mau Tingkatkan Layanan Kesehatan di
duet Gede Ngurah Ambara Putra-I Nengah Yasa Ad...
# 4   Calon bupati (cabup) Bangli nomor urut 3, Ida ...
# 5                                           Kesehatan
# 6                                           Kesehatan
# 7                                            Denpasar
# 8                                          Pariwisata
# 9                                 Ekonomi & Perbankan
# 10                                         Gaya Hidup
# 11                                          Kesehatan
# 12                                         Pendidikan
# 13                                         Pariwisata
# 14                                         Pendidikan
# 15                                           Politika
# 16                                           Politika
# 17                                           Buleleng
# 18                                         Gaya Hidup
# 19                                           Politika
# 20                                          Klungkung
# 21                                           Politika
# 22                                           Buleleng
# 23                                         Pendidikan
# 24                                           Politika
# 25                                           Nasional
# 26                                           Politika
# 27                              Hiburan & Seni Budaya
# 28                                             Badung
# 29                              Hiburan & Seni Budaya

# %%
clean_data_combined.to_excel("C:/Users/asus/OneDrive/BPS/Neraca/beritaclean_combined_sektor16_2024_triwulan4_bali.xlsx")

# %% [markdown]
# # **SENTIMENT ANALYSIS**

# %% [markdown]
# ## Dataset Preparation

# %%
clean_data = pd.read_excel("C:/Users/asus/OneDrive/BPS/Neraca/beritaclean_combined_sektor16_2024_triwulan4_bali.xlsx")
clean_data
# Out:
#     Unnamed: 0                                              title    keyword  \
# 0            0  Solusi Mahayastra dan Kakarsana soal Peningkat...  kesehatan
# 1            1  Kampanye di Klungkung, Koster-Giri Janjikan Ke...  kesehatan
# 2            2  Giri Prasta Janjikan Seragam Sekolah dan Layan...  kesehatan
# 3            3  Ambara-Adi Mau Tingkatkan Layanan Kesehatan di...  kesehatan
# 4            4  Cegah Stunting, Giri-Brata Janji Tambah Anggar...  kesehatan
# 5            5  Layanan Telekonsultasi Kesehatan BPJS Mulai Di...  kesehatan
# 6            6    Kebiasaan yang Bisa Mengganggu Kesehatan Mental  kesehatan
# 7            7  Dari Debat Pilwali Kota Denpasar 2024: Paslon ...  kesehatan
# 8            8  KEK Sanur: KEK Kesehatan Peringkat Ke- 2 di Se...  kesehatan
# 9            9  Pertamina Patra Niaga Hadirkan Desa Ramah Anak...  kesehatan
# 10          10  Pertama di Aplikasi GoPay, Pengguna Bisa Akses...  kesehatan
# 11          11  Ikuti Perkembangan Zaman, BPOM Sosialisasikan ...  kesehatan
# 12          12  Hibah DRTPM Kemenristekdikti PMP: Peningkatan ...  kesehatan
# 13          13  The Sanur Perkenalkan KEK Kesehatan Sanur ke P...  kesehatan
# 14          14  Gatra Bali sebagai Aplikasi Usadha dalam Menun...  kesehatan
# 15          15  Menuju Kesehatan Berkualitas: Sutjidra-Supriat...  kesehatan
# 16          16  Kepemimpinan Satriya Pastikan Biaya Kesehatan ...  kesehatan
# 17          17  Dari Pelatihan Warga Binaan di Lapas Singaraja...  kesehatan
# 18          18  Stelatopia+ Dengan Prebiotik: Perawatan Kompre...  kesehatan
# 19          19  Berikan Layanan Kesehatan Terbaik, Satriya Pro...  kesehatan
# 20          20  Seminggu Lebih Kerja Keras Padamkan Kebakaran ...  kesehatan
# 21          21  Pemeriksaan Kesehatan Gratis Suyadinata Disamb...  kesehatan
# 22          22  Optimalkan Pelayanan Kesehatan Darurat RSUD Bu...  kesehatan
# 23          23  Sekolah Pascasarjana dan FKG Unair Inisiasi Pr...  kesehatan
# 24          24  Koster-Giri akan Bangun Sports Center Bali di ...  kesehatan
# 11     Rabu, 30 Oktober 2024 | 11:10 WIB
# 12   Selasa, 29 Oktober 2024 | 14:05 WIB
# 13   Selasa, 29 Oktober 2024 | 12:25 WIB
# 14   Selasa, 29 Oktober 2024 | 09:51 WIB
# 15    Jumat, 25 Oktober 2024 | 19:02 WIB
# 16    Jumat, 25 Oktober 2024 | 10:39 WIB
# 17     Rabu, 23 Oktober 2024 | 20:25 WIB
# 18     Rabu, 23 Oktober 2024 | 08:55 WIB
# 19     Rabu, 23 Oktober 2024 | 08:38 WIB
# 20   Selasa, 22 Oktober 2024 | 07:10 WIB
# 21    Sabtu, 19 Oktober 2024 | 15:53 WIB
# 22    Kamis, 17 Oktober 2024 | 17:30 WIB
# 23    Kamis, 17 Oktober 2024 | 14:08 WIB
# 24    Senin, 14 Oktober 2024 | 15:00 WIB
# 25     Kamis, 3 Oktober 2024 | 08:35 WIB
# 26    Selasa, 1 Oktober 2024 | 09:40 WIB
# 27    Jumat, 1 November 2024 | 11:29 WIB
# 28      Rabu, 9 Oktober 2024 | 21:34 WIB
# 29   Senin, 11 November 2024 | 12:45 WIB
#
#                                               content
# 0   Dua pasangan calon (paslon) yang berlaga dalam...
# 1   Calon gubernur dan wakil gubernur Bali nomor u...
# 2   Calon wakil gubernur (cawagub) Bali, I Nyoman ...
# 3   Duet Gede Ngurah Ambara Putra-I Nengah Yasa Ad...
# 4   Calon bupati (cabup) Bangli nomor urut 3, Ida ...
# 5                                           Kesehatan
# 6                                           Kesehatan
# 7                                            Denpasar
# 8                                          Pariwisata
# 9                                 Ekonomi & Perbankan
# 10                                         Gaya Hidup
# 11                                          Kesehatan
# 12                                         Pendidikan
# 13                                         Pariwisata
# 14                                         Pendidikan
# 15                                           Politika
# 16                                           Politika
# 17                                           Buleleng
# 18                                         Gaya Hidup
# 19                                           Politika
# 20                                          Klungkung
# 21                                           Politika
# 22                                           Buleleng
# 23                                         Pendidikan
# 24                                           Politika
# 25                                           Nasional
# 26                                           Politika
# 27                              Hiburan & Seni Budaya
# 28                                             Badung
# 29                              Hiburan & Seni Budaya

# %%
clean_data_2 = clean_data.drop(['link','date','source'], axis=1)
clean_data_2
# Out:
#     Unnamed: 0                                              title    keyword  \
# 0            0  Solusi Mahayastra dan Kakarsana soal Peningkat...  kesehatan
# 1            1  Kampanye di Klungkung, Koster-Giri Janjikan Ke...  kesehatan
# 2            2  Giri Prasta Janjikan Seragam Sekolah dan Layan...  kesehatan
# 3            3  Ambara-Adi Mau Tingkatkan Layanan Kesehatan di...  kesehatan
# 4            4  Cegah Stunting, Giri-Brata Janji Tambah Anggar...  kesehatan
# 5            5  Layanan Telekonsultasi Kesehatan BPJS Mulai Di...  kesehatan
# 6            6    Kebiasaan yang Bisa Mengganggu Kesehatan Mental  kesehatan
# 7            7  Dari Debat Pilwali Kota Denpasar 2024: Paslon ...  kesehatan
# 8            8  KEK Sanur: KEK Kesehatan Peringkat Ke- 2 di Se...  kesehatan
# 9            9  Pertamina Patra Niaga Hadirkan Desa Ramah Anak...  kesehatan
# 10          10  Pertama di Aplikasi GoPay, Pengguna Bisa Akses...  kesehatan
# 11          11  Ikuti Perkembangan Zaman, BPOM Sosialisasikan ...  kesehatan
# 12          12  Hibah DRTPM Kemenristekdikti PMP: Peningkatan ...  kesehatan
# 13          13  The Sanur Perkenalkan KEK Kesehatan Sanur ke P...  kesehatan
# 14          14  Gatra Bali sebagai Aplikasi Usadha dalam Menun...  kesehatan
# 15          15  Menuju Kesehatan Berkualitas: Sutjidra-Supriat...  kesehatan
# 16          16  Kepemimpinan Satriya Pastikan Biaya Kesehatan ...  kesehatan
# 17          17  Dari Pelatihan Warga Binaan di Lapas Singaraja...  kesehatan
# 18          18  Stelatopia+ Dengan Prebiotik: Perawatan Kompre...  kesehatan
# 19          19  Berikan Layanan Kesehatan Terbaik, Satriya Pro...  kesehatan
# 20          20  Seminggu Lebih Kerja Keras Padamkan Kebakaran ...  kesehatan
# 21          21  Pemeriksaan Kesehatan Gratis Suyadinata Disamb...  kesehatan
# 22          22  Optimalkan Pelayanan Kesehatan Darurat RSUD Bu...  kesehatan
# 23          23  Sekolah Pascasarjana dan FKG Unair Inisiasi Pr...  kesehatan
# 24          24  Koster-Giri akan Bangun Sports Center Bali di ...  kesehatan
# 25          25  Dari Arifin Panigoro Dialog Seri Ke- 13, Darur...  kesehatan
# 26          26  Adi Arnawa Prihatin dengan Kondisi Pasutri di ...  kesehatan
# 27          27  Heboh, Foto Ziva Magnolya Diam-diam Bertunanga...     sosial
# 28          28  Plt. Bupati Badung Suiasa Sampaikan Penjelasan...     sosial
# 29          29  Agus Salim Ternyata Berbohong? Terciduk Kamera...     donasi
#
#                                               content
# 0   Dua pasangan calon (paslon) yang berlaga dalam...
# 1   Calon gubernur dan wakil gubernur Bali nomor u...
# 2   Calon wakil gubernur (cawagub) Bali, I Nyoman ...
# 3   Duet Gede Ngurah Ambara Putra-I Nengah Yasa Ad...
# 4   Calon bupati (cabup) Bangli nomor urut 3, Ida ...
# 5                                           Kesehatan
# 6                                           Kesehatan
# 7                                            Denpasar
# 8                                          Pariwisata
# 9                                 Ekonomi & Perbankan
# 10                                         Gaya Hidup
# 11                                          Kesehatan
# 12                                         Pendidikan
# 13                                         Pariwisata
# 14                                         Pendidikan
# 15                                           Politika
# 16                                           Politika
# 17                                           Buleleng
# 18                                         Gaya Hidup
# 19                                           Politika
# 20                                          Klungkung
# 21                                           Politika
# 22                                           Buleleng
# 23                                         Pendidikan
# 24                                           Politika
# 25                                           Nasional
# 26                                           Politika
# 27                              Hiburan & Seni Budaya
# 28                                             Badung
# 29                              Hiburan & Seni Budaya

# %% [markdown]
# ## Preprocessing Judul Bahasa Indonesia

# %%
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from transformers import BertTokenizer

# Download stopwords dari NLTK
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Inisialisasi Stemmer (Sastrawi)
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Tokenizer IndoBERT (atau BERT)
tokenizer = BertTokenizer.from_pretrained('indolem/indobert-base-uncased')

# %%
# Fungsi Preprocessing
def preprocess_text(text):
    # 1. Mengubah teks ke huruf kecil
    text = text.lower()

    # 2. Menghapus URL, mention, hashtag, dan angka
    text = re.sub(r"http\S+|www\S+|https\S+", "", text)  # Menghapus URL
    text = re.sub(r"@\w+", "", text)  # Menghapus mention (@username)
    text = re.sub(r"#\w+", "", text)  # Menghapus hashtag (#hashtag)
    text = re.sub(r"\d+", "", text)  # Menghapus angka

    # 3. Menghapus tanda baca (jika diperlukan)
    text = re.sub(r"[^\w\s]", "", text)  # Menghapus tanda baca

    # 4. Tokenisasi menggunakan NLTK
    words = word_tokenize(text)  # Memecah kalimat menjadi kata

    # # 5. Menghapus stop words (menggunakan NLTK)
    # stop_words = set(stopwords.words('indonesian'))
    # words = [word for word in words if word not in stop_words]

    # 6. Stemming dengan Sastrawi
    words = [stemmer.stem(word) for word in words]

    # 7. Menggabungkan kembali kata-kata menjadi kalimat
    cleaned_text = " ".join(words)

    # 8. Tokenisasi menggunakan IndoBERT tokenizer (optional: untuk input model)
    input_ids = tokenizer.encode(cleaned_text, add_special_tokens=True)
    
    return cleaned_text, input_ids

# %%
clean_data_3 = clean_data_2.copy()

# Terapkan fungsi preprocess_text ke kolom 'description'
clean_data_3['cleaned_title'], clean_data_3['input_ids'] = zip(*clean_data_3['title'].apply(preprocess_text))

# %%
print(clean_data_3.shape)
clean_data_3
# Out:
# (30, 6)
#     Unnamed: 0                                              title    keyword  \
# 0            0  Solusi Mahayastra dan Kakarsana soal Peningkat...  kesehatan
# 1            1  Kampanye di Klungkung, Koster-Giri Janjikan Ke...  kesehatan
# 2            2  Giri Prasta Janjikan Seragam Sekolah dan Layan...  kesehatan
# 3            3  Ambara-Adi Mau Tingkatkan Layanan Kesehatan di...  kesehatan
# 4            4  Cegah Stunting, Giri-Brata Janji Tambah Anggar...  kesehatan
# 5            5  Layanan Telekonsultasi Kesehatan BPJS Mulai Di...  kesehatan
# 6            6    Kebiasaan yang Bisa Mengganggu Kesehatan Mental  kesehatan
# 7            7  Dari Debat Pilwali Kota Denpasar 2024: Paslon ...  kesehatan
# 8            8  KEK Sanur: KEK Kesehatan Peringkat Ke- 2 di Se...  kesehatan
# 9            9  Pertamina Patra Niaga Hadirkan Desa Ramah Anak...  kesehatan
# 10          10  Pertama di Aplikasi GoPay, Pengguna Bisa Akses...  kesehatan
# 11          11  Ikuti Perkembangan Zaman, BPOM Sosialisasikan ...  kesehatan
# 12          12  Hibah DRTPM Kemenristekdikti PMP: Peningkatan ...  kesehatan
# 13          13  The Sanur Perkenalkan KEK Kesehatan Sanur ke P...  kesehatan
# 14          14  Gatra Bali sebagai Aplikasi Usadha dalam Menun...  kesehatan
# 15          15  Menuju Kesehatan Berkualitas: Sutjidra-Supriat...  kesehatan
# 16          16  Kepemimpinan Satriya Pastikan Biaya Kesehatan ...  kesehatan
# 17          17  Dari Pelatihan Warga Binaan di Lapas Singaraja...  kesehatan
# 18          18  Stelatopia+ Dengan Prebiotik: Perawatan Kompre...  kesehatan
# 19          19  Berikan Layanan Kesehatan Terbaik, Satriya Pro...  kesehatan
# 20          20  Seminggu Lebih Kerja Keras Padamkan Kebakaran ...  kesehatan
# 21          21  Pemeriksaan Kesehatan Gratis Suyadinata Disamb...  kesehatan
# 22          22  Optimalkan Pelayanan Kesehatan Darurat RSUD Bu...  kesehatan
# 23          23  Sekolah Pascasarjana dan FKG Unair Inisiasi Pr...  kesehatan
# 24          24  Koster-Giri akan Bangun Sports Center Bali di ...  kesehatan
# 25          25  Dari Arifin Panigoro Dialog Seri Ke- 13, Darur...  kesehatan
# 26          26  Adi Arnawa Prihatin dengan Kondisi Pasutri di ...  kesehatan
# 27          27  Heboh, Foto Ziva Magnolya Diam-diam Bertunanga...     sosial
# 28          28  Plt. Bupati Badung Suiasa Sampaikan Penjelasan...     sosial
# 29          29  Agus Salim Ternyata Berbohong? Terciduk Kamera...     donasi
#
#                                               content  \
# 0   Dua pasangan calon (paslon) yang berlaga dalam...
# 1   Calon gubernur dan wakil gubernur Bali nomor u...
# 2   Calon wakil gubernur (cawagub) Bali, I Nyoman ...
# 3   Duet Gede Ngurah Ambara Putra-I Nengah Yasa Ad...
# 4   Calon bupati (cabup) Bangli nomor urut 3, Ida ...
# 5                                           Kesehatan
# 6                                           Kesehatan
# 7                                            Denpasar
# 8                                          Pariwisata
# 9                                 Ekonomi & Perbankan
# 10                                         Gaya Hidup
# 11                                          Kesehatan
# 12                                         Pendidikan
# 13                                         Pariwisata
# 14                                         Pendidikan
# 15                                           Politika
# 16                                           Politika
# 17                                           Buleleng
# 18                                         Gaya Hidup
# 19                                           Politika
# 20                                          Klungkung
# 21                                           Politika
# 22                                           Buleleng
# 23                                         Pendidikan
# 24                                           Politika
# 25                                           Nasional
# 26                                           Politika
# 27                              Hiburan & Seni Budaya
# 28                                             Badung
# 29                              Hiburan & Seni Budaya
#
#                                         cleaned_title  \
# 0   solusi mahayastra dan kakarsana soal tingkat l...
# 1   kampanye di klungkung kostergiri janji kesehat...
# 2   giri prasta janji seragam sekolah dan layan se...
# 3   ambaraadi mau tingkat layan sehat di banjarban...
# 4   cegah stunting giribrata janji tambah anggar s...
# 5   layan telekonsultasi sehat bpjs mulai uji coba...
# 6                 biasa yang bisa ganggu sehat mental
# 7   dari debat pilwali kota denpasar paslon jayawi...
# 8   kek sanur kek sehat peringkat ke di sektor jas...
# 9   pertamina patra niaga hadir desa ramah anak pe...
# 10  pertama di aplikasi gopay guna bisa akses asur...
# 11  ikut kembang zaman bpom sosialisasi regulasi b...
# 12  hibah drtpm kemenristekdikti pmp tingkat sehat...
# 13  the sanur kenal kek sehat sanur ke pasar austr...
# 14  gatra bal bagai aplikasi usadha dalam tunjang ...
# 15  tuju sehat kualitas sutjidrasupriatna siap dok...
# 16  pimpin satriya pasti biaya sehat masyarakat gr...
# 17  dari latih warga bina di lapas singaraja latih...
# 18  stelatopia dengan prebiotik awat komprehensif ...
# 19  ikan layan sehat baik satriya program tingkat ...
# 20  minggu lebih kerja keras padam bakar tpa di nu...
# 21  periksa sehat gratis suyadinata sambut antusia...
# 22  optimal layan sehat darurat rsud buleleng bisa...
# 23  sekolah pascasarjana dan fkg unair inisiasi pr...
# 24  kostergiri akan bangun sports center bal di ba...
# 25  dari arifin panigoro dialog seri ke darurat se...
# 26  adi arnawa prihatin dengan kondisi pasutri di ...
# 27  heboh foto ziva magnolya diamdiam tunang denga...
# 28  plt bupati badung suiasa sampai jelas raperda ...
# 29  agus salim nyata bohong ciduk kamera bisa liha...
#
#                                             input_ids
# 0   [3, 6920, 5774, 12348, 3423, 1501, 11176, 3173...
# 1   [3, 4917, 1485, 26080, 27217, 3810, 1667, 6453...
# 2   [3, 18719, 5806, 1512, 6453, 10007, 2270, 1501...
# 3   [3, 21833, 9707, 2046, 2882, 2842, 2939, 1476,...
# 4   [3, 14888, 1534, 945, 3207, 935, 2227, 18719, ...
# 5   [3, 2939, 1476, 8860, 2235, 19538, 5427, 5719,...
# 6     [3, 2799, 1497, 1777, 5511, 943, 5427, 7397, 4]
# 7   [3, 1542, 12550, 4086, 9389, 939, 1850, 7791, ...
# 8   [3, 1898, 29577, 1898, 5427, 4865, 1500, 1485,...
# 9   [3, 6167, 2769, 1780, 12087, 4112, 2019, 9790,...
# 10  [3, 1889, 1485, 5952, 3686, 2187, 950, 4813, 1...
# 11  [3, 3354, 11101, 3400, 27201, 10068, 13798, 18...
# 12  [3, 16290, 2455, 9296, 931, 3154, 2203, 4745, ...
# 13  [3, 1969, 29577, 7751, 1898, 5427, 29577, 1500...
# 14  [3, 6509, 1780, 2513, 2560, 5952, 13329, 22143...
# 15  [3, 31615, 5427, 4493, 5242, 3504, 5017, 1562,...
# 16  [3, 24496, 2688, 1667, 1494, 3417, 3592, 5427,...
# 17  [3, 1542, 5050, 2082, 13092, 1485, 26304, 1303...
# 18  [3, 12485, 5351, 13197, 1545, 12398, 4207, 795...
# 19  [3, 3675, 2939, 1476, 5427, 1983, 2688, 1667, ...
# 20  [3, 3554, 1716, 2533, 3173, 16457, 4327, 20647...
# 21  [3, 20286, 5427, 6938, 25595, 15122, 1640, 168...
# 22  [3, 10998, 2939, 1476, 5427, 6262, 14760, 2660...
# 23  [3, 2270, 16252, 1501, 12388, 938, 28302, 9628...
# 24  [3, 27217, 3810, 1667, 1634, 7593, 16779, 6637...
# 25  [3, 1542, 11245, 5376, 26993, 6175, 2699, 1500...
# 26  [3, 5270, 13370, 1813, 13690, 1545, 2706, 1746...
# 27  [3, 22327, 4724, 8263, 3000, 11892, 25644, 936...
# 28  [3, 24667, 4705, 21769, 19720, 1654, 1996, 260...
# 29  [3, 2902, 11467, 5169, 18665, 20307, 1532, 775...

# %% [markdown]
# ## Translate Judul ke Bahasa Inggris dan Preprocessing

# %%
pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2022.6.15.1)
# Requirement already satisfied: hstspreload in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.11.1)
# Requirement already satisfied: sniffio in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Fungsi translator

# %%
from googletrans import Translator
import pandas as pd

# Fungsi untuk menerjemahkan teks ke bahasa Inggris
def translate_to_english(text):
    translator = Translator()
    try:
        translated_text = translator.translate(text, dest='en').text
        return translated_text
    except Exception as e:
        print(f"Error translating text: {e}")
        return text

# %%
clean_data_4 = clean_data_3.copy()

# Menerapkan fungsi translate_to_english pada kolom "Title"
clean_data_4['title_translated'] = clean_data_4['title'].apply(translate_to_english)

# Menampilkan dataframe setelah perubahan
print(clean_data_4.shape)
clean_data_4
# Out:
# (30, 7)
#     Unnamed: 0                                              title    keyword  \
# 0            0  Solusi Mahayastra dan Kakarsana soal Peningkat...  kesehatan
# 1            1  Kampanye di Klungkung, Koster-Giri Janjikan Ke...  kesehatan
# 2            2  Giri Prasta Janjikan Seragam Sekolah dan Layan...  kesehatan
# 3            3  Ambara-Adi Mau Tingkatkan Layanan Kesehatan di
#                                         cleaned_title  \
# 0   solusi mahayastra dan kakarsana soal tingkat l...
# 1   kampanye di klungkung kostergiri janji kesehat...
# 2   giri prasta janji seragam sekolah dan layan se...
# 3   ambaraadi mau tingkat layan sehat di banjarban...
# 4   cegah stunting giribrata janji tambah anggar s...
# 5   layan telekonsultasi sehat bpjs mulai uji coba...
# 6                 biasa yang bisa ganggu sehat mental
# 7   dari debat pilwali kota denpasar paslon jayawi...
# 8   kek sanur kek sehat peringkat ke di sektor jas...
# 9   pertamina patra niaga hadir desa ramah anak pe...
# 10  pertama di aplikasi gopay guna bisa akses asur...
# 11  ikut kembang zaman bpom sosialisasi regulasi b...
# 12  hibah drtpm kemenristekdikti pmp tingkat sehat...
# 13  the sanur kenal kek sehat sanur ke pasar austr...
# 14  gatra bal bagai aplikasi usadha dalam tunjang ...
# 15  tuju sehat kualitas sutjidrasupriatna siap dok...
# 16  pimpin satriya pasti biaya sehat masyarakat gr...
# 17  dari latih warga bina di lapas singaraja latih...
# 18  stelatopia dengan prebiotik awat komprehensif ...
# 19  ikan layan sehat baik satriya program tingkat ...
# 20  minggu lebih kerja keras padam bakar tpa di nu...
# 21  periksa sehat gratis suyadinata sambut antusia...
# 22  optimal layan sehat darurat rsud buleleng bisa...
# 23  sekolah pascasarjana dan fkg unair inisiasi pr...
# 24  kostergiri akan bangun sports center bal di ba...
# 25  dari arifin panigoro dialog seri ke darurat se...
# 26  adi arnawa prihatin dengan kondisi pasutri di ...
# 27  heboh foto ziva magnolya diamdiam tunang denga...
# 28  plt bupati badung suiasa sampai jelas raperda ...
# 29  agus salim nyata bohong ciduk kamera bisa liha...
#
#                                             input_ids  \
# 0   [3, 6920, 5774, 12348, 3423, 1501, 11176, 3173...
# 1   [3, 4917, 1485, 26080, 27217, 3810, 1667, 6453...
# 2   [3, 18719, 5806, 1512, 6453, 10007, 2270, 1501...
# 3   [3, 21833, 9707, 2046, 2882, 2842, 2939, 1476,...
# 4   [3, 14888, 1534, 945, 3207, 935, 2227, 18719, ...
# 5   [3, 2939, 1476, 8860, 2235, 19538, 5427, 5719,...
# 6     [3, 2799, 1497, 1777, 5511, 943, 5427, 7397, 4]
# 7   [3, 1542, 12550, 4086, 9389, 939, 1850, 7791, ...
# 8   [3, 1898, 29577, 1898, 5427, 4865, 1500, 1485,...
# 9   [3, 6167, 2769, 1780, 12087, 4112, 2019, 9790,...
# 10  [3, 1889, 1485, 5952, 3686, 2187, 950, 4813, 1...
# 11  [3, 3354, 11101, 3400, 27201, 10068, 13798, 18...
# 12  [3, 16290, 2455, 9296, 931, 3154, 2203, 4745, ...
# 13  [3, 1969, 29577, 7751, 1898, 5427, 29577, 1500...
# 14  [3, 6509, 1780, 2513, 2560, 5952, 13329, 22143...
# 15  [3, 31615, 5427, 4493, 5242, 3504, 5017, 1562,...
# 16  [3, 24496, 2688, 1667, 1494, 3417, 3592, 5427,...
# 17  [3, 1542, 5050, 2082, 13092, 1485, 26304, 1303...
# 18  [3, 12485, 5351, 13197, 1545, 12398, 4207, 795...
# 19  [3, 3675, 2939, 1476, 5427, 1983, 2688, 1667, ...
# 20  [3, 3554, 1716, 2533, 3173, 16457, 4327, 20647...
# 21  [3, 20286, 5427, 6938, 25595, 15122, 1640, 168...
# 22  [3, 10998, 2939, 1476, 5427, 6262, 14760, 2660...
# 23  [3, 2270, 16252, 1501, 12388, 938, 28302, 9628...
# 24  [3, 27217, 3810, 1667, 1634, 7593, 16779, 6637...
# 25  [3, 1542, 11245, 5376, 26993, 6175, 2699, 1500...
# 26  [3, 5270, 13370, 1813, 13690, 1545, 2706, 1746...
# 27  [3, 22327, 4724, 8263, 3000, 11892, 25644, 936...
# 28  [3, 24667, 4705, 21769, 19720, 1654, 1996, 260...
# 29  [3, 2902, 11467, 5169, 18665, 20307, 1532, 775...
#
#                                      title_translated
# 0   Mahayastra and Kakarsana solutions about impro...
# 1   Campaign in Klungkung, Koster-Giri promises fr...
# 2   Giri Prasta promised school uniforms and free ...
# 3   AMBARA-ADI WANT TO IMPROVE HEALTH SERVICES IN ...
# 4   Prevent stunting, giri-brata promises to add h...
# 5   BPJS Health Teleconsultation Services began to...
# 6        Habits that can interfere with mental health
# 7   From the Denpasar City Pilwali Debate 2024: Pa...
# 8   KEK Sanur: KEK Health ranked 2nd in the Servic...
# 9   Pertamina Patra Niaga Presents a Child Friendl...
# 10  First in the Gopay application, users can acce...
# 11  Follow the times, BPOM socializes the latest r...
# 12  DRTPM Grant Kemenristekdikti PMP: Improvement ...
# 13  The Sanur Introducing Sanur Health to the Aust...
# 14  Gatra Bali as a Usadha application in supporti...
# 15  Towards quality health: Sutjidra-Supriatna Pre...
# 16  Satriya's leadership Ensures FREE Public Healt...
# 17  From the training of fostered residents in Sin...
# 18  Stelatopia with probiotics: Comprehensive Care...
# 19  Provide the best health services, Satriya prog...
# 20  A week more hard work to extinguish TPA fires ...
# 21  Suyadinata's free health checks were greeted e...
# 22  Optimize emergency health services Buleleng Re...
# 23  Postgraduate School and FKG UNAIR Initiation o...
# 24  Koster-Giri will build a Sports Center in Bali...
# 25  From Arifin Panigoro Dialogue of the 13th Seri...
# 26  Adi Arnawa is concerned about the condition of...
# 27  Splashy, Ziva Magnolya's photo was secretly en...
# 28  Plt.Regent of Badung Suiasa conveyed the expla...
# 29  Agus Salim turned out to be lying?Camer caught...

# %%
import nltk
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import spacy
# Load the model
nlp = spacy.load("en_core_web_sm")

# Download NLTK resources (if not already done)
nltk.download('punkt')
nltk.download('stopwords')

# Load spaCy English model for lemmatization
nlp = spacy.load("en_core_web_sm")

def clean_text(text):
    """
    Perform basic text cleaning including:
    - Lowercasing
    - Removing punctuation and special characters
    - Removing extra spaces
    """
    # Convert to lowercase
    text = text.lower()

    # Remove punctuation and special characters (using regular expressions)
    text = re.sub(f"[{string.punctuation}]", "", text)

    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# def remove_stopwords(text):
#     """
#     Remove stopwords from the text.
#     """
#     stop_words = set(stopwords.words('english'))
#     word_tokens = word_tokenize(text)
    
#     # Filter out stopwords
#     filtered_text = [word for word in word_tokens if word not in stop_words]
    
#     return ' '.join(filtered_text)

def lemmatize_text(text):
    """
    Lemmatize the text to reduce words to their base form.
    """
    doc = nlp(text)
    
    # Lemmatize each token (word) and join them back into a string
    lemmatized_text = " ".join([token.lemma_ for token in doc])
    
    return lemmatized_text

def preprocess_text(text):
    """
    Complete preprocessing pipeline:
    1. Clean the text (remove punctuation, lowercase)
    2. Remove stopwords
    3. Lemmatize the text
    """
    text = clean_text(text)
    # text = remove_stopwords(text)
    text = lemmatize_text(text)
    
    return text
# Out:
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:1144: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\tensor\python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
clean_data_4['cleaned_title_translated'] = clean_data_4['title_translated'].apply(preprocess_text)

print(clean_data_4.shape)
clean_data_4
# Out:
# (30, 8)
#     Unnamed: 0                                              title    keyword  \
# 0            0  Solusi Mahayastra dan Kakarsana soal Peningkat...  kesehatan
# 1            1  Kampanye di Klungkung, Koster-Giri Janjikan Ke...  kesehatan
# 2            2  Giri Prasta Janjikan Seragam Sekolah dan Layan...  kesehatan
# 3            3  Ambara-Adi Mau Tingkatkan Layanan Kesehatan di...  kesehatan
# 4            4  Cegah Stunting, Giri-Brata Janji Tambah Anggar...  kesehatan
# 5            5  Layanan Telekonsultasi Kesehatan BPJS Mulai Di...  kesehatan
# 6            6    Kebiasaan yang Bisa Mengganggu Kesehatan Mental  kesehatan
# 7            7  Dari Debat Pilwali Kota Denpasar 2024: Paslon ...  kesehatan
# 8            8  KEK Sanur: KEK Kesehatan Peringkat Ke- 2 di Se...  kesehatan
# 9            9  Pertamina Patra Niaga Hadirkan Desa Ramah Anak...  kesehatan
# 10          10  Pertama di Aplikasi GoPay, Pengguna Bisa Akses...  kesehatan
# 11          11  Ikuti Perkembangan Zaman, BPOM Sosialisasikan ...  kesehatan
# 12          12  Hibah DRTPM Kemenristekdikti PMP: Peningkatan ...  kesehatan
# 13          13  The Sanur Perkenalkan KEK Kesehatan Sanur ke P...  kesehatan
# 14          14  Gatra Bali sebagai Aplikasi Usadha dalam Menun...  kesehatan
# 15          15  Menuju Kesehatan Berkualitas: Sutjidra-Supriat...  kesehatan
# 16          16  Kepemimpinan Satriya Pastikan Biaya Kesehatan ...  kesehatan
# 17          17  Dari Pelatihan Warga Binaan di Lapas Singaraja...  kesehatan
# 18          18  Stelatopia+ Dengan Prebiotik: Perawatan Kompre...  kesehatan
# 19          19  Berikan Layanan Kesehatan Terbaik, Satriya Pro...  kesehatan
# 20          20  Seminggu Lebih Kerja Keras Padamkan Kebakaran ...  kesehatan
# 21          21  Pemeriksaan Kesehatan Gratis Suyadinata Disamb...  kesehatan
# 22          22  Optimalkan Pelayanan Kesehatan Darurat RSUD Bu...  kesehatan
# 23          23  Sekolah Pascasarjana dan FKG Unair Inisiasi Pr...  kesehatan
# 24          24  Koster-Giri akan Bangun Sports Center Bali di ...  kesehatan
# 25          25  Dari Arifin Panigoro Dialog Seri Ke- 13, Darur...  kesehatan
# 26          26  Adi Arnawa Prihatin dengan Kondisi Pasutri di ...  kesehatan
# 27          27  Heboh, Foto Ziva Magnolya Diam-diam Bertunanga...     sosial
# 28          28  Plt. Bupati Badung Suiasa Sampaikan Penjelasan...     sosial
# 29          29  Agus Salim Ternyata Berbohong? Terciduk Kamera...     donasi
#
#                                               content  \
# 0   Dua pasangan calon (paslon) yang berlaga dalam...
# 1   Calon gubernur dan wakil gubernur Bali nomor u...
# 2   Calon wakil gubernur (cawagub) Bali, I Nyoman ...
# 3   Duet Gede Ngurah Ambara Putra-I Nengah Yasa Ad...
# 4   Calon bupati (cabup) Bangli nomor urut 3, Ida ...
# 5                                           Kesehatan
# 6                                           Kesehatan
# 7                                            Denpasar
# 8                                          Pariwisata
# 9                                 Ekonomi & Perbankan
# 10                                         Gaya Hidup
# 11                                          Kesehatan
# 12                                         Pendidikan
# 13                                         Pariwisata
# 14                                         Pendidikan
# 15                                           Politika
# 16                                           Politika
# 17                                           Buleleng
# 18                                         Gaya Hidup
# 19                                           Politika
# 20                                          Klungkung
# 21                                           Politika
# 22                                           Buleleng
# 23                                         Pendidikan
# 24                                           Politika
# 25                                           Nasional
# 26                                           Politika
# 27                              Hiburan & Seni Budaya
# 28                                             Badung
# 29                              Hiburan & Seni Budaya
#
#                                         cleaned_title  \
# 0   solusi mahayastra dan kakarsana soal tingkat l...
# 1   kampanye di klungkung kostergiri janji kesehat...
# 2   giri prasta janji seragam sekolah dan layan se...
# 3   ambaraadi mau tingkat layan sehat di banjarban...
# 4   cegah stunting giribrata janji tambah anggar s...
# 5   layan telekonsultasi sehat bpjs mulai uji coba...
# 6                 biasa yang bisa ganggu sehat mental
# 7   dari debat pilwali kota denpasar paslon jayawi...
# 8   kek sanur kek sehat peringkat ke di sektor jas...
# 9   pertamina patra niaga hadir desa ramah anak pe...
# 10  pertama di aplikasi gopay guna bisa akses asur...
# 11  ikut kembang zaman bpom sosialisasi regulasi b...
# 12  hibah drtpm kemenristekdikti pmp tingkat sehat...
# 13  the sanur kenal kek sehat sanur ke pasar austr...
# 14  gatra bal bagai aplikasi usadha dalam tunjang ...
# 15  tuju sehat kualitas sutjidrasupriatna siap dok...
# 16  pimpin satriya pasti biaya sehat masyarakat gr...
# 17  dari latih warga bina di lapas singaraja latih...
# 18  stelatopia dengan prebiotik awat komprehensif ...
# 19  ikan layan sehat baik satriya program tingkat ...
# 20  minggu lebih kerja keras padam bakar tpa di nu...
# 21  periksa sehat gratis suyadinata sambut antusia...
# 22  optimal layan sehat darurat rsud buleleng bisa...
# 23  sekolah pascasarjana dan fkg unair inisiasi pr...
# 24  kostergiri akan bangun sports center bal di ba...
# 25  dari arifin panigoro dialog seri ke darurat se...
# 26  adi arnawa prihatin dengan kondisi pasutri di ...
# 27  heboh foto ziva magnolya diamdiam tunang denga...
# 28  plt bupati badung suiasa sampai jelas raperda ...
# 29  agus salim nyata bohong ciduk kamera bisa liha...
#
#                                             input_ids  \
# 0   [3, 6920, 5774, 12348, 3423, 1501, 11176, 3173...
# 1   [3, 4917, 1485, 26080, 27217, 3810, 1667, 6453...
# 2   [3, 18719, 5806, 1512, 6453, 10007, 2270, 1501...
# 3   [3, 21833, 9707, 2046, 2882, 2842, 2939, 1476,...
# 4   [3, 14888, 1534, 945, 3207, 935, 2227, 18719, ...
# 5   [3, 2939, 1476, 8860, 2235, 19538, 5427, 5719,...
# 6     [3, 2799, 1497, 1777, 5511, 943, 5427, 7397, 4]
# 7   [3, 1542, 12550, 4086, 9389, 939, 1850, 7791, ...
# 8   [3, 1898, 29577, 1898, 5427, 4865, 1500, 1485,...
# 9   [3, 6167, 2769, 1780, 12087, 4112, 2019, 9790,...
# 10  [3, 1889, 1485, 5952, 3686, 2187, 950, 4813, 1...
# 11  [3, 3354, 11101, 3400, 27201, 10068, 13798, 18...
# 12  [3, 16290, 2455, 9296, 931, 3154, 2203, 4745, ...
# 13  [3, 1969, 29577, 7751, 1898, 5427, 29577, 1500...
# 14  [3, 6509, 1780, 2513, 2560, 5952, 13329, 22143...
# 15  [3, 31615, 5427, 4493, 5242, 3504, 5017, 1562,...
# 16  [3, 24496, 2688, 1667, 1494, 3417, 3592, 5427,...
# 17  [3, 1542, 5050, 2082, 13092, 1485, 26304, 1303...
# 18  [3, 12485, 5351, 13197, 1545, 12398, 4207, 795...
# 19  [3, 3675, 2939, 1476, 5427, 1983, 2688, 1667, ...
# 20  [3, 3554, 1716, 2533, 3173, 16457, 4327, 20647...
# 21  [3, 20286, 5427, 6938, 25595, 15122, 1640, 168...
# 22  [3, 10998, 2939, 1476, 5427, 6262, 14760, 2660...
# 23  [3, 2270, 16252, 1501, 12388, 938, 28302, 9628...
# 24  [3, 27217, 3810, 1667, 1634, 7593, 16779, 6637...
# 25  [3, 1542, 11245, 5376, 26993, 6175, 2699, 1500...
# 26  [3, 5270, 13370, 1813, 13690, 1545, 2706, 1746...
# 27  [3, 22327, 4724, 8263, 3000, 11892, 25644, 936...
# 28  [3, 24667, 4705, 21769, 19720, 1654, 1996, 260...
# 29  [3, 2902, 11467, 5169, 18665, 20307, 1532, 775...
#
#                                      title_translated  \
# 0   Mahayastra and Kakarsana solutions about impro...
# 1   Campaign in Klungkung, Koster-Giri promises fr...
# 2   Giri Prasta promised school uniforms and free ...
# 3   AMBARA-ADI WANT TO IMPROVE HEALTH SERVICES IN ...
# 4   Prevent stunting, giri-brata promises to add h...
# 5   BPJS Health Teleconsultation Services began to...
# 6        Habits that can interfere with mental health
# 7   From the Denpasar City Pilwali Debate 2024: Pa...
# 8   KEK Sanur: KEK Health ranked 2nd in the Servic...
# 9   Pertamina Patra Niaga Presents a Child Friendl...
# 10  First in the Gopay application, users can acce...
# 11  Follow the times, BPOM socializes the latest r...
# 12  DRTPM Grant Kemenristekdikti PMP: Improvement ...
# 13  The Sanur Introducing Sanur Health to the Aust...
# 14  Gatra Bali as a Usadha application in supporti...
# 15  Towards quality health: Sutjidra-Supriatna Pre...
# 16  Satriya's leadership Ensures FREE Public Healt...
# 17  From the training of fostered residents in Sin...
# 18  Stelatopia with probiotics: Comprehensive Care...
# 19  Provide the best health services, Satriya prog...
# 20  A week more hard work to extinguish TPA fires ...
# 21  Suyadinata's free health checks were greeted e...
# 22  Optimize emergency health services Buleleng Re...
# 23  Postgraduate School and FKG UNAIR Initiation o...
# 24  Koster-Giri will build a Sports Center in Bali...
# 25  From Arifin Panigoro Dialogue of the 13th Seri...
# 26  Adi Arnawa is concerned about the condition of...
# 27  Splashy, Ziva Magnolya's photo was secretly en...
# 28  Plt.Regent of Badung Suiasa conveyed the expla...
# 29  Agus Salim turned out to be lying?Camer caught...
#
#                              cleaned_title_translated
# 0   mahayastra and kakarsana solution about improv...
# 1   campaign in klungkung kostergiri promise free ...
# 2   giri prasta promise school uniform and free he...
# 3   ambaraadi want to improve health service in ba...
# 4   prevent stunt giribrata promise to add health ...
# 5   bpjs health teleconsultation service begin to ...
# 6         habit that can interfere with mental health
# 7   from the denpasar city pilwali debate 2024 pas...
# 8   kek sanur kek health rank 2nd in the service s...
# 9   pertamina patra niaga present a child friendly...
# 10  first in the gopay application user can access...
# 11  follow the time bpom socialize the late regula...
# 12  drtpm grant kemenristekdikti pmp improvement o...
# 13  the sanur introduce sanur health to the austra...
# 14  gatra bali as a usadha application in support ...
# 15  towards quality health sutjidrasupriatna prepa...
# 16  satriyas leadership ensure free public health ...
# 17  from the training of foster resident in singar...
# 18  stelatopia with probiotic comprehensive care o...
# 19  provide the good health service satriya progra...
# 20  a week more hard work to extinguish tpa fire i...
# 21  suyadinata free health check be greet enthusia...
# 22  optimize emergency health service buleleng reg...
# 23  postgraduate school and fkg unair initiation o...
# 24  kostergiri will build a sport center in bali i...
# 25  from arifin panigoro dialogue of the 13th seri...
# 26  adi arnawa be concerned about the condition of...
# 27  splashy ziva magnolyas photo be secretly engag...
# 28  pltregent of badung suiasa convey the explanat...
# 29  agus salim turn out to be lyingcamer catch can...

# %% [markdown]
# ## Sentimen Decision + Word Cloud + Export Result

# %%
data_ready = clean_data_4.copy()
data_ready.head()
# Out:
#    Unnamed: 0                                              title    keyword  \
# 0           0  Solusi Mahayastra dan Kakarsana soal Peningkat...  kesehatan
# 1           1  Kampanye di Klungkung, Koster-Giri Janjikan Ke...  kesehatan
# 2           2  Giri Prasta Janjikan Seragam Sekolah dan Layan...  kesehatan
# 3           3  Ambara-Adi Mau Tingkatkan Layanan Kesehatan di...  kesehatan
# 4           4  Cegah Stunting, Giri-Brata Janji Tambah Anggar...  kesehatan
#
#                                              content  \
# 0  Dua pasangan calon (paslon) yang berlaga dalam...
# 1  Calon gubernur dan wakil gubernur Bali nomor u...
# 2  Calon wakil gubernur (cawagub) Bali, I Nyoman ...
# 3  Duet Gede Ngurah Ambara Putra-I Nengah Yasa Ad...
# 4  Calon bupati (cabup) Bangli nomor urut 3, Ida ...
#
#                                        cleaned_title  \
# 0  solusi mahayastra dan kakarsana soal tingkat l...
# 1  kampanye di klungkung kostergiri janji kesehat...
# 2  giri prasta janji seragam sekolah dan layan se...
# 3  ambaraadi mau tingkat layan sehat di banjarban...
# 4  cegah stunting giribrata janji tambah anggar s...
#
#                                            input_ids  \
# 0  [3, 6920, 5774, 12348, 3423, 1501, 11176, 3173...
# 1  [3, 4917, 1485, 26080, 27217, 3810, 1667, 6453...
# 2  [3, 18719, 5806, 1512, 6453, 10007, 2270, 1501...
# 3  [3, 21833, 9707, 2046, 2882, 2842, 2939, 1476,...
# 4  [3, 14888, 1534, 945, 3207, 935, 2227, 18719, ...
#
#                                     title_translated  \
# 0  Mahayastra and Kakarsana solutions about impro...
# 1  Campaign in Klungkung, Koster-Giri promises fr...
# 2  Giri Prasta promised school uniforms and free ...
# 3  AMBARA-ADI WANT TO IMPROVE HEALTH SERVICES IN ...
# 4  Prevent stunting, giri-brata promises to add h...
#
#                             cleaned_title_translated
# 0  mahayastra and kakarsana solution about improv...
# 1  campaign in klungkung kostergiri promise free ...
# 2  giri prasta promise school uniform and free he...
# 3  ambaraadi want to improve health service in ba...
# 4  prevent stunt giribrata promise to add health ...

# %% [markdown]
# ### 1. TextBlob

# %% [markdown]
# #### Sentiment

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (8.1.3)
# Requirement already satisfied: joblib in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (2022.9.13)
# Requirement already satisfied: tqdm in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.8->textblob) (4.64.1)
# Requirement already satisfied: colorama in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
data_sentiment1 = data_ready[['keyword','title_translated','cleaned_title_translated']]
data_sentiment1
# Out:
#       keyword                                   title_translated  \
# 0   kesehatan  Mahayastra and Kakarsana solutions about impro...
# 1   kesehatan  Campaign in Klungkung, Koster-Giri promises fr...
# 2   kesehatan  Giri Prasta promised school uniforms and free ...
# 3   kesehatan  AMBARA-ADI WANT TO IMPROVE HEALTH SERVICES IN ...
# 4   kesehatan  Prevent stunting, giri-brata promises to add h...
# 5   kesehatan  BPJS Health Teleconsultation Services began to...
# 6   kesehatan       Habits that can interfere with mental health
# 7   kesehatan  From the Denpasar City Pilwali Debate 2024: Pa...
# 8   kesehatan  KEK Sanur: KEK Health ranked 2nd in the Servic...
# 9   kesehatan  Pertamina Patra Niaga Presents a Child Friendl...
# 10  kesehatan  First in the Gopay application, users can acce...
# 11  kesehatan  Follow the times, BPOM socializes the latest r...
# 12  kesehatan  DRTPM Grant Kemenristekdikti PMP: Improvement ...
# 13  kesehatan  The Sanur Introducing Sanur Health to the Aust...
# 14  kesehatan  Gatra Bali as a Usadha application in supporti...
# 15  kesehatan  Towards quality health: Sutjidra-Supriatna Pre...
# 16  kesehatan  Satriya's leadership Ensures FREE Public Healt...
# 17  kesehatan  From the training of fostered residents in Sin...
# 18  kesehatan  Stelatopia with probiotics: Comprehensive Care...
# 19  kesehatan  Provide the best health services, Satriya prog...
# 20  kesehatan  A week more hard work to extinguish TPA fires ...
# 21  kesehatan  Suyadinata's free health checks were greeted e...
# 22  kesehatan  Optimize emergency health services Buleleng Re...
# 23  kesehatan  Postgraduate School and FKG UNAIR Initiation o...
# 24  kesehatan  Koster-Giri will build a Sports Center in Bali...
# 25  kesehatan  From Arifin Panigoro Dialogue of the 13th Seri...
# 26  kesehatan  Adi Arnawa is concerned about the condition of...
# 27     sosial  Splashy, Ziva Magnolya's photo was secretly en...
# 28     sosial  Plt.Regent of Badung Suiasa conveyed the expla...
# 29     donasi  Agus Salim turned out to be lying?Camer caught...
#
#                              cleaned_title_translated
# 0   mahayastra and kakarsana solution about improv...
# 1   campaign in klungkung kostergiri promise free ...
# 2   giri prasta promise school uniform and free he...
# 3   ambaraadi want to improve health service in ba...
# 4   prevent stunt giribrata promise to add health ...
# 5   bpjs health teleconsultation service begin to ...
# 6         habit that can interfere with mental health
# 7   from the denpasar city pilwali debate 2024 pas...
# 8   kek sanur kek health rank 2nd in the service s...
# 9   pertamina patra niaga present a child friendly...
# 10  first in the gopay application user can access...
# 11  follow the time bpom socialize the late regula...
# 12  drtpm grant kemenristekdikti pmp improvement o...
# 13  the sanur introduce sanur health to the austra...
# 14  gatra bali as a usadha application in support ...
# 15  towards quality health sutjidrasupriatna prepa...
# 16  satriyas leadership ensure free public health ...
# 17  from the training of foster resident in singar...
# 18  stelatopia with probiotic comprehensive care o...
# 19  provide the good health service satriya progra...
# 20  a week more hard work to extinguish tpa fire i...
# 21  suyadinata free health check be greet enthusia...
# 22  optimize emergency health service buleleng reg...
# 23  postgraduate school and fkg unair initiation o...
# 24  kostergiri will build a sport center in bali i...
# 25  from arifin panigoro dialogue of the 13th seri...
# 26  adi arnawa be concerned about the condition of...
# 27  splashy ziva magnolyas photo be secretly engag...
# 28  pltregent of badung suiasa convey the explanat...
# 29  agus salim turn out to be lyingcamer catch can...

# %%
import pandas as pd
from textblob import TextBlob

# Pastikan kolom yang berisi alasan berhenti berlangganan dinamai 'reason'
# Jika nama kolom berbeda, ubah 'reason' sesuai dengan nama kolom yang benar
def get_sentiment(text):
    analysis = TextBlob(text)
    # Mengambil nilai sentimen
    return analysis.sentiment.polarity

# Menambahkan kolom baru untuk menyimpan nilai sentimen
data_sentiment1['sentiment_score_english'] = data_sentiment1['cleaned_title_translated'].apply(get_sentiment)

# Mengkategorikan sentimen
def categorize_sentiment(score):
    if score > 0:
        return 'Positif'
    elif score < 0:
        return 'Negatif'
    else:
        return 'Netral'

data_sentiment1['sentiment_category_english'] = data_sentiment1['sentiment_score_english'].apply(categorize_sentiment)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_14588\3177936794.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment1['sentiment_score_english'] = data_sentiment1['cleaned_title_translated'].apply(get_sentiment)
# C:\Users\asus\AppData\Local\Temp\ipykernel_14588\3177936794.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment1['sentiment_category_english'] = data_sentiment1['sentiment_score_english'].apply(categorize_sentiment)

# %%
data_sentiment1
# Out:
#       keyword                                   title_translated  \
# 0   kesehatan  Mahayastra and Kakarsana solutions about impro...
# 1   kesehatan  Campaign in Klungkung, Koster-Giri promises fr...
# 2   kesehatan  Giri Prasta promised school uniforms and free ...
# 3   kesehatan  AMBARA-ADI WANT TO IMPROVE HEALTH SERVICES IN ...
# 4   kesehatan  Prevent stunting, giri-brata promises to add h...
# 5   kesehatan  BPJS Health Teleconsultation Services began to...
# 6   kesehatan       Habits that can interfere with mental health
# 7   kesehatan  From the Denpasar City Pilwali Debate 2024: Pa...
# 8   kesehatan  KEK Sanur: KEK Health ranked 2nd in the Servic...
# 9   kesehatan  Pertamina Patra Niaga Presents a Child Friendl...
# 10  kesehatan  First in the Gopay application, users can acce...
# 11  kesehatan  Follow the times, BPOM socializes the latest r...
# 12  kesehatan  DRTPM Grant Kemenristekdikti PMP: Improvement ...
# 13  kesehatan  The Sanur Introducing Sanur Health to the Aust...
# 14  kesehatan  Gatra Bali as a Usadha application in supporti...
# 15  kesehatan  Towards quality health: Sutjidra-Supriatna Pre...
# 16  kesehatan  Satriya's leadership Ensures FREE Public Healt...
# 17  kesehatan  From the training of fostered residents in Sin...
# 18  kesehatan  Stelatopia with probiotics: Comprehensive Care...
# 19  kesehatan  Provide the best health services, Satriya prog...
# 20  kesehatan  A week more hard work to extinguish TPA fires ...
# 21  kesehatan  Suyadinata's free health checks were greeted e...
# 22  kesehatan  Optimize emergency health services Buleleng Re...
# 23  kesehatan  Postgraduate School and FKG UNAIR Initiation o...
# 24  kesehatan  Koster-Giri will build a Sports Center in Bali...
# 25  kesehatan  From Arifin Panigoro Dialogue of the 13th Seri...
# 26  kesehatan  Adi Arnawa is concerned about the condition of...
# 27     sosial  Splashy, Ziva Magnolya's photo was secretly en...
# 28     sosial  Plt.Regent of Badung Suiasa conveyed the expla...
# 29     donasi  Agus Salim turned out to be lying?Camer caught...
#
#                              cleaned_title_translated  \
# 0   mahayastra and kakarsana solution about improv...
# 1   campaign in klungkung kostergiri promise free ...
# 2   giri prasta promise school uniform and free he...
# 3   ambaraadi want to improve health service in ba...
# 4   prevent stunt giribrata promise to add health ...
# 5   bpjs health teleconsultation service begin to ...
# 6         habit that can interfere with mental health
# 7   from the denpasar city pilwali debate 2024 pas...
# 8   kek sanur kek health rank 2nd in the service s...
# 9   pertamina patra niaga present a child friendly...
# 10  first in the gopay application user can access...
# 11  follow the time bpom socialize the late regula...
# 12  drtpm grant kemenristekdikti pmp improvement o...
# 13  the sanur introduce sanur health to the austra...
# 14  gatra bali as a usadha application in support ...
# 15  towards quality health sutjidrasupriatna prepa...
# 16  satriyas leadership ensure free public health ...
# 17  from the training of foster resident in singar...
# 18  stelatopia with probiotic comprehensive care o...
# 19  provide the good health service satriya progra...
# 20  a week more hard work to extinguish tpa fire i...
# 21  suyadinata free health check be greet enthusia...
# 22  optimize emergency health service buleleng reg...
# 23  postgraduate school and fkg unair initiation o...
# 24  kostergiri will build a sport center in bali i...
# 25  from arifin panigoro dialogue of the 13th seri...
# 26  adi arnawa be concerned about the condition of...
# 27  splashy ziva magnolyas photo be secretly engag...
# 28  pltregent of badung suiasa convey the explanat...
# 29  agus salim turn out to be lyingcamer catch can...
#
#     sentiment_score_english sentiment_category_english
# 0                  0.000000                     Netral
# 1                  0.400000                    Positif
# 2                  0.400000                    Positif
# 3                  0.000000                     Netral
# 4                  0.000000                     Netral
# 5                  0.000000                     Netral
# 6                 -0.100000                    Negatif
# 7                  0.100000                    Positif
# 8                 -0.225000                    Negatif
# 9                  0.091667                    Positif
# 10                 0.175000                    Positif
# 11                -0.300000                    Negatif
# 12                 0.000000                     Netral
# 13                 0.000000                     Netral
# 14                 0.000000                     Netral
# 15                 0.000000                     Netral
# 16                 0.200000                    Positif
# 17                 0.000000                     Netral
# 18                 0.000000                     Netral
# 19                 0.700000                    Positif
# 20                 0.104167                    Positif
# 21                 0.450000                    Positif
# 22                 0.000000                     Netral
# 23                 0.000000                     Netral
# 24                -0.100000                    Negatif
# 25                 0.050000                    Positif
# 26                 0.000000                     Netral
# 27                -0.155556                    Negatif
# 28                 0.277778                    Positif
# 29                 0.150000                    Positif

# %%
sentiment_counts1 = data_sentiment1['sentiment_category_english'].value_counts()
sentiment_counts1
# Out:
# sentiment_category_english
# Netral     13
# Positif    12
# Negatif     5
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style of the plot using seaborn
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts1.index, y=sentiment_counts1.values, palette='viridis')

# Add labels and title
plt.title('Sentiment Category Distribution (Indonesia)', fontsize=16)
plt.xlabel('Sentiment Category', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Display the values on top of the bars
for i in range(len(sentiment_counts1)):
    plt.text(i, sentiment_counts1.values[i] + 0.5, 
             sentiment_counts1.values[i], 
             ha='center', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# #### Word Cloud (All and Based on Sentiment)

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (1.26.0)
# Requirement already satisfied: pillow in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: matplotlib in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (4.36.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all text from the 'Churn_Reason' column into a single string
text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1['cleaned_title_translated'])

# Create a word cloud
wordcloud_inggris = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_inggris, interpolation='bilinear')
plt.axis('off')  # Remove axes
plt.show()

# %% [markdown]
# Based on Sentiment

# %%
# Sentimen Positif
if data_sentiment1[data_sentiment1['sentiment_category_english'] == "Positif"].shape[0] != 0:
    data_sentiment1_positif = data_sentiment1[data_sentiment1['sentiment_category_english'] == "Positif"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_positif['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_positif_inggris = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_positif_inggris, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else:
    print("Tidak ada sentimen positif pada berita")

# %%
# Sentimen Negatif
if data_sentiment1[data_sentiment1['sentiment_category_english'] == "Negatif"].shape[0] != 0:
    data_sentiment1_negatif = data_sentiment1[data_sentiment1['sentiment_category_english'] == "Negatif"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_negatif['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_negatif_inggris = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_negatif_inggris, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen negatif pada berita")

# %%
# Sentimen Netral
if data_sentiment1[data_sentiment1['sentiment_category_english'] == "Netral"].shape[0] != 0:
    data_sentiment1_netral = data_sentiment1[data_sentiment1['sentiment_category_english'] == "Netral"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_netral['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_netral_inggris = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_netral_inggris, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen netral pada berita")

# %% [markdown]
# ### 2. VADER

# %% [markdown]
# #### Sentiment

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer

# Initialize VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Define a function to get sentiment scores with VADER
def get_sentiment_vader(text):
    # VADER provides a compound score which ranges from -1 (negative) to 1 (positive)
    score = sia.polarity_scores(text)['compound']
    return score

# Apply VADER to get the sentiment scores
data_sentiment1['sentiment_score_english_vader'] = data_sentiment1['cleaned_title_translated'].apply(get_sentiment_vader)

# Categorize sentiment with only 2 categories
def categorize_sentiment(score):
    if score > 0.05:  # Threshold for positive sentiment
        return 'Positif'
    elif score < -0.05:  # Threshold for negative sentiment
        return 'Negatif'
    else:
        return 'Netral'  # Scores between -0.05 and 0.05 considered neutral

data_sentiment1['sentiment_category_english_vader'] = data_sentiment1['sentiment_score_english_vader'].apply(categorize_sentiment)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_14588\17249303.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment1['sentiment_score_english_vader'] = data_sentiment1['cleaned_title_translated'].apply(get_sentiment_vader)
# C:\Users\asus\AppData\Local\Temp\ipykernel_14588\17249303.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment1['sentiment_category_english_vader'] = data_sentiment1['sentiment_score_english_vader'].apply(categorize_sentiment)

# %%
data_sentiment1.head()
# Out:
#      keyword                                   title_translated  \
# 0  kesehatan  Mahayastra and Kakarsana solutions about impro...
# 1  kesehatan  Campaign in Klungkung, Koster-Giri promises fr...
# 2  kesehatan  Giri Prasta promised school uniforms and free ...
# 3  kesehatan  AMBARA-ADI WANT TO IMPROVE HEALTH SERVICES IN ...
# 4  kesehatan  Prevent stunting, giri-brata promises to add h...
#
#                             cleaned_title_translated  sentiment_score_english  \
# 0  mahayastra and kakarsana solution about improv...                      0.0
# 1  campaign in klungkung kostergiri promise free ...                      0.4
# 2  giri prasta promise school uniform and free he...                      0.4
# 3  ambaraadi want to improve health service in ba...                      0.0
# 4  prevent stunt giribrata promise to add health ...                      0.0
#
#   sentiment_category_english  sentiment_score_english_vader  \
# 0                     Netral                         0.6369
# 1                    Positif                         0.6808
# 2                    Positif                         0.6808
# 3                     Netral                         0.4939
# 4                     Netral                         0.3400
#
#   sentiment_category_english_vader
# 0                          Positif
# 1                          Positif
# 2                          Positif
# 3                          Positif
# 4                          Positif

# %%
sentiment_counts1_vader = data_sentiment1['sentiment_category_english_vader'].value_counts()
sentiment_counts1_vader
# Out:
# sentiment_category_english_vader
# Positif    19
# Netral      9
# Negatif     2
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style of the plot using seaborn
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts1_vader.index, y=sentiment_counts1_vader.values, palette='viridis')

# Add labels and title
plt.title('Sentiment Category Distribution (Indonesia)', fontsize=16)
plt.xlabel('Sentiment Category', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Display the values on top of the bars
for i in range(len(sentiment_counts1_vader)):
    plt.text(i, sentiment_counts1_vader.values[i] + 0.5, 
             sentiment_counts1_vader.values[i], 
             ha='center', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# #### Word Cloud (Based on Sentiment Only)

# %%
# Sentimen Positif
if data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Positif"].shape[0] != 0:
    data_sentiment1_positif_vader = data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Positif"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_positif_vader['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_positif_inggris_vader = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_positif_inggris_vader, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen positif pada berita")

# %%
# Sentimen Negatif
if data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Negatif"].shape[0] != 0:
    data_sentiment1_negatif_vader = data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Negatif"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_negatif_vader['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_negatif_inggris_vader = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_negatif_inggris_vader, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen negatif pada berita")

# %%
# Sentimen Netral
if data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Netral"].shape[0] != 0:
    data_sentiment1_netral_vader = data_sentiment1[data_sentiment1['sentiment_category_english_vader'] == "Netral"]

    text = " ".join(cleaned_title_translated for cleaned_title_translated in data_sentiment1_netral_vader['cleaned_title_translated'])

    # Create a word cloud
    wordcloud_netral_inggris_vader = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_netral_inggris_vader, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen netral pada berita")

# %% [markdown]
# ### 3. IndoBERT

# %% [markdown]
# #### Sentiment

# %%
pip install transforms torch
# Out:
# Requirement already satisfied: transforms in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (0.2.1)
# Requirement already satisfied: torch in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (2.5.1)
# Requirement already satisfied: filelock in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
data_sentiment2 = data_ready[['keyword','title','cleaned_title','content']]
data_sentiment2
# Out:
#       keyword                                              title  \
# 0   kesehatan  Solusi Mahayastra dan Kakarsana soal Peningkat...
# 1   kesehatan  Kampanye di Klungkung, Koster-Giri Janjikan Ke...
# 2   kesehatan  Giri Prasta Janjikan Seragam Sekolah dan Layan...
# 3   kesehatan  Ambara-Adi Mau Tingkatkan Layanan Kesehatan di...
# 4   kesehatan  Cegah Stunting, Giri-Brata Janji Tambah Anggar...
# 5   kesehatan  Layanan Telekonsultasi Kesehatan BPJS Mulai Di...
# 6   kesehatan    Kebiasaan yang Bisa Mengganggu Kesehatan Mental
# 7   kesehatan  Dari Debat Pilwali Kota Denpasar 2024: Paslon ...
# 8   kesehatan  KEK Sanur: KEK Kesehatan Peringkat Ke- 2 di Se...
# 9   kesehatan  Pertamina Patra Niaga Hadirkan Desa Ramah Anak...
# 10  kesehatan  Pertama di Aplikasi GoPay, Pengguna Bisa Akses...
# 11  kesehatan  Ikuti Perkembangan Zaman, BPOM Sosialisasikan ...
# 12  kesehatan  Hibah DRTPM Kemenristekdikti PMP: Peningkatan ...
# 13  kesehatan  The Sanur Perkenalkan KEK Kesehatan Sanur ke P...
# 14  kesehatan  Gatra Bali sebagai Aplikasi Usadha dalam Menun...
# 15  kesehatan  Menuju Kesehatan Berkualitas: Sutjidra-Supriat...
# 16  kesehatan  Kepemimpinan Satriya Pastikan Biaya Kesehatan ...
# 17  kesehatan  Dari Pelatihan Warga Binaan di Lapas Singaraja...
# 18  kesehatan  Stelatopia+ Dengan Prebiotik: Perawatan Kompre...
# 19  kesehatan  Berikan Layanan Kesehatan Terbaik, Satriya Pro...
# 20  kesehatan  Seminggu Lebih Kerja Keras Padamkan Kebakaran ...
# 21  kesehatan  Pemeriksaan Kesehatan Gratis Suyadinata Disamb...
# 22  kesehatan  Optimalkan Pelayanan Kesehatan Darurat RSUD Bu...
# 23  kesehatan  Sekolah Pascasarjana dan FKG Unair Inisiasi Pr...
# 24  kesehatan  Koster-Giri akan Bangun Sports Center Bali di ...
# 25  kesehatan  Dari Arifin Panigoro Dialog Seri Ke- 13, Darur...
# 26  kesehatan  Adi Arnawa Prihatin dengan Kondisi Pasutri di ...
# 27     sosial  Heboh, Foto Ziva Magnolya Diam-diam Bertunanga...
# 28     sosial  Plt. Bupati Badung Suiasa Sampaikan Penjelasan...
# 29     donasi  Agus Salim Ternyata Berbohong? Terciduk Kamera...
#
#                                         cleaned_title  \
# 0   solusi mahayastra dan kakarsana soal tingkat l...
# 1   kampanye di klungkung kostergiri janji kesehat...
# 2   giri prasta janji seragam sekolah dan layan se...
# 3   ambaraadi mau tingkat layan sehat di banjarban...
# 4   cegah stunting giribrata janji tambah anggar s...
# 5   layan telekonsultasi sehat bpjs mulai uji coba...
# 6                 biasa yang bisa ganggu sehat mental
# 7   dari debat pilwali kota denpasar paslon jayawi...
# 8   kek sanur kek sehat peringkat ke di sektor jas...
# 9   pertamina patra niaga hadir desa ramah anak pe...
# 10  pertama di aplikasi gopay guna bisa akses asur...
# 11  ikut kembang zaman bpom sosialisasi regulasi b...
# 12  hibah drtpm kemenristekdikti pmp tingkat sehat...
# 13  the sanur kenal kek sehat sanur ke pasar austr...
# 14  gatra bal bagai aplikasi usadha dalam tunjang ...
# 15  tuju sehat kualitas sutjidrasupriatna siap dok...
# 16  pimpin satriya pasti biaya sehat masyarakat gr...
# 17  dari latih warga bina di lapas singaraja latih...
# 18  stelatopia dengan prebiotik awat komprehensif ...
# 19  ikan layan sehat baik satriya program tingkat ...
# 20  minggu lebih kerja keras padam bakar tpa di nu...
# 21  periksa sehat gratis suyadinata sambut antusia...
# 22  optimal layan sehat darurat rsud buleleng bisa...
# 23  sekolah pascasarjana dan fkg unair inisiasi pr...
# 24  kostergiri akan bangun sports center bal di ba...
# 25  dari arifin panigoro dialog seri ke darurat se...
# 26  adi arnawa prihatin dengan kondisi pasutri di ...
# 27  heboh foto ziva magnolya diamdiam tunang denga...
# 28  plt bupati badung suiasa sampai jelas raperda ...
# 29  agus salim nyata bohong ciduk kamera bisa liha...
#
#                                               content
# 0   Dua pasangan calon (paslon) yang berlaga dalam...
# 1   Calon gubernur dan wakil gubernur Bali nomor u...
# 2   Calon wakil gubernur (cawagub) Bali, I Nyoman ...
# 3   Duet Gede Ngurah Ambara Putra-I Nengah Yasa Ad...
# 4   Calon bupati (cabup) Bangli nomor urut 3, Ida ...
# 5                                           Kesehatan
# 6                                           Kesehatan
# 7                                            Denpasar
# 8                                          Pariwisata
# 9                                 Ekonomi & Perbankan
# 10                                         Gaya Hidup
# 11                                          Kesehatan
# 12                                         Pendidikan
# 13                                         Pariwisata
# 14                                         Pendidikan
# 15                                           Politika
# 16                                           Politika
# 17                                           Buleleng
# 18                                         Gaya Hidup
# 19                                           Politika
# 20                                          Klungkung
# 21                                           Politika
# 22                                           Buleleng
# 23                                         Pendidikan
# 24                                           Politika
# 25                                           Nasional
# 26                                           Politika
# 27                              Hiburan & Seni Budaya
# 28                                             Badung
# 29                              Hiburan & Seni Budaya

# %%
from transformers import BertForSequenceClassification, BertTokenizer
import torch

# Load the saved model and tokenizer
model_load_path = "C:/Users/asus/OneDrive/BPS/Neraca/smsa_bpsbali_indobert_model"  # The path where the model is saved
tokenizer_load_path = "C:/Users/asus/OneDrive/BPS/Neraca/smsa_bpsbali_indobert_tokenizer"  # The path where the tokenizer is saved

# Load the model and tokenizer
model = BertForSequenceClassification.from_pretrained(model_load_path)
tokenizer = BertTokenizer.from_pretrained(tokenizer_load_path)

# %%
from torch.nn.functional import softmax  # Softmax function to convert logits to probabilities

# Initialize an empty list to collect predictions
sentiment_predict = []
probabilities = []

# Loop through the cleaned titles
for text in data_sentiment2['cleaned_title']:
    # Tokenize the input text
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)

    # Make prediction
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():  # Disable gradients for inference
        outputs = model(**inputs)

    # Get the logits (raw scores)
    logits = outputs.logits
    
    # Apply softmax to convert logits to probabilities
    probs = softmax(logits, dim=-1)  # Softmax along the class dimension (last dimension)

    # Get the predicted class (index of max logit)
    predicted_class = logits.argmax(dim=-1).item()

    # Get the probability of the predicted class
    predicted_prob = probs[0, predicted_class].item()

    # Convert prediction to string label
    if predicted_class == 0:
        sentiment_label = "positif"
    elif predicted_class == 1:
        sentiment_label = "netral"
    else:
        sentiment_label = "negatif"

    # Append the sentiment label and its probability
    sentiment_predict.append(sentiment_label)
    probabilities.append(predicted_prob)

# After the loop, create the DataFrame
sentiment_predict_df = pd.DataFrame({
    'sentiment': sentiment_predict,
    'probability': probabilities
})

# Add it as a new column to the original DataFrame
data_sentiment2['sentiment_score_indonesia'] = sentiment_predict_df['probability']
data_sentiment2['sentiment_category_indonesia'] = sentiment_predict_df['sentiment']

# Optionally, you can print the DataFrame to check the results
data_sentiment2
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_14588\1096017218.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment2['sentiment_score_indonesia'] = sentiment_predict_df['probability']
# C:\Users\asus\AppData\Local\Temp\ipykernel_14588\1096017218.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sentiment2['sentiment_category_indonesia'] = sentiment_predict_df['sentiment']
#       keyword                                              title  \
# 0   kesehatan  Solusi Mahayastra dan Kakarsana soal Peningkat...
# 1   kesehatan  Kampanye di Klungkung, Koster-Giri Janjikan Ke...
# 2   kesehatan  Giri Prasta Janjikan Seragam Sekolah dan Layan...
# 3   kesehatan  Ambara-Adi Mau Tingkatkan Layanan Kesehatan di...
# 4   kesehatan  Cegah Stunting, Giri-Brata Janji Tambah Anggar...
# 5   kesehatan  Layanan Telekonsultasi Kesehatan BPJS Mulai Di...
# 6   kesehatan    Kebiasaan yang Bisa Mengganggu Kesehatan Mental
# 7   kesehatan  Dari Debat Pilwali Kota Denpasar 2024: Paslon ...
# 8   kesehatan  KEK Sanur: KEK Kesehatan Peringkat Ke- 2 di Se...
# 9   kesehatan  Pertamina Patra Niaga Hadirkan Desa Ramah Anak...
# 10  kesehatan  Pertama di Aplikasi GoPay, Pengguna Bisa Akses...
# 11  kesehatan  Ikuti Perkembangan Zaman, BPOM Sosialisasikan ...
# 12  kesehatan  Hibah DRTPM Kemenristekdikti PMP: Peningkatan ...
# 13  kesehatan  The Sanur Perkenalkan KEK Kesehatan Sanur ke P...
# 14  kesehatan  Gatra Bali sebagai Aplikasi Usadha dalam Menun...
# 15  kesehatan  Menuju Kesehatan Berkualitas: Sutjidra-Supriat...
duet Gede Ngurah Ambara Putra-I Nengah Yasa Ad...
# 4   Calon bupati (cabup) Bangli nomor urut 3, Ida ...
# 5                                           Kesehatan
# 6                                           Kesehatan
# 7                                            Denpasar
# 8                                          Pariwisata
# 9                                 Ekonomi & Perbankan
# 10                                         Gaya Hidup
# 11                                          Kesehatan
# 12                                         Pendidikan
# 13                                         Pariwisata
# 14                                         Pendidikan
# 15                                           Politika
# 16                                           Politika
# 17                                           Buleleng
# 18                                         Gaya Hidup
# 19                                           Politika
# 20                                          Klungkung
# 21                                           Politika
# 22                                           Buleleng
# 23                                         Pendidikan
# 24                                           Politika
# 25                                           Nasional
# 26                                           Politika
# 27                              Hiburan & Seni Budaya
# 28                                             Badung
# 29                              Hiburan & Seni Budaya
#
#     sentiment_score_indonesia sentiment_category_indonesia
# 0                    0.984495                       netral
# 1                    0.975180                       netral
# 2                    0.978261                       netral
# 3                    0.980366                       netral
# 4                    0.979708                       netral
# 5                    0.992675                       netral
# 6                    0.996054                      negatif
# 7                    0.969198                       netral
# 8                    0.889279                       netral
# 9                    0.753732                       netral
# 10                   0.943201                       netral
# 11                   0.990677                       netral
# 12                   0.993178                       netral
# 13                   0.884846                       netral
# 14                   0.641157                       netral
# 15                   0.971166                       netral
# 16                   0.530684                      positif
# 17                   0.922198                       netral
# 18                   0.902755                       netral
# 19                   0.959711                       netral
# 20                   0.722213                      positif
# 21                   0.962979                       netral
# 22                   0.988953                       netral
# 23                   0.991232                       netral
# 24                   0.853383                       netral
# 25                   0.996376                       netral
# 26                   0.979319                       netral
# 27                   0.936943                       netral
# 28                   0.994510                       netral
# 29                   0.846581                       netral

# %%
sentiment_counts2 = data_sentiment2['sentiment_category_indonesia'].value_counts()
sentiment_counts2
# Out:
# sentiment_category_indonesia
# netral     27
# positif     2
# negatif     1
# Name: count, dtype: int64

# %%
import seaborn as sns

# Set the style of the plot using seaborn
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts2.index, y=sentiment_counts2.values, palette='viridis')

# Add labels and title
plt.title('Sentiment Category Distribution (Indonesia)', fontsize=16)
plt.xlabel('Sentiment Category', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Display the values on top of the bars
for i in range(len(sentiment_counts2)):
    plt.text(i, sentiment_counts2.values[i] + 0.5, 
             sentiment_counts2.values[i], 
             ha='center', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# #### Word Cloud (All and Based on Sentiment)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all text from the 'Churn_Reason' column into a single string
text = " ".join(cleaned_title for cleaned_title in data_sentiment2['cleaned_title'])

# Create a word cloud
wordcloud_indonesia = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_indonesia, interpolation='bilinear')
plt.axis('off')  # Remove axes
plt.show()

# %% [markdown]
# Based on Sentiment

# %%
# Sentimen Positif
if data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "positif"].shape[0] != 0:
    data_sentiment2_positif = data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "positif"]

    text = " ".join(cleaned_title for cleaned_title in data_sentiment2_positif['cleaned_title'])

    # Create a word cloud
    wordcloud_positif_indonesia = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_positif_indonesia, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen positif pada berita")

# %%
# Sentimen Negatif
if data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "negatif"].shape[0] != 0:
    data_sentiment2_negatif = data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "negatif"]

    text = " ".join(cleaned_title for cleaned_title in data_sentiment2_negatif['cleaned_title'])

    # Create a word cloud
    wordcloud_negatif_indonesia = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_negatif_indonesia, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen negatif pada berita")

# %%
# Sentimen Netral
if data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "netral"].shape[0] != 0:
    data_sentiment2_netral = data_sentiment2[data_sentiment2['sentiment_category_indonesia'] == "netral"]

    text = " ".join(cleaned_title for cleaned_title in data_sentiment2_netral['cleaned_title'])

    # Create a word cloud
    wordcloud_netral_indonesia = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud using matplotlib
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_netral_indonesia, interpolation='bilinear')
    plt.axis('off')  # Remove axes
    plt.show()
else: print("Tidak ada sentimen netral pada berita")

# %% [markdown]
# ### Export Result

# %%
print(data_sentiment1.shape)
data_sentiment1.head()
# Out:
# (30, 7)
#      keyword                                   title_translated  \
# 0  kesehatan  Mahayastra and Kakarsana solutions about impro...
# 1  kesehatan  Campaign in Klungkung, Koster-Giri promises fr...
# 2  kesehatan  Giri Prasta promised school uniforms and free ...
# 3  kesehatan  AMBARA-ADI WANT TO IMPROVE HEALTH SERVICES IN ...
# 4  kesehatan  Prevent stunting, giri-brata promises to add h...
#
#                             cleaned_title_translated  sentiment_score_english  \
# 0  mahayastra and kakarsana solution about improv...                      0.0
# 1  campaign in klungkung kostergiri promise free ...                      0.4
# 2  giri prasta promise school uniform and free he...                      0.4
# 3  ambaraadi want to improve health service in ba...                      0.0
# 4  prevent stunt giribrata promise to add health ...                      0.0
#
#   sentiment_category_english  sentiment_score_english_vader  \
# 0                     Netral                         0.6369
# 1                    Positif                         0.6808
# 2                    Positif                         0.6808
# 3                     Netral                         0.4939
# 4                     Netral                         0.3400
#
#   sentiment_category_english_vader
# 0                          Positif
# 1                          Positif
# 2                          Positif
# 3                          Positif
# 4                          Positif

# %%
print(data_sentiment2.shape)
data_sentiment2.head()
# Out:
# (30, 6)
#      keyword                                              title  \
# 0  kesehatan  Solusi Mahayastra dan Kakarsana soal Peningkat...
# 1  kesehatan  Kampanye di Klungkung, Koster-Giri Janjikan Ke...
# 2  kesehatan  Giri Prasta Janjikan Seragam Sekolah dan Layan...
# 3  kesehatan  Ambara-Adi Mau Tingkatkan Layanan Kesehatan di...
# 4  kesehatan  Cegah Stunting, Giri-Brata Janji Tambah Anggar...
#
#                                        cleaned_title  \
# 0  solusi mahayastra dan kakarsana soal tingkat l...
# 1  kampanye di klungkung kostergiri janji kesehat...
# 2  giri prasta janji seragam sekolah dan layan se...
# 3  ambaraadi mau tingkat layan sehat di banjarban...
# 4  cegah stunting giribrata janji tambah anggar s...
#
#                                              content  \
# 0  Dua pasangan calon (paslon) yang berlaga dalam...
# 1  Calon gubernur dan wakil gubernur Bali nomor u...
# 2  Calon wakil gubernur (cawagub) Bali, I Nyoman ...
# 3  Duet Gede Ngurah Ambara Putra-I Nengah Yasa Ad...
# 4  Calon bupati (cabup) Bangli nomor urut 3, Ida ...
#
#    sentiment_score_indonesia sentiment_category_indonesia
# 0                   0.984495                       netral
# 1                   0.975180                       netral
# 2                   0.978261                       netral
# 3                   0.980366                       netral
# 4                   0.979708                       netral

# %%
# Assigning columns individually
sentiment_result = data_sentiment2.copy()  # Copy data_sentiment2 to avoid modifying the original

# Assign columns from data_sentiment1 to sentiment_result
sentiment_result['title_translated'] = data_sentiment1['title_translated']
sentiment_result['cleaned_title_translated'] = data_sentiment1['cleaned_title_translated']
sentiment_result['sentiment_category_english'] = data_sentiment1['sentiment_category_english']
sentiment_result['sentiment_score_english'] = data_sentiment1['sentiment_score_english']
sentiment_result['sentiment_category_english_vader'] = data_sentiment1['sentiment_category_english_vader']
sentiment_result['sentiment_score_english_vader'] = data_sentiment1['sentiment_score_english_vader']

print(sentiment_result.shape)
sentiment_result.head()
# Out:
# (30, 12)
#      keyword                                              title  \
# 0  kesehatan  Solusi Mahayastra dan Kakarsana soal Peningkat...
# 1  kesehatan  Kampanye di Klungkung, Koster-Giri Janjikan Ke...
# 2  kesehatan  Giri Prasta Janjikan Seragam Sekolah dan Layan...
# 3  kesehatan  Ambara-Adi Mau Tingkatkan Layanan Kesehatan di...
# 4  kesehatan  Cegah Stunting, Giri-Brata Janji Tambah Anggar...
#
#                                        cleaned_title  \
# 0  solusi mahayastra dan kakarsana soal tingkat l...
# 1  kampanye di klungkung kostergiri janji kesehat...
# 2  giri prasta janji seragam sekolah dan layan se...
# 3  ambaraadi mau tingkat layan sehat di banjarban...
# 4  cegah stunting giribrata janji tambah anggar s...
#
#                                              content  \
# 0  Dua pasangan calon (paslon) yang berlaga dalam...
# 1  Calon gubernur dan wakil gubernur Bali nomor u...
# 2  Calon wakil gubernur (cawagub) Bali, I Nyoman ...
# 3  Duet Gede Ngurah Ambara Putra-I Nengah Yasa Ad...
# 4  Calon bupati (cabup) Bangli nomor urut 3, Ida ...
#
#    sentiment_score_indonesia sentiment_category_indonesia  \
# 0                   0.984495                       netral
# 1                   0.975180                       netral
# 2                   0.978261                       netral
# 3                   0.980366                       netral
# 4                   0.979708                       netral
#
#                                     title_translated  \
# 0  Mahayastra and Kakarsana solutions about impro...
# 1  Campaign in Klungkung, Koster-Giri promises fr...
# 2  Giri Prasta promised school uniforms and free ...
# 3  AMBARA-ADI WANT TO IMPROVE HEALTH SERVICES IN ...
# 4  Prevent stunting, giri-brata promises to add h...
#
#                             cleaned_title_translated  \
# 0  mahayastra and kakarsana solution about improv...
# 1  campaign in klungkung kostergiri promise free ...
# 2  giri prasta promise school uniform and free he...
# 3  ambaraadi want to improve health service in ba...
# 4  prevent stunt giribrata promise to add health ...
#
#   sentiment_category_english  sentiment_score_english  \
# 0                     Netral                      0.0
# 1                    Positif                      0.4
# 2                    Positif                      0.4
# 3                     Netral                      0.0
# 4                     Netral                      0.0
#
#   sentiment_category_english_vader  sentiment_score_english_vader
# 0                          Positif                         0.6369
# 1                          Positif                         0.6808
# 2                          Positif                         0.6808
# 3                          Positif                         0.4939
# 4                          Positif                         0.3400

# %%
sentiment_result.to_excel("C:/Users/asus/OneDrive/BPS/Neraca/sentimentresult_sektor16_triwulan4_bali.xlsx")
